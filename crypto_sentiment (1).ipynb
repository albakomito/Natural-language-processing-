# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from newsapi import NewsApiClient
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Owner\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable
load_dotenv()
api_key = os.getenv("NEWS_API_KEY")

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
btc_articles = newsapi.get_everything(
    q="bitcoin",
    language="en",
    page_size=100, 
    sort_by="relevancy"
)

btc_articles
# Out:
# {'status': 'ok',
#  'totalResults': 10165,
#  'articles': [{'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Arielle Pardes',
#    'title': 'Miami’s Bitcoin Conference Left a Trail of Harassment',
#    'description': 'For some women, inappropriate conduct from other conference-goers continued to haunt them online.',
#    'url': 'https://www.wired.com/story/bitcoin-2022-conference-harassment/',
#    'urlToImage': 'https://media.wired.com/photos/627a89e3e37e715cb7d760d2/191:100/w_1280,c_limit/Bitcoin_Miami_Biz_GettyImages-1239817123.jpg',
#    'publishedAt': '2022-05-10T16:59:46Z',
#    'content': 'Now, even though there are a number of women-focused crypto spaces, Odeniran says women are still underrepresented. Ive been in spaces where Im the only Black person, or the only woman, or the only B… [+3828 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Justine Calma',
#    'title': 'Why fossil fuel companies see green in Bitcoin mining projects',
#    'description': 'ExxonMobil and other fossil fuel companies have turned to Bitcoin mining to address a gas problem. But their plans come with risks.',
#    'url': 'https://www.theverge.com/2022/5/4/23055761/exxonmobil-cryptomining-bitcoin-methane-gas',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/BZdljrBbt8tBl6oCCnckcDKqe6g=/0x90:4608x2503/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/23435975/1240300988.jpg',
#    'publishedAt': '2022-05-04T12:00:00Z',
#    'content': 'A Bitcoin mining site powered by otherwise lost gas from an oil well near Linden, Texas, on April 4th, 2022. | Photo by FRANCOIS PICARD/AFP via Getty Images\r\n\n \n\n Of all the corporate climate hype fl… [+6544 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Matt Novak',
#    'title': "Warren Buffett Says He Wouldn't Take All the Bitcoin in the World for $25",
#    'description': 'Warren Buffett has always been a bitcoin skeptic. But the billionaire investor had his most harsh words yet for the cryptocurrency over the weekend. Buffett made it clear that his opposition to crypto has nothing to do with whether people can make money tradi…',
#    'url': 'https://gizmodo.com/warren-buffett-all-bitcoin-world-25-dollars-assets-valu-1848866967',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/bbc389f90510758bf8f4131a7e2cbacd.png',
#    'publishedAt': '2022-05-02T11:30:00Z',
#    'content': 'Warren Buffett has always been a bitcoin skeptic. But the billionaire investor had his most harsh words yet for the cryptocurrency over the weekend. Buffett made it clear that his opposition to crypt… [+2297 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Kyle Barr',
#    'title': 'Luna Foundation Tried to Prop Up Terra’s Crumbling Base With Billions in Bitcoin, But It Still Failed',
#    'description': 'As a kid, I remember when my father tried to use a broom handle in a last ditch effort to support a roof that was collapsing from the weight of nearly three feet of snow. You can guess how well that went. In a similar vein, Terra blockchain reportedly spent $…',
#    'url': 'https://gizmodo.com/luna-foundation-terra-bitcoin-crypto-lfg-1848933191',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/f8f25ce9a57b3454932cdead4c3278b6.jpg',
#    'publishedAt': '2022-05-16T20:45:00Z',
#    'content': 'As a kid, I remember when my father tried to use a broom handle in a last ditch effort to support a roof that was collapsing from the weight of nearly three feet of snow. You can guess how well that … [+3390 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'Bitcoin value drops by 50% since November peak',
#    'description': 'The slide in the value of cryptocurrencies comes as stock markets around the world have also fallen.',
#    'url': 'https://www.bbc.co.uk/news/business-61375152',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/8362/production/_124643633_gettyimages-1384896168.jpg',
#    'publishedAt': '2022-05-09T03:04:37Z',
#    'content': "Image source, Getty Images\r\nThe value of Bitcoin continued to fall over the weekend as it dropped below $34,000 (£27,630), according to the Coinbase cryptocurrency exchange.\r\nThe world's largest cryp… [+2164 chars]"},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Lauren Leffer',
#    'title': 'Fidelity Wants to Include Bitcoin in 401(k) Plans; Elizabeth Warren and the Labor Department Have Concerns',
#    'description': "The nation's largest retirement plan provider is getting pushback for allowing investors to put a portion of their savings into cryptocurrency.",
#    'url': 'https://gizmodo.com/fidelity-wants-bitcoin-added-to-401-k-retirement-plans-1848885502',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/2413ade0375c0f5b3affe4029f35315c.jpg',
#    'publishedAt': '2022-05-05T18:10:00Z',
#    'content': 'If youve ever felt like introducing some Vegas-style odds into your retirement plan, youre finally in luck.\r\nLast week, Fidelity Investments announced that it would allow investors to put part of the… [+3239 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Jon Fingas',
#    'title': 'US Treasury issues first-ever sanctions against a cryptocurrency mixer',
#    'description': 'Cryptocurrency mixers are sometimes used to help online criminals launder their stolen money by hiding its true origins, and the US Treasury is now ready to clamp down on them when hostile governments are involved. The department has issued its first sanction…',
#    'url': 'https://www.engadget.com/us-treasury-sanctions-virtual-currency-mixer-north-korea-203502517.html',
#    'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2021-11/0db21000-4246-11ec-a8de-edfca39c0e00',
#    'publishedAt': '2022-05-06T20:35:02Z',
#    'content': 'Cryptocurrency mixers are sometimes used to help online criminals launder their stolen money by hiding its true origins, and the US Treasury is now ready to clamp down on them when hostile government… [+1432 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Bitcoin falls 7.2% to $28758 - Reuters.com',
#    'description': 'Bitcoin fell 7.23% to $28,758.29 at 22:05 GMT on Wednesday, losing $2,241.68 from its previous close.',
#    'url': 'https://www.reuters.com/business/bitcoin-falls-72-28758-2022-05-11/',
#    'urlToImage': 'https://www.reuters.com/resizer/lEay-or8c9TPjZOEmIjrJf3ylQk=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/3RKTTS2CRVM2BEEDCB2ZIPV3L4.jpg',
#    'publishedAt': '2022-05-11T22:18:00Z',
#    'content': "May 11 (Reuters) - Bitcoin fell 7.23% to $28,758.29 at 22:05 GMT on Wednesday, losing $2,241.68 from its previous close.\r\nBitcoin, the world's biggest and best-known cryptocurrency, is down 40.4% fro… [+361 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Bitcoin last up 5.7% at $39862.84 - Reuters.com',
#    'description': 'Bitcoin rose 5.7% to $39,862.84, on Wednesday, adding $2,102.94 to its previous close.',
#    'url': 'https://www.reuters.com/business/bitcoin-last-up-57-3986284-2022-05-04/',
#    'urlToImage': 'https://www.reuters.com/resizer/BWWUiBev3PUU7DomJJXE2-Iqz30=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/OZ6CVP422VIJ5A6UACI72VHUSY.jpg',
#    'publishedAt': '2022-05-04T20:16:00Z',
#    'content': "May 4 (Reuters) - Bitcoin rose 5.7% to $39,862.84, on Wednesday, adding $2,102.94 to its previous close.\r\nBitcoin, the world's biggest and best-known cryptocurrency, is up 20.9% from the year's low o… [+337 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Bitcoin last down 5.1% at $38391.36 - Reuters.com',
#    'description': 'Bitcoin dropped 5.1% to $38,391.36 on Tuesday, down $2,229.82 from its previous close.',
#    'url': 'https://www.reuters.com/technology/bitcoin-last-down-51-3839136-2022-04-26/',
#    'urlToImage': 'https://www.reuters.com/resizer/Gp-bLvBDv3-2g6-hsKYIWV0KicU=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/BT3DV4I6BJNQBL3JI4HWYNGSYQ.jpg',
#    'publishedAt': '2022-04-26T20:22:00Z',
#    'content': "April 26 (Reuters) - Bitcoin dropped 5.1% to $38,391.36 on Tuesday, down $2,229.82 from its previous close.\r\nBitcoin, the world's biggest and best-known cryptocurrency, is up 16% from the year's low … [+339 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Editorial',
#    'title': 'Cryptoverse: rising interest hurts Bitcoin - Reuters',
#    'description': "From Bitcoin's dramatic drop to a new way to pay for your luxury Gucci handbag, we round up the week's big stories in cryptocurrencies. Kristy Kilburn reports.",
#    'url': 'https://www.reuters.com/video/watch/idOV695710052022RP1',
#    'urlToImage': 'https://static.reuters.com/resources/r/?d=20220510&i=OV695710052022RP1&r=OV695710052022RP1&t=2',
#    'publishedAt': '2022-05-10T18:29:04Z',
#    'content': "Posted \r\nFrom Bitcoin's dramatic drop to a new way to pay for your luxury Gucci handbag, we round up the week's big stories in cryptocurrencies. Kristy Kilburn reports."},
#   {'source': {'id': None, 'name': 'Bitcoin.com'},
#    'author': None,
#    'title': 'Bitcoin, Ethereum Technical Analysis: BTC Slips to 10-Month Low, Below $33000 – Market Updates Bitcoin News - Bitcoin News',
#    'description': '<ol><li>Bitcoin, Ethereum Technical Analysis: BTC Slips to 10-Month Low, Below $33000 – Market Updates Bitcoin News\xa0\xa0Bitcoin News\r\n</li><li>Bitcoin drops 50% from peak, near lowest levels in last one year\xa0\xa0Economic Times\r\n</li><li>Crypto Crash: Why is cryptoc…',
#    'url': 'https://news.bitcoin.com/bitcoin-ethereum-technical-analysis-btc-slips-to-10-month-low-below-33000/',
#    'urlToImage': 'https://static.news.bitcoin.com/wp-content/uploads/2022/05/shutterstock_1978798856-1.jpg',
#    'publishedAt': '2022-05-09T13:45:30Z',
#    'content': 'BTC fell to its lowest level since last July, as prices dropped below $33,000 to start the week. The selloff in cryptocurrency started last week, following the Fed’s decision to hike interest rates b… [+2651 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Bitcoin falls 7.8% to $31333 - Reuters',
#    'description': 'Bitcoin dropped 7.81% to $31,333.41 at 20:03 GMT on Monday, losing $2,655.98 from its previous close.',
#    'url': 'https://www.reuters.com/business/bitcoin-falls-78-31333-2022-05-09/',
#    'urlToImage': 'https://www.reuters.com/resizer/BWWUiBev3PUU7DomJJXE2-Iqz30=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/OZ6CVP422VIJ5A6UACI72VHUSY.jpg',
#    'publishedAt': '2022-05-09T20:11:00Z',
#    'content': "May 9 (Reuters) - Bitcoin dropped 7.81% to $31,333.41 at 20:03 GMT on Monday, losing $2,655.98 from its previous close.\r\nBitcoin, the world's biggest and best-known cryptocurrency, is down 35% from t… [+351 chars]"},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Kevin Hurler',
#    'title': 'You Can Now Go See Fantastic Beasts With Dogecoin at AMC Theaters',
#    'description': 'Dogecoiners unite! Movie theater chain AMC has welcomed some more cryptocurrencies as payment options for online and mobile purchases. In a tweet on April 15, AMC CEO Adam Aron announced that moviegoers can now pay for movie tickets and concessions using Doge…',
#    'url': 'https://gizmodo.com/you-can-now-go-see-fantastic-beasts-with-dogecoin-at-am-1848805758',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/9c1a5c315585258a257319589a2c2bf5.jpg',
#    'publishedAt': '2022-04-18T20:30:00Z',
#    'content': 'Dogecoiners unite! Movie theater chain AMC has welcomed some more cryptocurrencies as payment options for online and mobile purchases. In a tweet on April 15, AMC CEO Adam Aron announced that moviego… [+1603 chars]'},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Gian M. Volpicelli',
#    'title': 'Terra’s Crypto Meltdown Was Inevitable',
#    'description': 'An epic crash in algorithmic stablecoins spells trouble for the entire industry.',
#    'url': 'https://www.wired.com/story/terra-luna-collapse/',
#    'urlToImage': 'https://media.wired.com/photos/627d5bac0c454f12d5142672/191:100/w_1280,c_limit/Terra-Luna-Stable-Coins-Business-1382597134.jpg',
#    'publishedAt': '2022-05-12T19:14:35Z',
#    'content': 'At a Mexican restaurant in North London a few weeks ago, a handful of small-time but remarkably discerning retail cryptocurrency investors predicted that terra and luna would crash. Several of them w… [+2779 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': "Cryptoverse: Buying the dip? Bitcoin's a rates rookie - Reuters",
#    'description': 'Bitcoin has scant experience with rising interest rates, posing perils for investors looking to capitalize on its dramatic drop.',
#    'url': 'https://www.reuters.com/business/finance/cryptoverse-buying-dip-bitcoins-rates-rookie-2022-05-10/',
#    'urlToImage': 'https://www.reuters.com/resizer/mhnlNnjhE1y-CQ7JRZnTaDhnC_s=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/5O2YCJEQRNIP3KJAD2CMYQT3HM.jpg',
#    'publishedAt': '2022-05-10T05:17:00Z',
#    'content': 'May 10 (Reuters) - Bitcoin has scant experience with rising interest rates, posing perils for investors looking to capitalize on its dramatic drop.\r\nThe cryptocurrency has tanked along with other ris… [+4315 chars]'},
#   {'source': {'id': None, 'name': 'CNET'},
#    'author': 'Kourtnee Jackson',
#    'title': 'Central African Republic Passes Bill to Make Bitcoin Legal Tender - CNET',
#    'description': 'The nation is the second in line to make bitcoin a form of legal payment.',
#    'url': 'https://www.cnet.com/personal-finance/crypto/central-african-republic-passes-bill-to-make-bitcoin-legal-tender/',
#    'urlToImage': 'https://www.cnet.com/a/img/resize/254465c78aa125dceeb1d745c522cdd52ce7f7b1/2022/04/22/5e2b33a9-9ee6-400b-a99e-21bd935e2912/bitcoin-crypto-logo-2022-614.jpg?auto=webp&fit=crop&height=630&width=1200',
#    'publishedAt': '2022-04-27T15:44:58Z',
#    'content': "The Central African Republic has adopted bitcoin as legal tender, making it the second nation in the world -- after El Salvador -- to do so. On Wednesday, President Faustin Archange Touadera's office… [+1078 chars]"},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'msmash',
#    'title': 'Bitcoin Has No Future as a Payments Network, Says FTX Chief',
#    'description': "Bitcoin has no future as a payments network because of its inefficiency and high environmental costs, according to one of crypto's most influential chief executives. From a report: Sam Bankman-Fried, founder of the digital asset exchange FTX, said the proof o…",
#    'url': 'https://tech.slashdot.org/story/22/05/16/147235/bitcoin-has-no-future-as-a-payments-network-says-ftx-chief',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/bitcoin_64.png',
#    'publishedAt': '2022-05-16T14:07:00Z',
#    'content': 'Sam Bankman-Fried, founder of the digital asset exchange FTX, said the proof of work system of validating blockchain transactions, which underpins bitcoin, was not capable of scaling up to cope with … [+1063 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'htowey@insider.com (Hannah Towey)',
#    'title': "Bitcoin crash erases $36 million in value from El Salvador government's massive crypto investment as national debt grows",
#    'description': 'El Salvador became the first country to make bitcoin legal tender in September despite multiple warnings from financial institutions.',
#    'url': 'https://markets.businessinsider.com/news/currencies/el-salvador-government-loses-36-million-bitcoin-crash-national-debt-2022-5',
#    'urlToImage': 'https://i.insider.com/627d3e7e27d5960019ee4e59?width=1200&format=jpeg',
#    'publishedAt': '2022-05-13T08:12:28Z',
#    'content': 'El Salvador which became the first country to make bitcoin legal tender in September has lost $36 million in cryptocurrency as bitcoin plummeted over 50% from its all-time high on Thursday.\xa0\r\nPreside… [+2209 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Analysis: Bitcoin adoption by Central African Republic baffles cryptoverse - Reuters.com',
#    'description': "Central African Republic's adoption of bitcoin, while many of the world's largest economies stay wary of it, has puzzled the cryptocurrency world and residents of the gold and diamond-producing country, and prompted caution from the IMF.",
#    'url': 'https://www.reuters.com/world/africa/bitcoin-adoption-by-central-african-republic-baffles-cryptoverse-2022-04-28/',
#    'urlToImage': 'https://www.reuters.com/resizer/sBWUvemJW0ryqtlCm2qpRiwhcus=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/XW2TXYEQFZNPVKYUBO65KACFFU.jpg',
#    'publishedAt': '2022-04-28T16:58:00Z',
#    'content': "BANGUI, April 28 (Reuters) - Central African Republic's adoption of bitcoin, while many of the world's largest economies stay wary of it, has puzzled the cryptocurrency world and residents of the gol… [+4218 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Central African Republic adopts bitcoin as an official currency - Reuters',
#    'description': 'Central African Republic has adopted bitcoin as an official currency, the presidency said on Wednesday, becoming the first country in Africa and only the second in the world to do so.',
#    'url': 'https://www.reuters.com/world/africa/central-african-republic-adopts-bitcoin-an-official-currency-2022-04-27/',
#    'urlToImage': 'https://www.reuters.com/resizer/hQUFyg89hsElzlhGfkPIvaoHxbY=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/IB36Y4ZKDRLJNA3LRDQAHS7UGM.jpg',
#    'publishedAt': '2022-04-27T18:03:00Z',
#    'content': 'BANGUI, April 27 (Reuters) - Central African Republic has adopted bitcoin as an official currency, the presidency said on Wednesday, becoming the first country in Africa and only the second in the wo… [+2211 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Editorial',
#    'title': "Bitcoin to bourses: Africa's top business news - Reuters",
#    'description': "A senior government official says South Africa's green transition will need funding of one trillion rand while Zambia's president says the country is close to finding an investor for Mopani Copper Mines. Here are five stories making business headlines in sub-…",
#    'url': 'https://www.reuters.com/video/watch/idOV475529042022RP1',
#    'urlToImage': 'https://static.reuters.com/resources/r/?d=20220429&i=OV475529042022RP1&r=OV475529042022RP1&t=2',
#    'publishedAt': '2022-04-29T12:11:15Z',
#    'content': "Posted \r\nA senior government official says South Africa's green transition will need funding of one trillion rand while Zambia's president says the country is close to finding an investor for Mopani … [+93 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Editorial',
#    'title': 'Bitcoin slumps to lowest level since January - Reuters',
#    'description': "The value of the world's biggest cryptocurrencies have been sliding in line with global markets, in particular the tech-heavy Nasdaq. Tom Scally has more.",
#    'url': 'https://www.reuters.com/video/watch/idOV668209052022RP1',
#    'urlToImage': 'https://static.reuters.com/resources/r/?d=20220509&i=OV668209052022RP1&r=OV668209052022RP1&t=2',
#    'publishedAt': '2022-05-09T11:44:15Z',
#    'content': "Posted \r\nThe value of the world's biggest cryptocurrencies have been sliding in line with global markets, in particular the tech-heavy Nasdaq. Tom Scally has more."},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Editorial',
#    'title': "'Stablecoin' collapse crushes crypto - Reuters",
#    'description': '05/13 Cryptocurrencies nursed large losses early Friday with bitcoin set for a record losing streak as the collapse of TerraUSD, a so-called stablecoin, rippled through markets.',
#    'url': 'https://www.reuters.com/video/watch/idsv8I?now=true',
#    'urlToImage': 'https://ajo.prod.reuters.tv/api/v2/img/627e6d5ae4b09631b0e48930-1652452698077?location=LANDSCAPE',
#    'publishedAt': '2022-05-13T15:10:47Z',
#    'content': 'Posted \r\n05/13 Cryptocurrencies nursed large losses early Friday with bitcoin set for a record losing streak as the collapse of TerraUSD, a so-called stablecoin, rippled through markets.'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Block swings to quarterly loss as bitcoin boost fades - Reuters.com',
#    'description': 'Block Inc <a href="https://www.reuters.com/companies/SQ.N" target="_blank">(SQ.N)</a>, the payments company led by Jack Dorsey, on Thursday reported a loss for the first quarter as demand for bitcoin softened due to a decline in cryptocurrency prices.',
#    'url': 'https://www.reuters.com/technology/block-swings-quarterly-loss-bitcoin-boost-fades-2022-05-05/',
#    'urlToImage': 'https://www.reuters.com/resizer/BWWUiBev3PUU7DomJJXE2-Iqz30=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/OZ6CVP422VIJ5A6UACI72VHUSY.jpg',
#    'publishedAt': '2022-05-05T20:18:00Z',
#    'content': 'May 5 (Reuters) - Block Inc (SQ.N), the payments company led by Jack Dorsey, on Thursday reported a loss for the first quarter as demand for bitcoin softened due to a decline in cryptocurrency prices… [+635 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Editorial',
#    'title': 'Bitcoin slumps to lowest level since January - Reuters',
#    'description': "05/09 The value of the world's biggest cryptocurrencies have been sliding in line with global markets, in particular the tech-heavy Nasdaq.",
#    'url': 'https://www.reuters.com/video/watch/idsv1V?now=true',
#    'urlToImage': 'https://ajo.prod.reuters.tv/api/v2/img/62791df9e4b085d396fd6c0c-1652104697122?location=LANDSCAPE',
#    'publishedAt': '2022-05-09T14:34:37Z',
#    'content': "Posted \r\n05/09 The value of the world's biggest cryptocurrencies have been sliding in line with global markets, in particular the tech-heavy Nasdaq."},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Bitcoin back below $30000; European regulators renew crypto warnings - Reuters',
#    'description': 'Cryptocurrencies resumed their slide on Monday, giving up the gains they had eked out over the weekend, as regulators continued to circle.',
#    'url': 'https://www.reuters.com/markets/us/bitcoin-back-below-30000-european-regulators-renew-crypto-warnings-2022-05-16/',
#    'urlToImage': 'https://www.reuters.com/resizer/w_UfuRFkdp1SRGWX-3lqEk79I7o=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/DE6HJWA3QZLT3ANRYUBAZSA75M.jpg',
#    'publishedAt': '2022-05-16T09:38:00Z',
#    'content': 'HONG KONG, May 16 (Reuters) - Cryptocurrencies resumed their slide on Monday, giving up the gains they had eked out over the weekend, as regulators continued to circle.\r\nEuropean officials reiterated… [+2143 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Swiss National Bank opposed to holding bitcoin as a reserve currency - Reuters',
#    'description': "The Swiss National Bank is against buying and holding bitcoin as a reserve currency, Chairman Thomas Jordan said at the central bank's annual general meeting on Friday.",
#    'url': 'https://www.reuters.com/business/finance/swiss-national-bank-opposed-holding-bitcoin-reserve-currency-2022-04-29/',
#    'urlToImage': 'https://www.reuters.com/resizer/TekDiFrf7I8nK01TXJycbJalJto=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/K6HZSML74ZJVTMTU7LWUZAYJPA.jpg',
#    'publishedAt': '2022-04-29T11:54:00Z',
#    'content': "ZURICH, April 29 (Reuters) - The Swiss National Bank is against buying and holding bitcoin as a reserve currency, Chairman Thomas Jordan said at the central bank's annual general meeting on Friday.\r\n… [+1882 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Commodity currencies hit by tumbling oil prices, bitcoin near 10-month low - Reuters',
#    'description': 'Falling commodity prices dragged the Australian and Canadian currencies lower on Tuesday, although the dollar was steady against most other majors while bitcoin continued to tumble.',
#    'url': 'https://www.reuters.com/business/commodity-currencies-hit-by-tumbling-oil-prices-bitcoin-near-10-month-low-2022-05-10/',
#    'urlToImage': 'https://www.reuters.com/resizer/0xp08SvjW4W2Y3SxtEZvQQ-RmeQ=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/MXXAWI2YARNANIKZUZS2MDUXGM.jpg',
#    'publishedAt': '2022-05-10T02:37:00Z',
#    'content': 'HONG KONG, May 10 (Reuters) - Falling commodity prices dragged the Australian and Canadian currencies lower on Tuesday, although the dollar was steady against most other majors while bitcoin continue… [+2251 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Editorial',
#    'title': 'The Week in Numbers: bitcoin plunges, Warhol soars - Reuters',
#    'description': "From bitcoin's record losing streak to Warhol's record sale, we round up the big numbers in business and finance over the week to May 13. Olivia Chan reports.",
#    'url': 'https://www.reuters.com/video/watch/idRCV00B1R8',
#    'urlToImage': 'https://static.reuters.com/resources/r/?d=20220513&i=RCV00B1R8&r=RCV00B1R8&t=2',
#    'publishedAt': '2022-05-13T14:25:59Z',
#    'content': "Posted \r\nFrom bitcoin's record losing streak to Warhol's record sale, we round up the big numbers in business and finance over the week to May 13. Olivia Chan reports."},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': None,
#    'title': 'Rappi enters the world of cryptocurrencies by implementing Bitcoin as a payment method',
#    'description': 'Platform users will be able to purchase products and services by paying with Bitcoin.',
#    'url': 'https://www.entrepreneur.com/article/425055',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1650297478-shutterstock-1471332953.jpg',
#    'publishedAt': '2022-04-18T16:42:00Z',
#    'content': 'The technological advancement that surrounds cryptocurrencies evolves rapidly; that is why the platforms day by day look for ways to be present within these emerging universes; which will become dail… [+1755 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Analysis: Crypto crash leaves El Salvador with no easy exit from worsening crisis - Reuters',
#    'description': "El Salvador's big bet on bitcoin, which the Central American nation has been buying since September, has soured in recent weeks as a cryptocurrency rout shaved over a third of the value of the government's holdings, Reuters calculations show.",
#    'url': 'https://www.reuters.com/markets/europe/crypto-crash-leaves-el-salvador-with-no-easy-exit-worsening-crisis-2022-05-19/',
#    'urlToImage': 'https://www.reuters.com/resizer/oDdrMrkNRKCwVAGqmoQ29gdaHcI=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/QDA7HEPP75P3NNYPIW6LUQIZTE.jpg',
#    'publishedAt': '2022-05-19T05:34:00Z',
#    'content': "SAN SALVADOR/NEW YORK, May 19 (Reuters) - El Salvador's big bet on bitcoin, which the Central American nation has been buying since September, has soured in recent weeks as a cryptocurrency rout shav… [+5171 chars]"},
#   {'source': {'id': None, 'name': 'VentureBeat'},
#    'author': 'Fynn Kreuz, Numbrs',
#    'title': 'The technological disruption of bitcoin',
#    'description': 'Bitcoin is an example of how tech could transform the global financial system and represent an alternative to the storage of economic value.',
#    'url': 'https://venturebeat.com/2022/04/20/the-technological-disruption-of-bitcoin/',
#    'urlToImage': 'https://venturebeat.com/wp-content/uploads/2022/04/GettyImages-1321675861-Koron.jpg?w=1200&strip=all',
#    'publishedAt': '2022-04-20T20:07:00Z',
#    'content': 'We are excited to bring Transform 2022 back in-person July 19 and virtually July 20 - 28. Join AI and data leaders for insightful talks and exciting networking opportunities. Register today!\r\nSome te… [+6394 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'FTX chief says Bitcoin has no future as a payments network- FT - Reuters.com',
#    'description': "Cryptocurrency exchange FTX's founder has said that Bitcoin has no future as a payments network and criticized the digital currency for its inefficiency and high environmental costs, the Financial Times reported on Monday.",
#    'url': 'https://www.reuters.com/markets/currencies/ftx-chief-says-bitcoin-has-no-future-payments-network-ft-2022-05-16/',
#    'urlToImage': 'https://www.reuters.com/resizer/wi5YBLbMmVbe6N_0tS8zPRU6cvg=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/VLMVBBYF3JP4BEXCUZEOGSBQKQ.jpg',
#    'publishedAt': '2022-05-16T04:25:00Z',
#    'content': "May 16 (Reuters) - Cryptocurrency exchange FTX's founder has said that Bitcoin has no future as a payments network and criticized the digital currency for its inefficiency and high environmental cost… [+534 chars]"},
#   {'source': {'id': None, 'name': 'CNET'},
#    'author': 'Julian Dossett',
#    'title': 'Bitcoin Slides Below $30,000 Amid Wider Economic Downturn - CNET',
#    'description': 'Soaring inflation is just one driver of broad losses across the crypto markets.',
#    'url': 'https://www.cnet.com/personal-finance/crypto/bitcoin-slides-below-30000-amid-wider-economic-downturn/',
#    'urlToImage': 'https://www.cnet.com/a/img/resize/e736ff3429cf9ce47ad9f25eaed65ddae36428d1/2022/04/26/5616cb3e-89a1-4066-a84e-b288587f5f2f/gettyimages-1346301743.jpg?auto=webp&fit=crop&height=630&width=1200',
#    'publishedAt': '2022-05-10T23:51:45Z',
#    'content': "Cryptocurrency prices are down amid a slew of grim economic news. With potential factors as disparate as the war In Ukraine, rising inflation and the Fed's corresponding interest rate hikes, the pric… [+2914 chars]"},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'EditorDavid',
#    'title': 'Cryptocurrency Markets Drop $200B, Bitcoin Down 50% Since November',
#    'description': '40 days ago Bitcoin sold for $47,454. It\'s price now is $34,007 — a drop of 28%. \nAbout a third of that drop happened this week, as "Bitcoin, ethereum and other major cryptocurrencies have fallen sharply," Forbes reports, "wiping around $200 billion from the …',
#    'url': 'https://news.slashdot.org/story/22/05/09/0026233/cryptocurrency-markets-drop-200b-bitcoin-down-50-since-november',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/bitcoin_64.png',
#    'publishedAt': '2022-05-09T01:34:00Z',
#    'content': '40 days ago Bitcoin sold for $47,454. It\'s price now is $34,007 — a drop of 28%.About a third of that drop happened this week, as "Bitcoin, ethereum and other major cryptocurrencies have fallen sharp… [+975 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'prosen@insider.com (Phil Rosen)',
#    'title': "El Salvador's bitcoin bond reportedly hasn't lured a single investor, and markets are bracing for a default on conventional debt",
#    'description': "El Salvador's conventional bonds due in 2032 yield 24%, according to data from Bloomberg",
#    'url': 'https://markets.businessinsider.com/news/bonds/el-salvador-bitcoin-bonds-investors-crypto-bukele-default-debt-ukraine-2022-5',
#    'urlToImage': 'https://i.insider.com/627126b4facd1e0019fba688?width=1200&format=jpeg',
#    'publishedAt': '2022-05-03T14:18:01Z',
#    'content': "Investors aren't flocking to El Salvador's bitcoin bond, and in fact, the crypto-backed offering hasn't drawn a single buyer, according to Bloomberg.\xa0\r\nMillennial president Nayib Bukele is seeking $1… [+1361 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'avcooper@businessinsider.com (Amanda Cooper)',
#    'title': 'US stock futures bounce back after rout that sent the S&P 500 to 1-year lows, while bitcoin struggles at $30,000',
#    'description': 'Investors are growing increasingly worried about rising inflation and slowing growth, as bitcoin briefly dropped below $30,000.',
#    'url': 'https://markets.businessinsider.com/news/stocks/stocks-us-futures-rally-sp500-hit-year-low-bitcoin-slump-2022-5',
#    'urlToImage': 'https://i.insider.com/627a2fb894a2c10018eeb67b?width=1200&format=jpeg',
#    'publishedAt': '2022-05-10T09:52:37Z',
#    'content': "US stock index futures rallied on Tuesday, suggesting a modest recovery at the open from the previous day's rout that drove the S&amp;P 500 to a one-year low, as investors bought back technology stoc… [+3816 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Bitcoin falls to lowest since January, in line with tumbling stock markets - Reuters',
#    'description': 'Bitcoin fell to its lowest level since January on Monday as slumping equity markets continued to hurt cryptocurrencies, which are currently trading in line with so-called riskier assets like tech stocks.',
#    'url': 'https://www.reuters.com/business/finance/bitcoin-falls-lowest-since-january-line-with-tumbling-stock-markets-2022-05-09/',
#    'urlToImage': 'https://www.reuters.com/resizer/B0qAxA8TjZ596MlWtB1mhDiQ1HM=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/SBR5WIGRUVJBRNZBI6EL6DOKVA.jpg',
#    'publishedAt': '2022-05-09T04:43:00Z',
#    'content': 'HONG KONG, May 9 (Reuters) - Bitcoin fell to its lowest level since January on Monday as slumping equity markets continued to hurt cryptocurrencies, which are currently trading in line with so-called… [+1775 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Madeline Garfinkle',
#    'title': 'Rough Monday For Bitcoin: 5.2% Drop in 24 Hours',
#    'description': 'After its fifth consecutive day of drops, Bitcoin is down more than 50% since its peak in November.',
#    'url': 'https://www.entrepreneur.com/article/427129',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1652111042-GettyImages-1339026234.jpg',
#    'publishedAt': '2022-05-09T15:00:00Z',
#    'content': 'As of Monday\xa0morning, Bitcoin is down to $32,940, a drop that marks a steep fall of more than 50% since its all-time high of $68,990 in November and Bitcoin isnt the only digital currency taking a di… [+1414 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'mfox@businessinsider.com (Matthew Fox)',
#    'title': 'MicroStrategy falls 16% as bitcoin inches closer to its margin call level of $21,000',
#    'description': 'Bitcoin has dropped 18% over the past week, dipping below $33,000, after it was rejected at a key resistance level of $40,000.',
#    'url': 'https://markets.businessinsider.com/news/stocks/microstrategy-stock-price-bitcoin-21000-margin-call-level-crypto-decline-2022-5',
#    'urlToImage': 'https://i.insider.com/62791049a6a880001827fef0?width=1200&format=jpeg',
#    'publishedAt': '2022-05-09T13:54:02Z',
#    'content': 'MicroStrategy fell 16% on Monday to its lowest level since 2020 as the stock price continues to closely track the price of bitcoin and gets closer to its margin call level.\r\nBitcoin has dropped 18% o… [+1899 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Entrepreneur Staff',
#    'title': 'The Senate of Mexico installs its first Bitcoin ATM',
#    'description': 'The installation of the ATM seeks to promote financial education and raise awareness of the need to regulate the use of cryptocurrencies in Mexico.',
#    'url': 'https://www.entrepreneur.com/article/425857',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1651068389-shutterstock-1261474762.jpg',
#    'publishedAt': '2022-04-27T16:28:00Z',
#    'content': 'Yesterday, the forum "Bitcoin: Mexico facing the future" was held in the Senate of the Mexican Republic in order to analyze and trigger the growth of the cryptocurrency market. Organized by Senators … [+1951 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': "Stablecoin Terra's broken dollar peg hits wider crypto markets - Reuters",
#    'description': "TerraUSD, the world's fourth-largest stablecoin, lost a third of its value on Tuesday, spooking cryptocurrency investors and partly contributing to bitcoin's tumble below $30,000 for the first time in 10 months.",
#    'url': 'https://www.reuters.com/business/finance/stablecoin-terras-broken-dollar-peg-hits-wider-crypto-markets-2022-05-10/',
#    'urlToImage': 'https://www.reuters.com/resizer/F-rbHTYtq-04GOCz7vsrCWkvHzU=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/D72GJSYE4BIE5BTVFRVPAEOPWU.jpg',
#    'publishedAt': '2022-05-10T06:21:00Z',
#    'content': "HONG KONG, May 10 (Reuters) - TerraUSD, the world's fourth-largest stablecoin, lost a third of its value on Tuesday, spooking cryptocurrency investors and partly contributing to bitcoin's tumble belo… [+2401 chars]"},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Amanda Breen',
#    'title': "Charlie Munger Slams 'Stupid' and 'Evil' Bitcoin, Says Communist China's Leader Was Right to Ban It",
#    'description': "During Berkshire Hathaway's annual shareholders meeting, Munger and Warren Buffett ripped into the cryptocurrency.",
#    'url': 'https://www.entrepreneur.com/article/426541',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1651505193-GettyImages-1124907098.jpg',
#    'publishedAt': '2022-05-02T15:00:00Z',
#    'content': 'It\'s no secret that Berkshire Hathaway and its owner/CEO Warren Buffett aren\'t ardent backers of Bitcoin; just a few years ago, the billionaire investor referred to the cryptocurrency as "rat poison … [+2346 chars]'},
#   {'source': {'id': None, 'name': 'Bitcoin.com'},
#    'author': None,
#    'title': 'Elon Musk Secures Funding From Crypto-Friendly Binance, Sequoia, Fidelity to Buy Twitter – Featured Bitcoin News - Bitcoin News',
#    'description': '<ol><li>Elon Musk Secures Funding From Crypto-Friendly Binance, Sequoia, Fidelity to Buy Twitter – Featured Bitcoin News\xa0\xa0Bitcoin News\r\n</li><li>Elon Musk to lead Twitter temporarily after $44 billion takeover, says report | World Business Watch\xa0\xa0WION\r\n</li><…',
#    'url': 'https://news.bitcoin.com/elon-musk-secures-funding-from-crypto-friendly-binance-sequoia-fidelity-to-buy-twitter/',
#    'urlToImage': 'https://static.news.bitcoin.com/wp-content/uploads/2022/05/elon-musk-twitter.jpg',
#    'publishedAt': '2022-05-06T00:38:11Z',
#    'content': 'Tesla and Spacex CEO Elon Musk has secured $7.139 billion in new financing commitments to fund his acquisition of Twitter, including from several pro-crypto companies. Cryptocurrency exchange Binance… [+3452 chars]'},
#   {'source': {'id': 'time', 'name': 'Time'},
#    'author': None,
#    'title': 'Ethereum and Bitcoin Prices Are Tanking. Here’s Why One Expert Thinks Bitcoin Could Drop Even Lower - NextAdvisor',
#    'description': '<ol><li>Ethereum and Bitcoin Prices Are Tanking. Here’s Why One Expert Thinks Bitcoin Could Drop Even Lower\xa0\xa0NextAdvisor\r\n</li><li>Does the cryptocurrency crash pose a threat to the financial system?\xa0\xa0Financial Post\r\n</li><li>Going ‘To Zero’—Panic Is Sweeping…',
#    'url': 'https://time.com/nextadvisor/investing/cryptocurrency/cryptocurrency-btc-eth-price-falling/',
#    'urlToImage': 'https://time.com/nextadvisor/wp-content/uploads/2022/05/daily-crypto-update-4-9-1000x630.jpg',
#    'publishedAt': '2022-05-09T16:44:18Z',
#    'content': 'Editorial IndependenceWe want to help you make more informed decisions. Some links on this page clearly marked may take you to a partner website and may result in us earning a referral commission. Fo… [+6022 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': "Bitcoin eyes record losing streak as 'stablecoin' collapse crushes crypto - Reuters",
#    'description': 'Cryptocurrencies nursed large losses on Friday, with bitcoin pinned below $30,000 and set for a record losing streak as the collapse of TerraUSD, a so-called stablecoin, rippled through markets.',
#    'url': 'https://www.reuters.com/markets/europe/bitcoin-eyes-record-losing-streak-stablecoin-collapse-crushes-crypto-2022-05-13/',
#    'urlToImage': 'https://www.reuters.com/resizer/wqC8arXi4KlPfpjS3PlXL9N9z3Q=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/TLRRMFTHJ5J7RM36TEYY3EQYEA.jpg',
#    'publishedAt': '2022-05-13T03:39:00Z',
#    'content': 'SINGAPORE, May 13 (Reuters) - Cryptocurrencies nursed large losses on Friday, with bitcoin pinned below $30,000 and set for a record losing streak as the collapse of TerraUSD, a so-called stablecoin,… [+3439 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Crypto collapse intensifies as stablecoin Tether slides below dollar peg - Reuters.com',
#    'description': "The meltdown in TerraUSD, one of the world's largest stablecoins, rippled through cryptocurrency markets on Thursday, pushing another major stablecoin Tether below its dollar peg and sending bitcoin to 16-month lows.",
#    'url': 'https://www.reuters.com/markets/us/crypto-collapse-intensifies-stablecoin-tether-slides-below-dollar-peg-2022-05-12/',
#    'urlToImage': 'https://www.reuters.com/pf/resources/images/reuters/reuters-default.png?d=94',
#    'publishedAt': '2022-05-12T20:10:00Z',
#    'content': "LONDON/NEW YORK, May 12 (Reuters) - The meltdown in TerraUSD, one of the world's largest stablecoins, rippled through cryptocurrency markets on Thursday, pushing another major stablecoin Tether below… [+4847 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Editorial',
#    'title': "Crypto 'too small' to damage broader market - Reuters.com",
#    'description': 'As cryptocurrency investors are spooked by crashes in bitcoin and stablecoins, Charley Cooper, Managing Director of R3, says the sector is still too small to make a significant impact on traditional markets.',
#    'url': 'https://www.reuters.com/video/watch/idOV747012052022RP1',
#    'urlToImage': 'https://static.reuters.com/resources/r/?d=20220512&i=OV747012052022RP1&r=OV747012052022RP1&t=2',
#    'publishedAt': '2022-05-12T09:07:48Z',
#    'content': 'Posted \r\nAs cryptocurrency investors are spooked by crashes in bitcoin and stablecoins, Charley Cooper, Managing Director of R3, says the sector is still too small to make a significant impact on tra… [+16 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Central African bank regulator reminds states of crypto ban - Reuters',
#    'description': "Central Africa's regional banking regulator sent out a reminder on Friday about its ban on the use of cryptocurrencies, weeks after the Central African Republic, a member state, made bitcoin legal tender.",
#    'url': 'https://www.reuters.com/world/africa/central-african-bank-regulator-reminds-states-crypto-ban-2022-05-13/',
#    'urlToImage': 'https://www.reuters.com/resizer/vhLxHmngyO-Awrv6W0REjw4g980=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/ADHRTIBRO5LVXGAYXCRVNLCX24.jpg',
#    'publishedAt': '2022-05-13T17:40:00Z',
#    'content': "N'DJAMENA, May 13 (Reuters) - Central Africa's regional banking regulator sent out a reminder on Friday about its ban on the use of cryptocurrencies, weeks after the Central African Republic, a membe… [+1872 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Gucci jumps on the crypto bandwagon with U.S. project - Reuters.com',
#    'description': "Gucci's high-end handbags and other luxury products can now be bought using cryptocurrencies, including bitcoin, in some U.S. stores, the Italian company said, as digital currencies move to broader acceptance.",
#    'url': 'https://www.reuters.com/business/retail-consumer/gucci-jumps-crypto-bandwagon-with-us-project-2022-05-05/',
#    'urlToImage': 'https://www.reuters.com/resizer/aLPEIt4kysCMpwdBeNLdWl6_YxU=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/353HRRTJVVKDLIMZK5Y3V2JP3I.jpg',
#    'publishedAt': '2022-05-05T08:26:00Z',
#    'content': "May 5 (Reuters) - Gucci's high-end handbags and other luxury products can now be bought using cryptocurrencies, including bitcoin, in some U.S. stores, the Italian company said, as digital currencies… [+1161 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': "Bitcoin's African outpost raises several red flags - Reuters",
#    'description': 'Bitcoin’s latest fans are about as far as you can get from Silicon Valley crypto bros. War-torn Central African Republic (CAR) on Wednesday adopted the digital currency as legal tender <a href="/world/africa/central-african-republic-adopts-bitcoin-an-official…',
#    'url': 'https://www.reuters.com/world/africa/bitcoins-african-outpost-raises-several-red-flags-2022-05-03/',
#    'urlToImage': 'https://www.reuters.com/resizer/QmgPzsTbb3ksaGQqxcXEzTq294A=/728x381/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/BLOPVBCVWBK6JKVHF2LQC4XFKY.jpg',
#    'publishedAt': '2022-05-03T11:28:00Z',
#    'content': 'LONDON, May 2 (Reuters Breakingviews) - Bitcoins latest fans are about as far as you can get from Silicon Valley crypto bros. War-torn Central African Republic (CAR) on Wednesday adopted the digital … [+3464 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': "Breakingviews - Goldman's financial alchemy extends to crypto too - Reuters.com",
#    'description': 'Trust Goldman Sachs <a href="https://www.reuters.com/companies/GS.N" target="_blank">(GS.N)</a> to find an angle for investment banks in the cryptocurrency sector. David Solomon’s $100 billion group made a bitcoin-backed loan to $27 billion exchange Coinbase …',
#    'url': 'https://www.reuters.com/breakingviews/goldmans-financial-alchemy-extends-crypto-too-2022-05-04/',
#    'urlToImage': 'https://www.reuters.com/resizer/1RLBKXa7PoGKcv722niq_QAZQ08=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/YXYSDJG4DVJDVF3Y6VT4XZ6FMA.jpg',
#    'publishedAt': '2022-05-04T11:16:00Z',
#    'content': 'LONDON, May 4 (Reuters Breakingviews) - Trust Goldman Sachs (GS.N) to find an angle for investment banks in the cryptocurrency sector. David Solomons $100 billion group made a bitcoin-backed loan to … [+3002 chars]'},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'Matt Ott',
#    'title': 'Bitcoin tumbles, a stablecoin plunges in wild week in crypto - The Associated Press - en Español',
#    'description': '<ol><li>Bitcoin tumbles, a stablecoin plunges in wild week in crypto\xa0\xa0The Associated Press - en Español\r\n</li><li>Bitcoin Tumbles In Wild Week For Cryptocurrency\xa0\xa0HuffPost\r\n</li><li>Bitcoin rebounds to $30000, LUNA crashes to $0 and Elon Musk pauses Twitter d…',
#    'url': 'https://apnews.com/article/technology-bitcoin-prices-inflation-4b2d3670a79a0e9ea295974f88767cfe',
#    'urlToImage': 'https://storage.googleapis.com/afs-prod/media/c3ba43297ba34c58a6c7f1dbbb478eb3/3000.jpeg',
# ...
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Small players lose faith in crypto after sell-off - Reuters.com',
#    'description': 'Nofe Isah, a 25-year old based in Nigeria, has been investing in crypto since January. Last week, she lost all of her $5,000 in savings as cryptocurrency luna went into free fall.',
#    'url': 'https://www.reuters.com/markets/europe/small-players-lose-faith-crypto-after-sell-off-2022-05-17/',
#    'urlToImage': 'https://www.reuters.com/resizer/6U8A_9TLEefvl0p1lDql8g2sMD4=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/3OL24TUV5JL5XGOPKVWKS7JCI4.jpg',
#    'publishedAt': '2022-05-17T11:36:00Z',
#    'content': 'WASHINGTON/MUMBAI, May 17 (Reuters) - Nofe Isah, a 25-year old based in Nigeria, has been investing in crypto since January. Last week, she lost all of her $5,000 in savings as cryptocurrency luna we… [+5652 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Coinbase is conjoined to crypto - Reuters',
#    'description': 'Coinbase Global <a href="https://www.reuters.com/companies/COIN.O" target="_blank">(COIN.O)</a> went for a ride when digital collectibles like Bitcoin soared. The excitement meant more customers, rising trading volumes and rocketing fees. Last year’s revenue …',
#    'url': 'https://www.reuters.com/breakingviews/coinbase-is-conjoined-crypto-2022-05-11/',
#    'urlToImage': 'https://www.reuters.com/resizer/bCqaEgNN3wAahdG6wS4NZ38B2CI=/728x381/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/JBCJGBY24FPTFLDV7LMOTJ5THQ.jpg',
#    'publishedAt': '2022-05-11T19:01:00Z',
#    'content': 'NEW YORK, May 11 (Reuters Breakingviews) - Coinbase Global (COIN.O) went for a ride when digital collectibles like Bitcoin soared. The excitement meant more customers, rising trading volumes and rock… [+1726 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Breakingviews - Crypto moves herald era of the blockchain buyout - Reuters',
#    'description': 'Private equity groups have sat on the sidelines of the crypto boom, which has seen the value of bitcoin and ether rally by 400% and 1,400% over the past two years. An EY survey found that <a href="https://www.ey.com/en_gl/private-equity/will-seeing-what-lies-…',
#    'url': 'https://www.reuters.com/breakingviews/crypto-moves-herald-era-blockchain-buyout-2022-04-29/',
#    'urlToImage': 'https://www.reuters.com/resizer/JV9_2z7D2Ppeuej6tQZPYYnu69M=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/YLIKWS7CWVKU5APZEJUFPV3R2U.jpg',
#    'publishedAt': '2022-04-29T10:35:00Z',
#    'content': 'LONDON, April 29 (Reuters Breakingviews) - Private equity groups have sat on the sidelines of the crypto boom, which has seen the value of bitcoin and ether rally by 400% and 1,400% over the past two… [+1842 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Global crypto regulation body likely in next year, top official says - Reuters.com',
#    'description': 'Global market regulators are likely to launch a joint body within the next year to better co-ordinate cryptocurrency rules, a senior watchdog official has said.',
#    'url': 'https://www.reuters.com/markets/currencies/global-crypto-regulation-body-likely-next-year-top-official-says-2022-05-12/',
#    'urlToImage': 'https://www.reuters.com/resizer/w_UfuRFkdp1SRGWX-3lqEk79I7o=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/DE6HJWA3QZLT3ANRYUBAZSA75M.jpg',
#    'publishedAt': '2022-05-12T11:04:00Z',
#    'content': 'LONDON/HONG KONG, May 12 (Reuters) - Global market regulators are likely to launch a joint body within the next year to better co-ordinate cryptocurrency rules, a senior watchdog official has said.\r\n… [+1786 chars]'},
#   {'source': {'id': None, 'name': 'Kitco NEWS'},
#    'author': 'http://www.facebook.com/kitconews',
#    'title': "A 'short attack' caused UST de-peg, Luna's 97% price collapse, so who was responsible? - Kitco NEWS",
#    'description': "A 'short attack' caused UST de-peg, Luna's 97% price collapse, so who was responsible?\xa0\xa0Kitco NEWS",
#    'url': 'https://www.kitco.com/news/2022-05-12/A-short-attack-caused-UST-de-peg-Luna-s-97-price-collapse-so-who-was-responsible.html',
#    'urlToImage': 'https://www.kitco.com/news/2022-05-12/images/Ronald-AngSiy.jpg',
#    'publishedAt': '2022-05-12T15:04:00Z',
#    'content': "(Kitco News) - A short attack triggered Terra's LUNA to crash more than 97 percent over the past few days. This caused a corresponding fall in the price of UST, which fell to 2 cents early Thursday. … [+3213 chars]"},
#   {'source': {'id': None, 'name': 'CNET'},
#    'author': 'Daniel Van Boom',
#    'title': 'Luna Cryptocurrency Collapse: How UST Broke and Why It Matters - CNET',
#    'description': "Last week a Luna coin was worth $85. Now it's worth a cent. Here's why that matters.",
#    'url': 'https://www.cnet.com/personal-finance/crypto/luna-cryptocurrency-collapse-how-ust-broke-and-why-it-matters/',
#    'urlToImage': 'https://www.cnet.com/a/img/resize/95140bf2d56c706fab2efd5002e57d9f9dfa71ba/2022/05/12/f724b568-16a0-4a74-a9c1-ccf78a83e176/gettyimages-1240622075.jpg?auto=webp&fit=crop&height=630&width=1200',
#    'publishedAt': '2022-05-12T23:58:36Z',
#    'content': "The cryptocurrency market isn't pretty right now. Look anywhere and you'll see red: bitcoin and ether are both down over 30% week-on-week, hitting lows not seen since 2020, and altcoins like solana, … [+8299 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Canadian dollar to stay at core of financial system, not crypto -BoC - Reuters',
#    'description': "The Canadian dollar will remain at the center of the country's financial system, the central bank chief said on Monday, responding to questions about a Conservative leadership candidate's pledge to make the country the blockchain capital of the world.",
#    'url': 'https://www.reuters.com/business/finance/canadian-dollar-stay-core-financial-system-not-crypto-boc-2022-04-25/',
#    'urlToImage': 'https://www.reuters.com/resizer/YPL5pBziOvnp6VVSMZmELK0L5Cw=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/Z2ECRC6ATNM33KWEIWFRUKTNNQ.jpg',
#    'publishedAt': '2022-04-25T19:37:00Z',
#    'content': "OTTAWA, April 25 (Reuters) - The Canadian dollar will remain at the center of the country's financial system, the central bank chief said on Monday, responding to questions about a Conservative leade… [+2728 chars]"},
#   {'source': {'id': None, 'name': 'Sigarch.org'},
#    'author': None,
#    'title': 'Drop Whatever You’re Researching and Start Working on Crypto',
#    'description': 'INTEL LAUNCHES NEW BITCOIN MINING CHIP, BLOCKSCALE Intel’s new bitcoin mining chip, the Intel Blockscale ASIC, will ship in Q3 2022 to select customers. (Bitcoin Magazine, April 2022) STOP! Before …',
#    'url': 'https://www.sigarch.org/drop-whatever-youre-researching-and-start-working-on-crypto/',
#    'urlToImage': 'https://www.sigarch.org/wp-content/uploads/2022/05/AdobeStock_337896792-scaled.jpeg',
#    'publishedAt': '2022-05-10T17:26:11Z',
#    'content': 'INTEL LAUNCHES NEW BITCOIN MINING CHIP, BLOCKSCALEIntels new bitcoin mining chip, the Intel Blockscale ASIC, will ship in Q3 2022 to select customers. (Bitcoin Magazine, April 2022)\r\nSTOP! Before you… [+5740 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'mfox@businessinsider.com (Matthew Fox)',
#    'title': 'Dow Jones plunges nearly 1,000 points and notches the fourth-straight losing week lower as investors brace for swift interest rate hikes from the Fed',
#    'description': 'For the week, the Dow finished down 1.85%, the S&P 500 tumbled 2.7%, and the Nasdaq crashed 3.8%.',
#    'url': 'https://markets.businessinsider.com/news/stocks/stock-market-news-today-dow-plunges-1000-points-losing-week-2022-4',
#    'urlToImage': 'https://i.insider.com/6262f8999f65660019064bd8?width=1200&format=jpeg',
#    'publishedAt': '2022-04-22T20:09:26Z',
#    'content': 'US stocks plunged on Friday, with the Dow Jones falling nearly 1,000 points as investors grappled with new comments from Fed Chair Jerome Powell that indicate bigger interest rate hikes ahead.\r\n"I wo… [+2451 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'insider@insider.com (Adriana Nunez)',
#    'title': "Block delivers strong Q1, hails Cash App's growth potential",
#    'description': 'Increased adoption of the Cash App card and direct deposits fueled growth for the peer-to-peer (P2P) payments app.',
#    'url': 'https://www.businessinsider.com/block-gross-payment-volume-surges-in-q1-2022-5',
#    'urlToImage': 'https://i.insider.com/6279257d94a2c10018ee8f99?width=1200&format=jpeg',
#    'publishedAt': '2022-05-09T14:30:47Z',
#    'content': "By the numbers:\xa0Block's gross payment volume (GPV) surged 31%\xa0year over year (YoY) in Q1, hitting $43.5 billion,\xa0per\xa0its shareholder letter. GPV growth accelerated slightly from the same period\xa0last … [+2693 chars]"},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Alex Hern and Dan Milmo',
#    'title': 'Q&A: the collapse of terra and what it could mean beyond crypto',
#    'description': 'After the crash of the ‘stablecoin’ sparked panic, could the collapse of the wider crypto market lead to a more permanent economic crunch?<ul><li>$7.6bn of ‘stablecoin’ tether redeemed since start of crypto crisis</li></ul>The collapse of a multibillion-dolla…',
#    'url': 'https://amp.theguardian.com/technology/2022/may/16/qa-the-collapse-of-terra-and-what-it-could-mean-beyond-crypto',
#    'urlToImage': 'https://i.guim.co.uk/img/media/b36d7e0600834b5d01906d337db38d4d5ead204c/0_86_3500_2100/master/3500.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=7d70ff8a9fbe0a7478aa6e83d87d21b1',
#    'publishedAt': '2022-05-16T17:09:20Z',
#    'content': 'The collapse of a multibillion-dollar cryptocurrency called terra has sparked a wave of fear, uncertainty and doubt across the sector, leading some, like Coinbases chief executive, Brian Armstrong, t… [+6694 chars]'},
#   {'source': {'id': 'time', 'name': 'Time'},
#    'author': 'Stan Choe / AP',
#    'title': 'Fidelity Will Let Workers Put Some of Their 401(K) Savings Directly Into Bitcoin',
#    'description': 'Retirement giant Fidelity said Tuesday that it’s launched a way for workers to put some of their 401(k) savings and contributions directly in bitcoin',
#    'url': 'https://time.com/6170756/fidelity-retirement-bitcoin/',
#    'urlToImage': 'https://api.time.com/wp-content/uploads/2022/04/fidelity-retirement-bitcoin.jpg?quality=85&w=1200&h=628&crop=1',
#    'publishedAt': '2022-04-26T15:53:23Z',
#    'content': 'NEW YORK — More workers may soon be able to stake some of their 401(k) retirement savings to bitcoin, as cryptocurrencies crack even deeper into the mainstream.\r\nRetirement giant Fidelity said Tuesda… [+4255 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'tmohamed@businessinsider.com (Theron Mohamed)',
#    'title': "Warren Buffett and Charlie Munger trashed bitcoin, rang the inflation alarm, and revealed new Apple and Activision Blizzard purchases. Here are 12 key takeaways from Berkshire Hathaway's annual meeting.",
#    'description': 'Buffett and Munger also called out stock-market gamblers, teased overseas buys, and warned passive investors like BlackRock have grown too powerful.',
#    'url': 'https://markets.businessinsider.com/news/stocks/warren-buffett-charlie-munger-bitcoin-inflation-apple-activision-berkshire-meeting-2022-5',
#    'urlToImage': 'https://i.insider.com/627001e50983640018c0ae73?width=1200&format=jpeg',
#    'publishedAt': '2022-05-02T16:54:07Z',
#    'content': "Warren Buffett and Charlie Munger revealed they bought more Apple and Activision Blizzard stock last quarter, dismissed bitcoin as worthless, and rang the inflation alarm during Berkshire Hathaway's … [+7139 chars]"},
#   {'source': {'id': None, 'name': 'ReadWrite'},
#    'author': 'Brad Anderson',
#    'title': 'The Top 12 Blockchain Speakers for 2022',
#    'description': 'What’s happening in the blockchain industry this year? How will Bitcoin react to the return of inflation? What can cryptocurrencies offer banking? And what is the future for NFTs and the Metaverse? All these questions — and more — will determine the future of…',
#    'url': 'https://readwrite.com/top-blockchain-speakers-for-2022/',
#    'urlToImage': 'https://images.readwrite.com/wp-content/uploads/2022/04/2022-03-16-20_45_58-4573.jpg',
#    'publishedAt': '2022-04-26T18:00:42Z',
#    'content': 'Whats happening in the blockchain industry this year? How will Bitcoin react to the return of inflation? What can cryptocurrencies offer banking? And what is the future for NFTs and the Metaverse?\r\nA… [+5681 chars]'},
#   {'source': {'id': None, 'name': 'ReadWrite'},
#    'author': 'Joel Comm',
#    'title': 'The Top 12 Blockchain Speakers for 2022',
#    'description': 'What’s happening in the blockchain industry this year? How will Bitcoin react to the return of inflation? What can cryptocurrencies offer banking? And what is the future for NFTs and the Metaverse? All these questions — and more — will determine the future of…',
#    'url': 'https://readwrite.com/the-top-12-blockchain-speakers-for-2022/',
#    'urlToImage': 'https://images.readwrite.com/wp-content/uploads/2022/04/2022-03-16-20_45_58-4573.jpg',
#    'publishedAt': '2022-04-26T18:00:42Z',
#    'content': 'Whats happening in the blockchain industry this year? How will Bitcoin react to the return of inflation? What can cryptocurrencies offer banking? And what is the future for NFTs and the Metaverse?\r\nA… [+5681 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'TGIF - is it over yet? - Reuters',
#    'description': 'A look at the day ahead in markets from Dhara Ranasinghe.',
#    'url': 'https://www.reuters.com/markets/europe/tgif-is-it-over-yet-2022-05-13/',
#    'urlToImage': 'https://www.reuters.com/resizer/KaGvaYHqR0biueDKZADLS2QqHHc=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/RITR5QSEH5OUNFCY7OVLP3ARVI.jpg',
#    'publishedAt': '2022-05-13T07:02:00Z',
#    'content': 'A look at the day ahead in markets from Dhara Ranasinghe.\r\nAfter a wild ride, markets are in a calmer mood for now. Yet, it is Friday 13 and those prone to superstition would be forgiven for being ex… [+2585 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Cuba approves cryptocurrency services, requires central bank license - Reuters',
#    'description': 'The Cuban central bank issued regulations on Tuesday for virtual asset service providers, after giving a nod last year to the personal use of cryptocurrencies, a move some experts said could help the Communist-run Caribbean island skirt stiff U.S. sanctions.',
#    'url': 'https://www.reuters.com/world/americas/cuba-approves-cryptocurrency-services-requires-central-bank-license-2022-04-27/',
#    'urlToImage': 'https://www.reuters.com/resizer/sBWUvemJW0ryqtlCm2qpRiwhcus=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/XW2TXYEQFZNPVKYUBO65KACFFU.jpg',
#    'publishedAt': '2022-04-27T19:27:00Z',
#    'content': 'HAVANA, April 27 (Reuters) - The Cuban central bank issued regulations on Tuesday for virtual asset service providers, after giving a nod last year to the personal use of cryptocurrencies, a move som… [+2231 chars]'}]}

# %%
# Fetch the Ethereum news articles
eth_articles = newsapi.get_everything(
    q="ethereum",
    language="en",
    page_size=100, 
    sort_by="relevancy"
)

eth_articles
# Out:
# {'status': 'ok',
#  'totalResults': 4871,
#  'articles': [{'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Jon Fingas',
#    'title': "Here's what NFTs look like on Instagram",
#    'description': "Meta has revealed more of how NFTs will work on Instagram. In the US-based test, you can show what you've bought or created for free by connecting your Instagram account to a compatible digital wallet and posting for the world to see. If you like, the social …",
#    'url': 'https://www.engadget.com/instagram-nft-details-131020868.html',
#    'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2022-05/2546c160-d05e-11ec-b75e-e45eaa8c5b2b',
#    'publishedAt': '2022-05-10T13:10:20Z',
#    'content': "Meta has revealed more of how NFTs will work on Instagram. In the US-based test, you can show what you've bought or created for free by connecting your Instagram account to a compatible digital walle… [+1223 chars]"},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Alex Hern',
#    'title': 'Yuga Labs apologises after sale of virtual land crashes Ethereum',
#    'description': 'Demand for plots of land in multiplayer game Otherside was so high it overwhelmed the Ethereum blockchainA multi-billion dollar cryptocurrency company has apologised to users after its sale of “metaverse land” sparked a frenzy that temporarily brought down th…',
#    'url': 'https://amp.theguardian.com/technology/2022/may/02/yuga-labs-apologises-after-sale-of-virtual-land-crashes-ethereum',
#    'urlToImage': 'https://i.guim.co.uk/img/media/e6382b02449503a6456ab870dbc394d5752212ad/0_117_3500_2101/master/3500.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=c33681237b4c480f24dfa73e196af8af',
#    'publishedAt': '2022-05-02T15:54:35Z',
#    'content': 'A multi-billion dollar cryptocurrency company has apologised to users after its sale of metaverse land sparked a frenzy that temporarily brought down the Ethereum cryptocurrency.\r\nYuga Labs, the comp… [+3475 chars]'},
#   {'source': {'id': None, 'name': 'CNET'},
#    'author': 'Daniel Van Boom',
#    'title': 'How Bored Ape Yacht Club Broke Ethereum - CNET',
#    'description': 'Transactions stalled for hours, and people paid thousands in fees whether their purchase succeeded or not.',
#    'url': 'https://www.cnet.com/personal-finance/crypto/how-bored-ape-yacht-club-broke-ethereum/',
#    'urlToImage': 'https://www.cnet.com/a/img/resize/ec8610207cf749f84654799866cb67699ac91a6d/2022/05/01/9c9ba1e1-519b-4e61-a12a-f3faa5d2f1a0/otherside-launch-image-rc1.jpg?auto=webp&fit=crop&height=630&width=1200',
#    'publishedAt': '2022-05-04T02:32:00Z',
#    'content': 'When Bored Ape Yacht Club creators Yuga Labs announced its Otherside NFT collection would launch on April 30, it was predicted by many to be the biggest NFT launch ever. Otherside is an upcoming Bore… [+6669 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': "Cryptoverse: Ether prepares for epic 'merge' in quest to eclipse bitcoin - Reuters.com",
#    'description': "Ether has promised to do better. It has promised to go to the next level, edging out crypto rivals and even outshining the godfather, bitcoin. But the clock's ticking.",
#    'url': 'https://www.reuters.com/business/cryptoverse-ether-prepares-epic-merge-quest-eclipse-bitcoin-2022-04-26/',
#    'urlToImage': 'https://www.reuters.com/resizer/Xpd4XRkm7eEYPo9_LKBQhpcDyBo=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/PKJQY4TBEVMRZNVN3OPZ7XHXLY.jpg',
#    'publishedAt': '2022-04-26T05:15:00Z',
#    'content': "April 26 (Reuters) - Ether has promised to do better. It has promised to go to the next level, edging out crypto rivals and even outshining the godfather, bitcoin. But the clock's ticking.\r\nThe No.2 … [+4092 chars]"},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Thomas Macaulay',
#    'title': 'What is the Ethereum merge and how could it make crypto greener?',
#    'description': 'Ethereum is preparing for an upgrade that’s been described as “the single most important event in crypto history.” The transition would overhaul the infrastructure of the world’s second-largest blockchain. Analysts predict the changes could cut the network’s …',
#    'url': 'https://thenextweb.com/news/what-is-ethereum-merge-when-will-it-happen-how-will-it-make-crypto-greener',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2022%2F04%2FUntitled-design-2-5.jpg&signature=616dbebe0be728ef3c201fb0415eaee8',
#    'publishedAt': '2022-04-26T20:45:44Z',
#    'content': 'Ethereum is preparing for an upgrade thats been described as the single most important event in crypto history.\r\nThe transition would overhaul the infrastructure of the worlds second-largest blockcha… [+2824 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Kevin Hurler',
#    'title': 'You Can Now Go See Fantastic Beasts With Dogecoin at AMC Theaters',
#    'description': 'Dogecoiners unite! Movie theater chain AMC has welcomed some more cryptocurrencies as payment options for online and mobile purchases. In a tweet on April 15, AMC CEO Adam Aron announced that moviegoers can now pay for movie tickets and concessions using Doge…',
#    'url': 'https://gizmodo.com/you-can-now-go-see-fantastic-beasts-with-dogecoin-at-am-1848805758',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/9c1a5c315585258a257319589a2c2bf5.jpg',
#    'publishedAt': '2022-04-18T20:30:00Z',
#    'content': 'Dogecoiners unite! Movie theater chain AMC has welcomed some more cryptocurrencies as payment options for online and mobile purchases. In a tweet on April 15, AMC CEO Adam Aron announced that moviego… [+1603 chars]'},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'EditorDavid',
#    'title': "Sale of Bored Apes' Metaverse Land Made Gas Fees Skyrocket Past $3,000",
#    'description': 'There\'s a new metaverse project from the creators of the "Bored Apes Yacht Club" NFTs. Last night they held a "virtual land" sale, reports Bloomberg, raising nearly a third of a billion dollars. \nAt about the same time, Mashable :\n\nIf you were trying to compl…',
#    'url': 'https://tech.slashdot.org/story/22/05/01/2256252/sale-of-bored-apes-metaverse-land-made-gas-fees-skyrocket-past-3000',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/social_64.png',
#    'publishedAt': '2022-05-01T22:59:00Z',
#    'content': 'There\'s a new metaverse project from the creators of the "Bored Apes Yacht Club" NFTs. Last night they held a "virtual land" sale, reports Bloomberg, raising nearly a third of a billion dollars.At ab… [+2023 chars]'},
#   {'source': {'id': 'time', 'name': 'Time'},
#    'author': None,
#    'title': 'Ethereum and Bitcoin Prices Are Tanking. Here’s Why One Expert Thinks Bitcoin Could Drop Even Lower - NextAdvisor',
#    'description': '<ol><li>Ethereum and Bitcoin Prices Are Tanking. Here’s Why One Expert Thinks Bitcoin Could Drop Even Lower\xa0\xa0NextAdvisor\r\n</li><li>Does the cryptocurrency crash pose a threat to the financial system?\xa0\xa0Financial Post\r\n</li><li>Going ‘To Zero’—Panic Is Sweeping…',
#    'url': 'https://time.com/nextadvisor/investing/cryptocurrency/cryptocurrency-btc-eth-price-falling/',
#    'urlToImage': 'https://time.com/nextadvisor/wp-content/uploads/2022/05/daily-crypto-update-4-9-1000x630.jpg',
#    'publishedAt': '2022-05-09T16:44:18Z',
#    'content': 'Editorial IndependenceWe want to help you make more informed decisions. Some links on this page clearly marked may take you to a partner website and may result in us earning a referral commission. Fo… [+6022 chars]'},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'EditorDavid',
#    'title': 'Cryptocurrency Markets Drop $200B, Bitcoin Down 50% Since November',
#    'description': '40 days ago Bitcoin sold for $47,454. It\'s price now is $34,007 — a drop of 28%. \nAbout a third of that drop happened this week, as "Bitcoin, ethereum and other major cryptocurrencies have fallen sharply," Forbes reports, "wiping around $200 billion from the …',
#    'url': 'https://news.slashdot.org/story/22/05/09/0026233/cryptocurrency-markets-drop-200b-bitcoin-down-50-since-november',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/bitcoin_64.png',
#    'publishedAt': '2022-05-09T01:34:00Z',
#    'content': '40 days ago Bitcoin sold for $47,454. It\'s price now is $34,007 — a drop of 28%.About a third of that drop happened this week, as "Bitcoin, ethereum and other major cryptocurrencies have fallen sharp… [+975 chars]'},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'EditorDavid',
#    'title': "Report: 'Nvidia's LHR Limiter Has Fallen, But Gamers Shouldn't Worry'",
#    'description': 'Slashdot reader Hmmmmmm shared this report from Hot Hardware:\n\nWhen Nvidia launched its Ampere Lite Hash Rate (LHR) graphics card with the feared Ethereum anti-mining limiter, the world knew it was only a matter of time before someone or a team cracked it. Ni…',
#    'url': 'https://tech.slashdot.org/story/22/05/15/190252/report-nvidias-lhr-limiter-has-fallen-but-gamers-shouldnt-worry',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/graphics_64.png',
#    'publishedAt': '2022-05-15T19:39:00Z',
#    'content': 'When Nvidia launched its Ampere Lite Hash Rate (LHR) graphics card with the feared Ethereum anti-mining limiter, the world knew it was only a matter of time before someone or a team cracked it. NiceH… [+1230 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Bitcoin last up 5.7% at $39862.84 - Reuters.com',
#    'description': 'Bitcoin rose 5.7% to $39,862.84, on Wednesday, adding $2,102.94 to its previous close.',
#    'url': 'https://www.reuters.com/business/bitcoin-last-up-57-3986284-2022-05-04/',
#    'urlToImage': 'https://www.reuters.com/resizer/BWWUiBev3PUU7DomJJXE2-Iqz30=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/OZ6CVP422VIJ5A6UACI72VHUSY.jpg',
#    'publishedAt': '2022-05-04T20:16:00Z',
#    'content': "May 4 (Reuters) - Bitcoin rose 5.7% to $39,862.84, on Wednesday, adding $2,102.94 to its previous close.\r\nBitcoin, the world's biggest and best-known cryptocurrency, is up 20.9% from the year's low o… [+337 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Bitcoin last down 5.1% at $38391.36 - Reuters.com',
#    'description': 'Bitcoin dropped 5.1% to $38,391.36 on Tuesday, down $2,229.82 from its previous close.',
#    'url': 'https://www.reuters.com/technology/bitcoin-last-down-51-3839136-2022-04-26/',
#    'urlToImage': 'https://www.reuters.com/resizer/Gp-bLvBDv3-2g6-hsKYIWV0KicU=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/BT3DV4I6BJNQBL3JI4HWYNGSYQ.jpg',
#    'publishedAt': '2022-04-26T20:22:00Z',
#    'content': "April 26 (Reuters) - Bitcoin dropped 5.1% to $38,391.36 on Tuesday, down $2,229.82 from its previous close.\r\nBitcoin, the world's biggest and best-known cryptocurrency, is up 16% from the year's low … [+339 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Bitcoin falls 7.2% to $28758 - Reuters.com',
#    'description': 'Bitcoin fell 7.23% to $28,758.29 at 22:05 GMT on Wednesday, losing $2,241.68 from its previous close.',
#    'url': 'https://www.reuters.com/business/bitcoin-falls-72-28758-2022-05-11/',
#    'urlToImage': 'https://www.reuters.com/resizer/lEay-or8c9TPjZOEmIjrJf3ylQk=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/3RKTTS2CRVM2BEEDCB2ZIPV3L4.jpg',
#    'publishedAt': '2022-05-11T22:18:00Z',
#    'content': "May 11 (Reuters) - Bitcoin fell 7.23% to $28,758.29 at 22:05 GMT on Wednesday, losing $2,241.68 from its previous close.\r\nBitcoin, the world's biggest and best-known cryptocurrency, is down 40.4% fro… [+361 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Bitcoin falls 7.8% to $31333 - Reuters',
#    'description': 'Bitcoin dropped 7.81% to $31,333.41 at 20:03 GMT on Monday, losing $2,655.98 from its previous close.',
#    'url': 'https://www.reuters.com/business/bitcoin-falls-78-31333-2022-05-09/',
#    'urlToImage': 'https://www.reuters.com/resizer/BWWUiBev3PUU7DomJJXE2-Iqz30=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/OZ6CVP422VIJ5A6UACI72VHUSY.jpg',
#    'publishedAt': '2022-05-09T20:11:00Z',
#    'content': "May 9 (Reuters) - Bitcoin dropped 7.81% to $31,333.41 at 20:03 GMT on Monday, losing $2,655.98 from its previous close.\r\nBitcoin, the world's biggest and best-known cryptocurrency, is down 35% from t… [+351 chars]"},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Ivan Mehta',
#    'title': 'How the BAYC metaverse mint raised Ethereum gas fees to thousands of dollars',
#    'description': 'If you ever wanted to buy an NFT based on Ethereum, you would have to pay a transaction fee to register it on the blockchain. Last week, that fee skyrocketed to unprecedented levels. So you might have had to pay thousands of dollars as fees to get an NFT that…',
#    'url': 'https://thenextweb.com/news/bayc-metaverse-otherside-mint-gas-fees-analysis',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2022%2F05%2FOtherside-nft.jpg&signature=a5fe37575e1fe4a83069c67eddf3dc7d',
#    'publishedAt': '2022-05-02T12:17:07Z',
#    'content': 'If you ever wanted to buy an NFT based on Ethereum, you would have to pay a transaction fee to register it on the blockchain. Last week, that fee skyrocketed to unprecedented levels.\r\nSo you might ha… [+7216 chars]'},
#   {'source': {'id': 'ars-technica', 'name': 'Ars Technica'},
#    'author': 'Andrew Cunningham',
#    'title': 'NiceHash software unlocks full crypto-mining performance for most Nvidia GPUs',
#    'description': "But the workaround still can't defeat the newest version of Nvidia's LHR tech.",
#    'url': 'https://arstechnica.com/gadgets/2022/05/nicehash-software-unlocks-full-cryptomining-performance-for-most-nvidia-gpus/',
#    'urlToImage': 'https://cdn.arstechnica.net/wp-content/uploads/2018/03/30770561533_a4ea9f1dd9_o-760x380.jpg',
#    'publishedAt': '2022-05-09T16:52:01Z',
#    'content': '9 with 8 posters participating\r\nNvidia began releasing LHR (or Lite Hash Rate) graphics cards last year\xa0to slow down their cryptocurrency mining performance and make them less appealing to non-gamers… [+2182 chars]'},
#   {'source': {'id': None, 'name': 'Bitcoin.com'},
#    'author': None,
#    'title': 'Bitcoin, Ethereum Technical Analysis: BTC Slips to 10-Month Low, Below $33000 – Market Updates Bitcoin News - Bitcoin News',
#    'description': '<ol><li>Bitcoin, Ethereum Technical Analysis: BTC Slips to 10-Month Low, Below $33000 – Market Updates Bitcoin News\xa0\xa0Bitcoin News\r\n</li><li>Bitcoin drops 50% from peak, near lowest levels in last one year\xa0\xa0Economic Times\r\n</li><li>Crypto Crash: Why is cryptoc…',
#    'url': 'https://news.bitcoin.com/bitcoin-ethereum-technical-analysis-btc-slips-to-10-month-low-below-33000/',
#    'urlToImage': 'https://static.news.bitcoin.com/wp-content/uploads/2022/05/shutterstock_1978798856-1.jpg',
#    'publishedAt': '2022-05-09T13:45:30Z',
#    'content': 'BTC fell to its lowest level since last July, as prices dropped below $33,000 to start the week. The selloff in cryptocurrency started last week, following the Fed’s decision to hike interest rates b… [+2651 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'mfox@businessinsider.com (Matthew Fox)',
#    'title': 'Weekly NFT sales plunge 50% to $255 million amid crypto bear market. These were the 5 best-selling digital collections.',
#    'description': 'Total NFT sales volume hit $29 billion over the past year as artists, investors, and entrepreneurs descend upon the nascent Web3 space.',
#    'url': 'https://markets.businessinsider.com/news/currencies/bored-ape-yacht-club-reclaims-top-spot-weekly-nft-sales-2022-5',
#    'urlToImage': 'https://i.insider.com/628508651aa29100196a381f?width=1200&format=jpeg',
#    'publishedAt': '2022-05-18T15:53:28Z',
#    'content': 'The cryptocurrency boom over the past few years has helped propel a newer market to record heights: digital collectibles known as NFTs.\xa0\r\nThe craze has pushed total NFT sales volume to $29 billion ov… [+2866 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'bevans@insider.com (Brian Evans)',
#    'title': "ApeCoin dips 16% following Bored Ape Yacht Club creator's landmark metaverse NFT sale",
#    'description': 'The skid follows a massive NFT sale from Bored Ape Yacht Club creator Yuga Labs for its metaverse game "Otherside."',
#    'url': 'https://markets.businessinsider.com/news/currencies/apecoin-price-bored-ape-yacht-club-yuga-labs-metaverse-sale-2022-5',
#    'urlToImage': 'https://i.insider.com/622f3dd2843ef30018e6ddab?width=1200&format=jpeg',
#    'publishedAt': '2022-05-02T19:03:32Z',
#    'content': 'ApeCoin, the native cryptocurrency of the APE Ecosystem, slid 16% Monday in a viciously volatile trading session.\r\nTokens were trading at $14.60 per token at presstime. The crypto is often linked wit… [+1515 chars]'},
#   {'source': {'id': None, 'name': 'VentureBeat'},
#    'author': 'Dean Takahashi',
#    'title': 'AMD and web 3 firms launch $7M contest for zero-knowledge cryptography',
#    'description': 'A coalition of 22 leading zero-knowledge technology companies, foundations, and funds including Advanced Micro Devices, Aleo, Anoma, the Ethereum Foundation, Matter Labs, Mina Protocol, Polkadot Pioneers Prize, and Polygon have launched a contest to advance t…',
#    'url': 'https://venturebeat.com/2022/04/20/amd-and-web-3-firms-launch-7m-contest-for-zero-knowledge-cryptography/',
#    'urlToImage': 'https://venturebeat.com/wp-content/uploads/2022/04/ZPrize4.jpg?w=1200&strip=all',
#    'publishedAt': '2022-04-20T13:00:00Z',
#    'content': 'We are excited to bring Transform 2022 back in-person July 19 and virtually July 20 - 28. Join AI and data leaders for insightful talks and exciting networking opportunities. Register today!\r\nA coali… [+7528 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'Bitcoin value drops by 50% since November peak',
#    'description': 'The slide in the value of cryptocurrencies comes as stock markets around the world have also fallen.',
#    'url': 'https://www.bbc.co.uk/news/business-61375152',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/8362/production/_124643633_gettyimages-1384896168.jpg',
#    'publishedAt': '2022-05-09T03:04:37Z',
#    'content': "Image source, Getty Images\r\nThe value of Bitcoin continued to fall over the weekend as it dropped below $34,000 (£27,630), according to the Coinbase cryptocurrency exchange.\r\nThe world's largest cryp… [+2164 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'insider@insider.com (Paul Kim)',
#    'title': 'Understanding web3: The new version of the web that works on blockchain',
#    'description': 'Supporters of web3 call it a democratic version of the internet where you own your own data.',
#    'url': 'https://www.businessinsider.com/personal-finance/what-is-web3',
#    'urlToImage': 'https://i.insider.com/626af560c8c8ac001940fa09?width=1200&format=jpeg',
#    'publishedAt': '2022-04-28T20:29:33Z',
#    'content': "If its advocates are to be believed, web3 is freedom, democracy, and ownership an idealistic version of the web built for users. Theoretically, they're not wrong. Web3 is still in development, a few … [+8362 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Gucci jumps on the crypto bandwagon with U.S. project - Reuters.com',
#    'description': "Gucci's high-end handbags and other luxury products can now be bought using cryptocurrencies, including bitcoin, in some U.S. stores, the Italian company said, as digital currencies move to broader acceptance.",
#    'url': 'https://www.reuters.com/business/retail-consumer/gucci-jumps-crypto-bandwagon-with-us-project-2022-05-05/',
#    'urlToImage': 'https://www.reuters.com/resizer/aLPEIt4kysCMpwdBeNLdWl6_YxU=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/353HRRTJVVKDLIMZK5Y3V2JP3I.jpg',
#    'publishedAt': '2022-05-05T08:26:00Z',
#    'content': "May 5 (Reuters) - Gucci's high-end handbags and other luxury products can now be bought using cryptocurrencies, including bitcoin, in some U.S. stores, the Italian company said, as digital currencies… [+1161 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Twitter, Stripe pilot cryptocurrency payments for creators - Reuters',
#    'description': 'Twitter Inc <a href="https://www.reuters.com/companies/TWTR.N" target="_blank">(TWTR.N)</a> and digital payments processor Stripe Inc will pilot cryptocurrency payouts for select users of the social media site\'s content monetization products, the companies an…',
#    'url': 'https://www.reuters.com/technology/twitter-stripe-pilot-cryptocurrency-payments-creators-2022-04-22/',
#    'urlToImage': 'https://www.reuters.com/resizer/NTD2JIkWomh-SjohA_vs8Cm0cKM=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/V4EEOCXOM5MOTKBYKH2UYHO4WE.jpg',
#    'publishedAt': '2022-04-22T13:02:00Z',
#    'content': "April 22 (Reuters) - Twitter Inc (TWTR.N) and digital payments processor Stripe Inc will pilot cryptocurrency payouts for select users of the social media site's content monetization products, the co… [+1235 chars]"},
#   {'source': {'id': 'vice-news', 'name': 'Vice News'},
#    'author': 'Edward Ongweso Jr, Jordan Pearson',
#    'title': 'Bored Ape Virtual Land Sale Breaks Ethereum, Wastes $180 Million in Fees',
#    'description': 'Yuga Labs\' Otherside sale sparked a "gas war" that wasted millions and clogged up Ethereum, resulting in failed transactions.',
#    'url': 'https://www.vice.com/en/article/g5q7zb/bored-ape-virtual-land-sale-breaks-ethereum-wastes-dollar180-million-in-fees',
#    'urlToImage': 'https://video-images.vice.com/articles/6270162856f07d00947c0806/lede/1651513036020-gettyimages-1390557351.jpeg?image-resize-opts=Y3JvcD0xeHc6MC44MjJ4aDsweHcsMC4wNDczeGgmcmVzaXplPTEyMDA6KiZyZXNpemU9MTIwMDoq',
#    'publishedAt': '2022-05-02T17:42:57Z',
#    'content': 'On Saturday, Yuga Labs―the company behind the Bored Apes Yacht Club NFT collection― launched a sale for Otherdeeds, which are NFTs for digital land related to an upcoming “metaverse” gaming project c… [+4923 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Corin Faife',
#    'title': 'Stablecoins are struggling to survive the crypto crash',
#    'description': 'After the Terra stablecoin broke its dollar peg and dropped to less than 30 cents, investors have been watching closely for repercussions across cryptocurrency markets.',
#    'url': 'https://www.theverge.com/2022/5/12/23069232/terra-luna-collapse-stablecoins-crypto-crash-bitcoin',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/rUaR5RqYmvfihRfA_BzIMNOzcio=/0x146:2040x1214/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/10576389/acastro_180402_2428_001.jpg',
#    'publishedAt': '2022-05-12T20:56:14Z',
#    'content': 'Once pegged to the dollar, Terras UST coin is now trading at 40 cents\r\nIllustration by Alex Castro\r\nIts been a crushing few days for the Terra project, in a week that has been unforgiving for cryptoc… [+4159 chars]'},
#   {'source': {'id': 'vice-news', 'name': 'Vice News'},
#    'author': 'Lorenzo Franceschi-Bicchierai, Jordan Pearson',
#    'title': 'A Crypto Entrepreneur Is on the Lam After Dev Jailed for North Korea Trip',
#    'description': 'Christopher Emms, charged as a co-conspirator with jailed Ethereum developer Virgil Griffith, is at large.',
#    'url': 'https://www.vice.com/en/article/88gp8g/a-crypto-entrepreneur-is-on-the-lam-after-dev-jailed-for-north-korea-trip',
#    'urlToImage': 'https://video-images.vice.com/articles/6266e8c519b1e500944bcf2c/lede/1650914540319-north-korea.jpeg?image-resize-opts=Y3JvcD0xeHc6MC44NDQyeGg7MHh3LDB4aCZyZXNpemU9MTIwMDoqJnJlc2l6ZT0xMjAwOio',
#    'publishedAt': '2022-04-25T19:32:37Z',
#    'content': 'The U.S. Department of Justice accused two European citizens of money laundering for their role in helping the North Korean government organize a cryptocurrency conference in 2019. One of the men, 30… [+5976 chars]'},
#   {'source': {'id': None, 'name': 'CNET'},
#    'author': 'Daniel Van Boom',
#    'title': "Terra's Plan to Revive Luna After Historic Crypto Crash - CNET",
#    'description': 'Terralabs founder Kwon Do wants to create a new blockchain and distribute hundreds of millions of new luna tokens to burned investors.',
#    'url': 'https://www.cnet.com/personal-finance/crypto/terras-plan-to-revive-luna-after-historic-crypto-crash/',
#    'urlToImage': 'https://www.cnet.com/a/img/resize/f90165eae4cb2cb61453618e4f28cc17804b388d/2022/05/17/0d3b68a5-361e-464c-ae13-1c3c9b182c63/gettyimages-1240635265.jpg?auto=webp&fit=crop&height=630&width=1200',
#    'publishedAt': '2022-05-17T03:38:00Z',
#    'content': 'May has been a tough month for all cryptocurrencies, but especially for luna. While bitcoin and ether are down 25% and 30% respectively, the luna token cratered from $81 a month ago to a fraction of … [+3634 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Alex Hern UK technology editor',
#    'title': 'TerraUSD ‘stablecoin’ delisted from crypto exchanges',
#    'description': '‘Algorithmic stablecoin’, whose collapse triggered multibillion-dollar selloff, turns off blockchainTerraUSD, the “algorithmic stablecoin” whose collapse prompted a multibillion-dollar selloff across crypto markets, has turned off its blockchain and been deli…',
#    'url': 'https://amp.theguardian.com/technology/2022/may/13/terrausd-stablecoin-crypto-exchanges',
#    'urlToImage': 'https://i.guim.co.uk/img/media/1b178fdbbfa0db5fde7959b86ba45232c3a3baf5/0_384_5760_3456/master/5760.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=6860d93061e97f54bac1b4a68eb647f8',
#    'publishedAt': '2022-05-13T11:09:26Z',
#    'content': 'TerraUSD, the algorithmic stablecoin whose collapse prompted a multibillion-dollar selloff across crypto markets, has turned off its blockchain and been delisted from major exchanges, in effect shutt… [+3641 chars]'},
#   {'source': {'id': None, 'name': 'Bearblog.dev'},
#    'author': None,
#    'title': "You shouldn't invest in the crypto currency?",
#    'description': 'Disclaimer - I have invested 1% of my savings into stable cryptocurrencies such as Bitcoin and Ethereum etc.\nLet’s talk about slot games first. Most of them are',
#    'url': 'https://rohitgupta.bearblog.dev/why-you-shouldnt-invest-in-the-crypto-currency/',
#    'urlToImage': None,
#    'publishedAt': '2022-05-10T19:16:40Z',
#    'content': 'Disclaimer - I have invested 1% of my savings into stable cryptocurrencies such as Bitcoin and Ethereum etc.\r\nLets talk about slot games first. Most of them are designed in such a way that you will w… [+955 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'rhouston@businessinsider.com (Rickie Houston, CEPF)',
#    'title': 'eToro vs. Robinhood: How the investing platforms compare',
#    'description': 'eToro is best for crypto-focused traders, while Robinhood is a better option for frequent traders and options traders who want lower fees.',
#    'url': 'https://www.businessinsider.com/personal-finance/etoro-vs-robinhood',
#    'urlToImage': 'https://i.insider.com/62604e6fdb73840018a5414d?width=1200&format=jpeg',
#    'publishedAt': '2022-04-20T20:15:51Z',
#    'content': 'Bottom line: eToro is the best choice for crypto-focused and community-oriented traders, as it offers more assets including automated investing options like CopyPortfolios and the CopyTrader system. … [+8229 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Bitcoin falls to lowest since January, in line with tumbling stock markets - Reuters',
#    'description': 'Bitcoin fell to its lowest level since January on Monday as slumping equity markets continued to hurt cryptocurrencies, which are currently trading in line with so-called riskier assets like tech stocks.',
#    'url': 'https://www.reuters.com/business/finance/bitcoin-falls-lowest-since-january-line-with-tumbling-stock-markets-2022-05-09/',
#    'urlToImage': 'https://www.reuters.com/resizer/B0qAxA8TjZ596MlWtB1mhDiQ1HM=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/SBR5WIGRUVJBRNZBI6EL6DOKVA.jpg',
#    'publishedAt': '2022-05-09T04:43:00Z',
#    'content': 'HONG KONG, May 9 (Reuters) - Bitcoin fell to its lowest level since January on Monday as slumping equity markets continued to hurt cryptocurrencies, which are currently trading in line with so-called… [+1775 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'FTX chief welcomes more regulation as CFTC weighs its crypto derivatives proposal - Reuters.com',
#    'description': "Crypto exchange FTX's move to seek regulatory approval for direct trading in cryptocurrency derivatives will leave the door open for more oversight of the business in the United States, the company's chief executive officer said.",
#    'url': 'https://www.reuters.com/business/finance/ftx-chief-welcomes-more-regulation-cftc-weighs-its-crypto-derivatives-proposal-2022-04-28/',
#    'urlToImage': 'https://www.reuters.com/resizer/bR24nKf7RQi1pus8Pl8rSDLsYno=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/W4CQDYPB4ZJNJPFVMW5VJ2CONY.jpg',
#    'publishedAt': '2022-04-28T13:12:00Z',
#    'content': 'Representations of cryptocurrencies Bitcoin, Ethereum, DogeCoin, Ripple, Litecoin are placed on PC motherboard in this illustration taken, June 29, 2021. REUTERS/Dado Ruvic/Illustration/File Photo/Fi… [+1955 chars]'},
#   {'source': {'id': 'financial-post', 'name': 'Financial Post'},
#    'author': 'Financial Post Staff',
#    'title': 'Bitcoin, cryptocurrency shed $200 billion in one day - Financial Post',
#    'description': '<ol><li>Bitcoin, cryptocurrency shed $200 billion in one day\xa0\xa0Financial Post\r\n</li><li>$1 Trillion Crypto Meltdown—Huge Crash Wipes Out The Price Of Bitcoin, Ethereum, BNB, XRP, Cardano, Solana, Terra’s Luna And Avalanche\xa0\xa0Forbes\r\n</li><li>Crypto market’s cra…',
#    'url': 'https://financialpost.com/fp-finance/cryptocurrency/what-you-need-to-know-about-the-rout-that-just-wiped-200-billion-off-the-cryptocurrency-market-in-one-day',
#    'urlToImage': 'https://smartcdn.gprod.postmedia.digital/financialpost/wp-content/uploads/2022/05/bitcoin-0512.jpg',
#    'publishedAt': '2022-05-12T12:26:01Z',
#    'content': 'Contagion spreading to stock markets as investors see one more thing to worry about \r\nA massive sell-off has spread like wildfire through the world of cryptocurrencies.Photo by REUTERS/Dado Ruvic/Fil… [+7621 chars]'},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': "Meghan O'Gieblyn",
#    'title': 'Can Social Media Be Redeemed?',
#    'description': 'WIRED’s spiritual advice columnist on Jack Dorsey’s remorse for his role in creating a centralized internet and what it signals for the rest of us.',
#    'url': 'https://www.wired.com/story/can-social-media-be-redeemed/',
#    'urlToImage': 'https://media.wired.com/photos/62756b69ada91b8860a6f0d5/191:100/w_1280,c_limit/WI060122_ST_CloudSupport_01.jpg',
#    'publishedAt': '2022-05-11T12:00:00Z',
#    'content': 'I read that Jack Dorsey, a cofounder of Twitter, claims to regret his role in creating the centralized internet. Given what we know about the divisiveness, violence, and misinformation that social me… [+7774 chars]'},
#   {'source': {'id': None, 'name': 'Ctvnews.ca'},
#    'author': None,
#    'title': 'Poilievre personally holds investment in Bitcoin as he promotes crypto to Canadians - CTV News',
#    'description': 'Conservative Party leadership candidate Pierre Poilievre has a personal financial interest in cryptocurrencies that he has promoted during his campaign as a hedge against inflation.',
#    'url': 'https://www.ctvnews.ca/politics/poilievre-personally-holds-investment-in-bitcoin-as-he-promotes-crypto-to-canadians-1.5907615',
#    'urlToImage': 'https://www.ctvnews.ca/content/dam/ctvnews/en/images/2022/5/17/pierre-poilievre-1-5907634-1652823979715.jpg',
#    'publishedAt': '2022-05-17T21:47:00Z',
#    'content': 'Conservative Party leadership candidate Pierre Poilievre has a personal financial interest in cryptocurrencies that he has promoted during his campaign as a hedge against inflation.\r\nThe Ottawa-area … [+4372 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Entrepreneur en Español',
#    'title': 'AxenCoin, the new Mexican cryptocurrency',
#    'description': 'In addition to serving as an investment instrument, cryptocurrency will make it possible to pay for goods and services in the near future.',
#    'url': 'https://www.entrepreneur.com/article/426714',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1651612958-GettyImages-916432942-copy.jpg',
#    'publishedAt': '2022-05-03T23:01:00Z',
#    'content': 'Last week, the Senate of the Republic in Mexico organized a forum to raise awareness about the use of cryptocurrencies and to analyze and trigger their growth. The senators must have seen something, … [+1406 chars]'},
#   {'source': {'id': None, 'name': 'MakeUseOf'},
#    'author': 'Katie Rees',
#    'title': 'What Is Zilliqa? Will It Surpass Ethereum?',
#    'description': 'It has an ever-growing ecosystem, supports staking and NFTs, and is growing in popularity. So, what is Zilliqa?',
#    'url': 'https://www.makeuseof.com/what-is-zilliqa/',
#    'urlToImage': 'https://static1.makeuseofimages.com/wordpress/wp-content/uploads/2022/05/zilliqa-earth-1.jpg',
#    'publishedAt': '2022-05-15T16:00:14Z',
#    'content': "The cryptocurrency industry isn't just about buying and selling coins and tokens. You can do myriad other things with your crypto, and thousands of crypto enthusiasts want to take their passion a ste… [+6847 chars]"},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'EditorDavid',
#    'title': 'Dirk Hohndel, Early Linux Contributor, Joins Foundation Supporting Blockchain Platform Cardano',
#    'description': "Dirk Hohndel gets frequently mentioned on Slashdot. He was a very early contributor to Linux (and for the last five years the chief open source officer and vice president at VMware). But he's also the guy who interviews Linus Torvalds in the keynote sessions …",
#    'url': 'https://news.slashdot.org/story/22/04/23/0611251/dirk-hohndel-early-linux-contributor-joins-foundation-supporting-blockchain-platform-cardano',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/money_64.png',
#    'publishedAt': '2022-04-23T16:34:00Z',
#    'content': "Dirk Hohndel gets frequentlymentioned on Slashdot. He was a very early contributor to Linux (and for the last five years the chief open source officer and vice president at VMware). But he's also the… [+1660 chars]"},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Madeline Garfinkle',
#    'title': 'Rough Monday For Bitcoin: 5.2% Drop in 24 Hours',
#    'description': 'After its fifth consecutive day of drops, Bitcoin is down more than 50% since its peak in November.',
#    'url': 'https://www.entrepreneur.com/article/427129',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1652111042-GettyImages-1339026234.jpg',
#    'publishedAt': '2022-05-09T15:00:00Z',
#    'content': 'As of Monday\xa0morning, Bitcoin is down to $32,940, a drop that marks a steep fall of more than 50% since its all-time high of $68,990 in November and Bitcoin isnt the only digital currency taking a di… [+1414 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Entrepreneur Store',
#    'title': 'Become a Web3 Programmer in Your Own Time',
#    'description': 'Start programming for Web3 and carve out your stake of a new Internet frontier.',
#    'url': 'https://www.entrepreneur.com/article/425545',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1650663130-Ent-Web3Programming.jpeg',
#    'publishedAt': '2022-04-28T17:30:00Z',
#    'content': 'Over the past few years, the tech world has experienced a rapid evolution, spearheaded in large part by the blockchain. Now, that evolution is on the precipice of revolution as NFTs and the Metaverse… [+1613 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Callum Booth',
#    'title': '2 surprising uses of blockchain that could change the world',
#    'description': 'By now, we all know the most known use of blockchain technology: cryptocurrency. Of course, this isn’t all there is though. In 2022, we’ve seen NFTs (non-fungible tokens that are part of the Ethereum blockchain) capture the public’s imagination — but outside …',
#    'url': 'https://thenextweb.com/news/2-surprising-uses-blockchain-could-change-world-interview',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2022%2F04%2Fheader-image-blockchain-world.jpg&signature=64a64df4a4c637efe0aac5b74fe8f6d0',
#    'publishedAt': '2022-04-22T09:36:13Z',
#    'content': 'By now, we all know the most known use of blockchain technology: cryptocurrency.\r\nOf course, this isnt all there is though. In 2022, weve seen NFTs (non-fungible tokens that are part of the Ethereum … [+3811 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'The Conversation',
#    'title': 'Can you truly own anything in the metaverse? Not really, says a law professor',
#    'description': 'In 2021, an investment firm bought 2,000 acres of real estate for about US$4 million. Normally this would not make headlines, but in this case the land was virtual. It existed only in a metaverse platform called The Sandbox. By buying 792 non-fungible tokens …',
#    'url': 'https://thenextweb.com/news/can-you-truly-own-anything-in-the-metaverse-not-really-says-a-law-professor',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2022%2F04%2FDecentraland-art-hed.jpg&signature=213081ce2a9aa2ae7e534e0f1f5ea901',
#    'publishedAt': '2022-04-23T11:00:07Z',
#    'content': 'In 2021, an investment firm bought 2,000 acres of real estate for about US$4 million. Normally this would not make headlines, but in this case the land was virtual. It existed only in a metaverse pla… [+7561 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Alex Hern',
#    'title': '$7.6bn of ‘stablecoin’ tether redeemed since start of crypto crisis',
#    'description': 'Figures suggest company has paid out more than total cash on hand, as terra backers prepare relaunchDigital investors have withdrawn savings in the “stablecoin” tether worth $7.6bn since the cryptocurrency crisis began last week, suggesting the company has pa…',
#    'url': 'https://amp.theguardian.com/technology/2022/may/16/stablecoin-tether-redeemed-crypto-crisis-terra',
#    'urlToImage': 'https://i.guim.co.uk/img/media/ed7cd8cd63b5e9292e420fedea419d72de26d813/0_398_6002_3603/master/6002.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=45c2360bba42dde961b6e201c5640b06',
#    'publishedAt': '2022-05-16T15:01:58Z',
#    'content': 'Digital investors have withdrawn savings in the stablecoin tether worth $7.6bn since the cryptocurrency crisis began last week, suggesting the company has paid out a sum almost twice its total cash h… [+5273 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Alex Hern Technology editor',
#    'title': 'Crypto crash unlikely to reduce its climate impact, expert says',
#    'description': 'Enormous energy consumption has barely reduced despite $1tn being wiped off the sectorThe crypto crash will not reduce the sector’s climate impact any time soon, an economist has warned, even though the environmental footprint of digital currencies is in theo…',
#    'url': 'https://amp.theguardian.com/technology/2022/may/18/crypto-crash-unlikely-to-reduce-its-climate-impact-expert-says',
#    'urlToImage': 'https://i.guim.co.uk/img/media/5e2c92cf82aaf1cb540d6d078a8ff4d4085a8c37/116_299_5187_3112/master/5187.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=cd301a27bef4b29b454ee049a3bbfcd7',
#    'publishedAt': '2022-05-18T15:25:40Z',
#    'content': 'The crypto crash will not reduce the sectors climate impact any time soon, an economist has warned, even though the environmental footprint of digital currencies is in theory set by their market valu… [+4874 chars]'},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'msmash',
#    'title': 'Instagram To Start Testing NFTs With Select Creators this Week',
#    'description': 'Instagram head Adam Mosseri announced today that the platform is going to start testing NFTs with select creators in the United States this week. From a report: Mosseri noted that there will be no fees associated with posting or sharing a digital collectible …',
#    'url': 'https://tech.slashdot.org/story/22/05/09/1526228/instagram-to-start-testing-nfts-with-select-creators-this-week',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/social_64.png',
#    'publishedAt': '2022-05-09T15:26:00Z',
#    'content': "I looked inside the blockchain and the art I purchased was Not Fucking There. All I found was a URL that now returns 404. But I'm sure that I can resell it for more than I paid, most certainly. Just … [+148 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'hrobertson@businessinsider.com (Harry Robertson)',
#    'title': 'Stablecoin tether breaks its peg and drops to $0.95 as panic hits crypto markets after collapse of TerraUSD',
#    'description': 'Tether — which is supposed to be worth $1 — suffered its biggest drop in over a year as it dropped as low as $0.945.',
#    'url': 'https://markets.businessinsider.com/news/currencies/tether-depeg-dollar-fall-cryptocurrency-market-panic-terrausd-luna-2022-5',
#    'urlToImage': 'https://i.insider.com/627cc9a3dd983300191caa61?width=1200&format=jpeg',
#    'publishedAt': '2022-05-12T09:02:06Z',
#    'content': "Tether, the world's biggest stablecoin, tumbled as low as $0.94 on Thursday as panic spread across crypto markets after a dramatic plunge in the TerraUSD and luna tokens.\r\nThe stablecoin fell to $0.9… [+2101 chars]"},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Amanda Breen',
#    'title': 'NFTs Are Coming to Your Social-Media Feed This Week, Says Mark Zuckerberg',
#    'description': 'The broader implications for creators remain to be seen.',
#    'url': 'https://www.entrepreneur.com/article/427233',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1652194729-GettyImages-1325758241.jpg',
#    'publishedAt': '2022-05-10T14:56:00Z',
#    'content': 'Earlier this year, Meta CEO Mark Zuckerberg revealed the company was toying with the idea of bringing NFTs to its social-media platform Instagram, though he declined to comment on exactly how and whe… [+1844 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'insider@insider.com (Paul Kim)',
#    'title': 'Cryptocurrency is crashing. What does that mean for you?',
#    'description': 'The cryptocurrency market is in turmoil after two stablecoins destabilized and Coinbase announced net losses far greater than projected.',
#    'url': 'https://www.businessinsider.com/personal-finance/crypto-crash',
#    'urlToImage': 'https://i.insider.com/627eced89147a30018b4758b?width=1200&format=jpeg',
#    'publishedAt': '2022-05-13T23:04:06Z',
#    'content': "The cryptocurrency world has had a rough May so far.\xa0\r\nSince the start of the month, cryptocurrency has lost $600 billion of value. Bitcoin dropped to prices that haven't been seen since 2020, briefl… [+5071 chars]"},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Yakup Özkardes-Cheung',
#    'title': 'The New Creative Economy Within Web 3.0',
#    'description': 'Web 3.0 will be a place where anyone can share information without worrying about censorship, and people can create content without worrying about getting paid for it.',
#    'url': 'https://www.entrepreneur.com/article/423776',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1651509960-GettyImages-1388034008.jpg',
#    'publishedAt': '2022-05-14T17:00:00Z',
#    'content': 'What is Web 3.0, really?\r\nWeb 3.0 is an abbreviation of the third generation of the World Wide Web. It is a term coined by Tim Berners-Lee and describes an internet that is not only more interactive,… [+4033 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Masha Prusso',
#    'title': 'Think Marketplaces, Not Businesses: 3 Lucrative Industries Disrupted By Crypto',
#    'description': "Cryptocurrencies have moved well beyond replacing fiat currency. They are being specifically applied to distinct industries to have maximum impact -\xa0so here's why you should consider diversifying your crypto portfolio.",
#    'url': 'https://www.entrepreneur.com/article/424002',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1651697414-GettyImages-1369169431.jpg',
#    'publishedAt': '2022-05-10T16:30:00Z',
#    'content': 'Smart entrepreneurs will always look towards infrastructures and marketplaces as opposed to businesses. In Web2, its the difference between creating Google and creating an online website visited thro… [+5316 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': None,
#    'title': 'Coinbase NFT is already operating, the marketplace that aims to democratize investment in non-fungible digital tokens',
#    'description': 'Coinbase announced the launch of the beta version of the platform where NFTs from collections such as Cool Cats and World of Women can be purchased.',
#    'url': 'https://www.entrepreneur.com/article/425306',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1650482790-GettyImages-1239947157.jpg',
#    'publishedAt': '2022-04-20T19:39:00Z',
#    'content': 'Despite the fury that seems to exist around NFTs (non-fungible tokens, that is, cryptographic assets that represent something unique), during this 2022 the market has slowed down. On OpenSea, one of … [+2323 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Entrepreneur en Español',
#    'title': "Bored and Hungry, the fast food restaurant that uses NFT's from the Bored Ape Yacht Collection for its image",
#    'description': 'The most famous apes of the digital world are very present in a fast food place in California.',
#    'url': 'https://www.entrepreneur.com/article/427161',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1652112003-GettyImages-1390557351.jpg',
#    'publishedAt': '2022-05-09T17:39:00Z',
# ...
#    'url': 'https://9to5mac.com/2022/04/25/stripe-cryptocurrency-twitter/',
#    'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2022/03/Twitter-timeline.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2022-04-25T19:49:41Z',
#    'content': 'Stripe, an online payment processing service, is partnering with Twitter to test a way for creators to receive payments in cryptocurrency. This select group of creators who have monetization features… [+1399 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Alex Hern UK technology editor',
#    'title': 'Turmoil in crypto market as ‘stablecoin’ tether breaks dollar peg',
#    'description': 'Fears of contagion among already-falling cryptocurrencies if tether follows terra into collapseTether, the largest “stablecoin” and a foundational part of the cryptocurrency ecosystem, is at risk of a bank run after breaking its peg to the dollar amid the sec…',
#    'url': 'https://amp.theguardian.com/technology/2022/may/12/stablecoin-tether-breaks-dollar-peg-cryptocurrencies',
#    'urlToImage': 'https://i.guim.co.uk/img/media/5444c46de836d19958ddc28a5b1cafc71e9d9441/0_97_5019_3011/master/5019.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=3eff5a8d6745836b4e4dccaf8389733e',
#    'publishedAt': '2022-05-12T11:41:32Z',
#    'content': 'Tether, the largest stablecoin and a foundational part of the cryptocurrency ecosystem, is at risk of a bank run after breaking its peg to the dollar amid the sectors worst crash in years.\r\nThe crypt… [+4859 chars]'},
#   {'source': {'id': None, 'name': 'Motley Fool'},
#    'author': 'newsfeedback@fool.com (Daniel Foelber)',
#    'title': '1 Growth Stock, 1 Dividend Stock, and 1 Cryptocurrency to Buy Now',
#    'description': 'The case for ChargePoint, Starbucks, and Ethereum.',
#    'url': 'https://www.fool.com/investing/2022/04/22/1-growth-stock-1-dividend-stock-and-1-cryptocurren/',
#    'urlToImage': 'https://g.foolcdn.com/editorial/images/674152/1-crypto-concept.jpeg',
#    'publishedAt': '2022-04-22T12:30:00Z',
#    'content': 'During market sell-offs, sometimes it can be difficult to decide what to invest in. Do you buy growth stocks on sale? Maybe you want a dividend stock you can count on for passive income. Or maybe you… [+5931 chars]'},
#   {'source': {'id': None, 'name': 'Motley Fool'},
#    'author': 'newsfeedback@fool.com (Travis Hoium)',
#    'title': 'Ethereum in 3 Charts: Buy or Sell?',
#    'description': 'Ethereum gives investors reasons for both optimism and caution.',
#    'url': 'https://www.fool.com/investing/2022/04/25/ethereum-in-3-charts-buy-or-sell/',
#    'urlToImage': 'https://g.foolcdn.com/editorial/images/674737/digital-crypto-currency-floating-over-earth.jpg',
#    'publishedAt': '2022-04-25T11:15:00Z',
#    'content': 'Cryptocurrencies have taken the world by storm over the last few years, and one of the leaders has been Ethereum( ETH -2.75% ). The Ethereum blockchain allows developers to build smart contracts into… [+3445 chars]'},
#   {'source': {'id': None, 'name': 'Motley Fool'},
#    'author': 'newsfeedback@fool.com (Travis Hoium)',
#    'title': 'Why Bitcoin, Ethereum, and Coinbase Jumped Today',
#    'description': 'After a rough week, crypto is back on the upswing again.',
#    'url': 'https://www.fool.com/investing/2022/05/02/why-bitcoin-ethereum-and-coinbase-jumped-today/',
#    'urlToImage': 'https://g.foolcdn.com/editorial/images/677291/bitcoin-in-1-and-0.jpg',
#    'publishedAt': '2022-05-02T18:01:03Z',
#    'content': 'What happened\xa0\r\nAfter a rough week, cryptocurrency assets are on the mend on Monday morning. The calendar has turned over to a new month and the stock market is up slightly with crypto assets climbin… [+2676 chars]'},
#   {'source': {'id': None, 'name': 'Motley Fool'},
#    'author': 'newsfeedback@fool.com (Neil Patel)',
#    'title': '2 Cryptos That Could Outpace Ethereum',
#    'description': 'These younger blockchain projects are showing serious promise.',
#    'url': 'https://www.fool.com/investing/2022/04/28/2-cryptos-that-could-outpace-ethereum/',
#    'urlToImage': 'https://g.foolcdn.com/editorial/images/671000/gettyimages-1320686132.jpg',
#    'publishedAt': '2022-04-28T13:00:00Z',
#    'content': "It's hard to find an asset that has outperformed Ethereum's(ETH 0.12%) 5,500% return over the past five years. The world's top programmable blockchain certainly has its fair share of supporters in th… [+3866 chars]"},
#   {'source': {'id': None, 'name': 'Small Business Trends'},
#    'author': 'Yednekachew Samson',
#    'title': 'Take a Cryptocurrency Course to See If They’re for You',
#    'description': 'Take a cryptocurrency course to get a functional understanding of the future of digital finance as the techonology sees increased adoption.',
#    'url': 'https://smallbiztrends.com/2022/05/cryptocurrency-course.html',
#    'urlToImage': 'https://media.smallbiztrends.com/2022/04/cryptocurrency-course.png',
#    'publishedAt': '2022-05-02T19:00:15Z',
#    'content': 'If you buy something through our links, we may earn money from our affiliate partners. Learn more.\r\nIn June 2009, one Bitcoin (the first Crypto) was valued at 0.0001 USD, by November 2021 the value o… [+5205 chars]'},
#   {'source': {'id': None, 'name': 'The Business of Fashion'},
#    'author': 'Robert Williams',
#    'title': 'Gucci to Accept Cryptocurrency',
#    'description': 'The Italian megabrand is set to accept payment in Bitcoin, Ethereum, Dogecoin and other digital currencies at select US stores.',
#    'url': 'https://www.businessoffashion.com/articles/luxury/gucci-to-accept-cryptocurrency/',
#    'urlToImage': 'https://img.businessoffashion.com/resizer/7k9ZxDVuItxfr2-bgIOMdUOBehs=/1200x630/filters:format(jpg):quality(70):focal(4903x880:4913x890)/cloudfront-eu-central-1.images.arcpublishing.com/businessoffashion/5GK76QPVRFHLHEW5ZTK3E5PFSM.jpg',
#    'publishedAt': '2022-05-05T00:20:48Z',
#    'content': 'Clients of Italian luxury giant Gucci will soon be able to pay for products in cryptocurrency at certain US retail stores. \r\nGucci will accept 10 crypto currencies including Bitcoin, Ethereum and Dog… [+1527 chars]'},
#   {'source': {'id': None, 'name': 'Motley Fool'},
#    'author': 'newsfeedback@fool.com (Neil Patel)',
#    'title': '1 Cryptocurrency That Could Dwarf Ethereum',
#    'description': 'Thoughtfully trying to solve the scalability issue could mean huge upside for investors.',
#    'url': 'https://www.fool.com/investing/2022/05/13/1-cryptocurrency-that-could-dwarf-ethereum/',
#    'urlToImage': 'https://g.foolcdn.com/editorial/images/678912/gettyimages-1347340865-1.jpg',
#    'publishedAt': '2022-05-13T13:15:00Z',
#    'content': "Despite the recent turmoil rattling the crypto market, over the past five years, Ethereum(ETH 10.54%) has generated an astronomical return of 2,560%. You'd be hard-pressed to find a financial asset w… [+3549 chars]"},
#   {'source': {'id': None, 'name': 'Motley Fool'},
#    'author': 'newsfeedback@fool.com (Travis Hoium)',
#    'title': 'Is Solana Kicking Ethereum to the Curb?',
#    'description': "Ethereum's digital economy may be limited because of its inability to scale.",
#    'url': 'https://www.fool.com/investing/2022/05/12/is-solana-kicking-ethereum-to-the-curb/',
#    'urlToImage': 'https://g.foolcdn.com/editorial/images/679450/gettyimages-1317587887.jpg',
#    'publishedAt': '2022-05-12T11:00:00Z',
#    'content': 'The limits that Ethereum(ETH -18.88%) has on how it can scale today could be a serious challenge that allows competing blockchains to more fully develop in its place. In this Motley Fool Live segment… [+2000 chars]'},
#   {'source': {'id': None, 'name': 'Motley Fool'},
#    'author': 'newsfeedback@fool.com (Jon Quast)',
#    'title': 'This Ethereum Competitor Is Worth $5.25 Billion',
#    'description': 'Avalanche is currently the 10th largest cryptocurrency by market cap.',
#    'url': 'https://www.fool.com/investing/2022/05/12/this-ethereum-competitor-is-worth-525-billion/',
#    'urlToImage': 'https://g.foolcdn.com/editorial/images/679446/gettyimages-907902702_T1XF7UD.jpg',
#    'publishedAt': '2022-05-12T11:00:00Z',
#    'content': 'Ava Labs, the team behind Avalanche(AVAX -23.35%), is sitting on a lot of money for a crypto company. In this Motley Fool Live segment from "The Crypto Show," recorded April 20, Fool.com contributors… [+3005 chars]'},
#   {'source': {'id': None, 'name': 'Motley Fool'},
#    'author': 'newsfeedback@fool.com (Will Ebiefung)',
#    'title': '2 Top Cryptocurrencies to Buy and Never Sell',
#    'description': 'These two "Ethereum killers" look poised for sustainable success.',
#    'url': 'https://www.fool.com/investing/2022/05/10/2-top-cryptocurrencies-to-buy-and-never-sell/',
#    'urlToImage': 'https://g.foolcdn.com/editorial/images/678612/gettyimages-1323758599.jpg',
#    'publishedAt': '2022-05-10T10:45:00Z',
#    'content': 'Cryptocurrency is a speculative asset class, but leading blockchains like\xa0Solana\xa0(SOL -4.10%) and\xa0Cardano\xa0(ADA 0.02%) have fundamental advantages over rivals in sophistication and potential uses. Let… [+3203 chars]'},
#   {'source': {'id': None, 'name': 'HYPEBEAST'},
#    'author': 'info@hypebeast.com (HYPEBEAST), HYPEBEAST',
#    'title': 'Solana NFT Project Okay Bears Launches With $18 Million USD in Sales',
#    'description': 'Solana NFT\xa0trading volume has jumped thanks to a new NFT project, Decrypt reported. The Solana-based Okay Bears avatar series was so popular upon its release yesterday that the project generated more trading volume than any individual Ethereum project.Launchi…',
#    'url': 'https://hypebeast.com/2022/4/solana-nft-project-okay-bears-launch-record',
#    'urlToImage': 'https://image-cdn.hypb.st/https%3A%2F%2Fhypebeast.com%2Fimage%2F2022%2F04%2FSolana-NFT-Project-Okay-Bears-Launches-With-18-Million-USD-in-Sales-tw.jpg?w=960&cbr=1&q=90&fit=max',
#    'publishedAt': '2022-04-27T21:13:07Z',
#    'content': 'SolanaNFT\xa0trading volume has jumped thanks to a new NFT project, Decrypt reported. The Solana-based Okay Bears avatar series was so popular upon its release yesterday that the project generated more … [+867 chars]'},
#   {'source': {'id': None, 'name': 'Motley Fool'},
#    'author': 'newsfeedback@fool.com (Will Ebiefung)',
#    'title': '2 Top Cryptocurrencies to Buy and Hold for Decades',
#    'description': 'Bitcoin and Ethereum are the top dogs for a reason.',
#    'url': 'https://www.fool.com/investing/2022/04/26/2-top-cryptocurrencies-to-buy-and-hold-for-decades/',
#    'urlToImage': 'https://g.foolcdn.com/editorial/images/675938/gettyimages-1323758599.jpg',
#    'publishedAt': '2022-04-26T12:15:00Z',
#    'content': 'Want a cryptocurrency that can stand the test of time? Look no further than the industry\'s biggest names:\xa0Bitcoin\xa0( BTC 4.03% ) and\xa0Ethereum\xa0( ETH 4.58% ). Let\'s explore why these "blue chip" cryptos… [+3173 chars]'},
#   {'source': {'id': None, 'name': 'Motley Fool'},
#    'author': 'newsfeedback@fool.com (Will Ebiefung)',
#    'title': 'Got $500? 2 Top Cryptocurrencies to Buy for the Long Haul',
#    'description': 'Ethereum and Ripple could make excellent long-term investments.',
#    'url': 'https://www.fool.com/investing/2022/04/27/got-500-2-top-cryptocurrencies-to-buy-for-the-long/',
#    'urlToImage': 'https://g.foolcdn.com/editorial/images/676135/gettyimages-1147352160.jpg',
#    'publishedAt': '2022-04-27T10:50:00Z',
#    'content': "You don't need a fortune to get started in crypto. And a $500 starting investment could help set the foundation for enormous returns over the long term. Let's explore why Ethereum\xa0(ETH -3.94%) and\xa0Ri… [+3061 chars]"},
#   {'source': {'id': None, 'name': 'Motley Fool'},
#    'author': 'newsfeedback@fool.com (Will Ebiefung)',
#    'title': 'Market Plunge 2022: 2 Top Cryptos to Buy Cheap',
#    'description': 'Bitcoin and Ethereum have what it takes to bounce back.',
#    'url': 'https://www.fool.com/investing/2022/05/17/market-plunge-2022-2-top-cryptos-to-buy-cheap/',
#    'urlToImage': 'https://g.foolcdn.com/editorial/images/680042/gettyimages-904127288.jpg',
#    'publishedAt': '2022-05-17T12:00:00Z',
#    'content': "With the crypto market down a jaw-dropping 41% to $1.3 trillion year to date, this isn't a correction -- it's a crash. But while it's tempting to rush for the exits, this might turn into an opportuni… [+2952 chars]"},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'msmash',
#    'title': "FTX CEO Sam Bankman-Fried Says Likening Crypto Yield Farming To Ponzi Scheme a 'Reasonable Response'",
#    'description': 'Sam Bankman-Fried, chief executive and founder of Bahama-based crypto-exchange FTX and one of the most influential people in crypto, offered his insights into yield farming, projects that deliver tokens to buyers for staking. An excerpt from the podcast: Bloo…',
#    'url': 'https://news.slashdot.org/story/22/04/25/1648233/ftx-ceo-sam-bankman-fried-says-likening-crypto-yield-farming-to-ponzi-scheme-a-reasonable-response',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/money_64.png',
#    'publishedAt': '2022-04-25T16:48:00Z',
#    'content': "Bloomberg's Levine: Can you give me an intuitive understanding of farming? I mean, like to me, farming is like you sell some structured puts and collect premium, but perhaps there's a more sophistica… [+3425 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'rhouston@businessinsider.com (Rickie Houston, CEPF)',
#    'title': 'Coinbase vs. Coinbase Pro: How to choose between the basic and advanced crypto accounts',
#    'description': 'The basic Coinbase account best suits beginners, but advanced traders can upgrade to Coinbase Pro without any extra fees to get more tools and data.',
#    'url': 'https://www.businessinsider.com/personal-finance/coinbase-vs-coinbase-pro',
#    'urlToImage': 'https://i.insider.com/62854eb9e19cda0018867e4c?width=1200&format=jpeg',
#    'publishedAt': '2022-05-18T20:49:01Z',
#    'content': 'Bottom line:\xa0The basic Coinbase account best suits beginner and intermediate-level traders who want a simple interface and access to a variety of crypto products. Coinbase Pro, on the other hand, is … [+5803 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'insider@insider.com (Hanna Horvath)',
#    'title': '3 things to consider before adding bitcoin to your retirement portfolio, according to a financial planner',
#    'description': 'If you want to add bitcoin to your retirement portfolio, be sure you understand the risks involved and consider how close you are to retiring.',
#    'url': 'https://www.businessinsider.com/personal-finance/things-to-consider-before-adding-bitcoin-retirement-2022-5',
#    'urlToImage': 'https://i.insider.com/628254239147a30018b4854b?width=1200&format=jpeg',
#    'publishedAt': '2022-05-16T14:57:15Z',
#    'content': "What was once a niche investment is now becoming mainstream a vast majority of adults have at least heard about cryptocurrency, and 16% say they've invested or traded crypto. Now, the investment may … [+4441 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'prosen@insider.com (Phil Rosen)',
#    'title': '10 things before the opening bell',
#    'description': "Wall Street banks are warning of more uncertainty ahead, and they gave their stock recommendations. This and more, in today's opening bell newsletter.",
#    'url': 'https://www.businessinsider.com/10-things-before-the-opening-bell-may-2-2022-4',
#    'urlToImage': 'https://i.insider.com/622b992029e90c0019088910?width=1200&format=jpeg',
#    'publishedAt': '2022-05-02T10:00:00Z',
#    'content': "Welcome back readers. There's little indication that inflation is going away soon, and Wall Street is worried it could linger into next year and bring turmoil to the market. Today we're going over a … [+4502 chars]"}]}

# %%
# Create the Bitcoin sentiment scores DataFrame
btc_sentiments = []

for article in btc_articles["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        btc_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
# Create DataFrame
btc_ss_df = pd.DataFrame(btc_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
btc_ss_df = btc_ss_df[cols]

btc_ss_df.head()
# Out:
#          date                                               text  compound  \
# 0  2022-05-10  Now, even though there are a number of women-f...    0.0772
# 1  2022-05-04  A Bitcoin mining site powered by otherwise los...   -0.0516
# 2  2022-05-02  Warren Buffett has always been a bitcoin skept...   -0.3269
# 3  2022-05-16  As a kid, I remember when my father tried to u...    0.3818
# 4  2022-05-09  Image source, Getty Images\r\nThe value of Bit...    0.3400
#
#    positive  negative  neutral
# 0     0.036     0.000    0.964
# 1     0.056     0.061    0.882
# 2     0.085     0.143    0.772
# 3     0.114     0.052    0.833
# 4     0.072     0.000    0.928

# %%
# Create the Ethereum sentiment scores DataFrame
eth_sentiments = []

for article in eth_articles["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        eth_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
# Create DataFrame
eth_ss_df = pd.DataFrame(eth_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
eth_ss_df = eth_ss_df[cols]

eth_ss_df.head()
# Out:
#          date                                               text  compound  \
# 0  2022-05-10  Meta has revealed more of how NFTs will work o...    0.6486
# 1  2022-05-02  A multi-billion dollar cryptocurrency company ...   -0.2263
# 2  2022-05-04  When Bored Ape Yacht Club creators Yuga Labs a...   -0.2732
# 3  2022-04-26  April 26 (Reuters) - Ether has promised to do ...    0.5346
# 4  2022-04-26  Ethereum is preparing for an upgrade thats bee...    0.2716
#
#    positive  negative  neutral
# 0     0.135     0.000    0.865
# 1     0.046     0.075    0.879
# 2     0.000     0.055    0.945
# 3     0.142     0.000    0.858
# 4     0.065     0.000    0.935

# %%
# Describe the Bitcoin Sentiment
btc_ss_df.describe()
# Out:
#          compound    positive    negative     neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean    -0.032648    0.052250    0.060010    0.887750
# std      0.429843    0.065469    0.074539    0.091787
# min     -0.831600    0.000000    0.000000    0.557000
# 25%     -0.381800    0.000000    0.000000    0.839500
# 50%      0.000000    0.018000    0.046500    0.897500
# 75%      0.323650    0.081250    0.094750    0.951250
# max      0.865500    0.263000    0.299000    1.000000

# %%
# Describe the Ethereum Sentiment
eth_ss_df.describe()
# Out:
#          compound    positive    negative     neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.087897    0.078360    0.048440    0.873250
# std      0.477614    0.089021    0.060292    0.090506
# min     -0.836000    0.000000    0.000000    0.622000
# 25%     -0.284450    0.000000    0.000000    0.825000
# 50%      0.000000    0.062000    0.037000    0.881500
# 75%      0.437950    0.127250    0.075000    0.935500
# max      0.952000    0.378000    0.299000    1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Ethereum had the highest mean positive score of 0.078360, compared to Bitcoin's 0.052250.
#
# Q: Which coin had the highest compound score?
#
# A: Ethereum had the highest compound score of 0.952000, compared to Bitcoin's 0.865500. Further, Ethereum and Bitcoin both had identical maximum negative scores of 0.299000.
#
# Q. Which coin had the highest positive score?
#
# A: Ethereum had the highest positive score of 0.378000, compared to Bitcoin's 0.263000.

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re
import nltk
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Owner\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Owner\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Owner\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()

# Create a list of stopwords
sw = set(stopwords.words('english'))
print(stopwords.words('english'))

# Expand the default stopwords list if necessary
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    
    # Remove the punctuation from text 
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', text) 
    
    # Create a tokenized list of the words (creating object out of text)
    re_words = word_tokenize(re_clean)
    
    
    # Lemmatize words into root words
    result = [lemmatizer.lemmatize(word) for word in re_words]
   
    # Convert the words to lowercase
    tokens = [word.lower() for word in re_words if word.lower() not in sw]
    
    # Remove the stop words
    # Performed above 
    
    return tokens

# %%
# Create a new tokens column for Bitcoin 
btc_ss_df['tokens']= btc_ss_df.text.apply(tokenizer)
btc_ss_df
# Out:
#           date                                               text  compound  \
# 0   2022-05-10  Now, even though there are a number of women-f...    0.0772
# 1   2022-05-04  A Bitcoin mining site powered by otherwise los...   -0.0516
# 2   2022-05-02  Warren Buffett has always been a bitcoin skept...   -0.3269
# 3   2022-05-16  As a kid, I remember when my father tried to u...    0.3818
# 4   2022-05-09  Image source, Getty Images\r\nThe value of Bit...    0.3400
# ..         ...                                                ...       ...
# 95  2022-05-02  Warren Buffett and Charlie Munger revealed the...   -0.6486
# 96  2022-04-26  Whats happening in the blockchain industry thi...    0.0000
# 97  2022-04-26  Whats happening in the blockchain industry thi...    0.0000
# 98  2022-05-13  A look at the day ahead in markets from Dhara ...    0.6249
# 99  2022-04-27  HAVANA, April 27 (Reuters) - The Cuban central...    0.5994
#
#     positive  negative  neutral  \
# 0      0.036     0.000    0.964
# 1      0.056     0.061    0.882
# 2      0.085     0.143    0.772
# 3      0.114     0.052    0.833
# 4      0.072     0.000    0.928
# ..       ...       ...      ...
# 95     0.000     0.159    0.841
# 96     0.000     0.000    1.000
# 97     0.000     0.000    1.000
# 98     0.124     0.000    0.876
# 99     0.140     0.000    0.860
#
#                                                tokens
# 0   [even, though, number, womenfocused, crypto, s...
# 1   [bitcoin, mining, site, powered, otherwise, lo...
# 2   [warren, buffett, always, bitcoin, skeptic, bi...
# 3   [kid, remember, father, tried, use, broom, han...
# 4   [image, source, getty, imagesthe, value, bitco...
# ..                                                ...
# 95  [warren, buffett, charlie, munger, revealed, b...
# 96  [whats, happening, blockchain, industry, year,...
# 97  [whats, happening, blockchain, industry, year,...
# 98  [look, day, ahead, markets, dhara, ranasinghea...
# 99  [havana, april, reuters, cuban, central, bank,...
#
# [100 rows x 7 columns]

# %%
# Create a new tokens column for Ethereum
eth_ss_df['tokens']= eth_ss_df.text.apply(tokenizer)
eth_ss_df
# Out:
#           date                                               text  compound  \
# 0   2022-05-10  Meta has revealed more of how NFTs will work o...    0.6486
# 1   2022-05-02  A multi-billion dollar cryptocurrency company ...   -0.2263
# 2   2022-05-04  When Bored Ape Yacht Club creators Yuga Labs a...   -0.2732
# 3   2022-04-26  April 26 (Reuters) - Ether has promised to do ...    0.5346
# 4   2022-04-26  Ethereum is preparing for an upgrade thats bee...    0.2716
# ..         ...                                                ...       ...
# 95  2022-05-17  With the crypto market down a jaw-dropping 41%...   -0.2144
# 96  2022-04-25  Bloomberg's Levine: Can you give me an intuiti...    0.3612
# 97  2022-05-18  Bottom line: The basic Coinbase account best s...    0.8271
# 98  2022-05-16  What was once a niche investment is now becomi...    0.0000
# 99  2022-05-02  Welcome back readers. There's little indicatio...   -0.1779
#
#     positive  negative  neutral  \
# 0      0.135     0.000    0.865
# 1      0.046     0.075    0.879
# 2      0.000     0.055    0.945
# 3      0.142     0.000    0.858
# 4      0.065     0.000    0.935
# ..       ...       ...      ...
# 95     0.000     0.050    0.950
# 96     0.101     0.000    0.899
# 97     0.231     0.000    0.769
# 98     0.000     0.000    1.000
# 99     0.076     0.118    0.806
#
#                                                tokens
# 0   [meta, revealed, nfts, work, instagram, usbase...
# 1   [multibillion, dollar, cryptocurrency, company...
# 2   [bored, ape, yacht, club, creators, yuga, labs...
# 3   [april, reuters, ether, promised, better, prom...
# 4   [ethereum, preparing, upgrade, thats, describe...
# ..                                                ...
# 95  [crypto, market, jawdropping, trillion, year, ...
# 96  [bloombergs, levine, give, intuitive, understa...
# 97  [bottom, linethe, basic, coinbase, account, be...
# 98  [niche, investment, becoming, mainstream, vast...
# 99  [welcome, back, readers, theres, little, indic...
#
# [100 rows x 7 columns]

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Create variable for Bitcoin tokens column 
btc_tokens = btc_ss_df['tokens']

# Combine tokens from list of lists into one large list 
btc_tokens_list = []
for sublist in btc_tokens:
    for item in sublist:
        btc_tokens_list.append(item)
        
# Display btc_tokens_list
btc_tokens_list
# Out:
# ['even',
#  'though',
#  'number',
#  'womenfocused',
#  'crypto',
#  'spaces',
#  'odeniran',
#  'says',
#  'women',
#  'still',
#  'underrepresented',
#  'ive',
#  'spaces',
#  'im',
#  'black',
#  'person',
#  'woman',
#  'b',
#  'chars',
#  'bitcoin',
#  'mining',
#  'site',
#  'powered',
#  'otherwise',
#  'lost',
#  'gas',
#  'oil',
#  'well',
#  'near',
#  'linden',
#  'texas',
#  'april',
#  'th',
#  'photo',
#  'francois',
#  'picardafp',
#  'via',
#  'getty',
#  'images',
#  'corporate',
#  'climate',
#  'hype',
#  'fl',
#  'chars',
#  'warren',
#  'buffett',
#  'always',
#  'bitcoin',
#  'skeptic',
#  'billionaire',
#  'investor',
#  'harsh',
#  'words',
#  'yet',
#  'cryptocurrency',
#  'weekend',
#  'buffett',
#  'made',
#  'clear',
#  'opposition',
#  'crypt',
#  'chars',
#  'kid',
#  'remember',
#  'father',
#  'tried',
#  'use',
#  'broom',
#  'handle',
#  'last',
#  'ditch',
#  'effort',
#  'support',
#  'roof',
#  'collapsing',
#  'weight',
#  'nearly',
#  'three',
#  'feet',
#  'snow',
#  'guess',
#  'well',
#  'chars',
#  'image',
#  'source',
#  'getty',
#  'imagesthe',
#  'value',
#  'bitcoin',
#  'continued',
#  'fall',
#  'weekend',
#  'dropped',
#  'according',
#  'coinbase',
#  'cryptocurrency',
#  'exchangethe',
#  'worlds',
#  'largest',
#  'cryp',
#  'chars',
#  'youve',
#  'ever',
#  'felt',
#  'like',
#  'introducing',
#  'vegasstyle',
#  'odds',
#  'retirement',
#  'plan',
#  'youre',
#  'finally',
#  'lucklast',
#  'week',
#  'fidelity',
#  'investments',
#  'announced',
#  'would',
#  'allow',
#  'investors',
#  'put',
#  'part',
#  'chars',
#  'cryptocurrency',
#  'mixers',
#  'sometimes',
#  'used',
#  'help',
#  'online',
#  'criminals',
#  'launder',
#  'stolen',
#  'money',
#  'hiding',
#  'true',
#  'origins',
#  'us',
#  'treasury',
#  'ready',
#  'clamp',
#  'hostile',
#  'government',
#  'chars',
#  'may',
#  'reuters',
#  'bitcoin',
#  'fell',
#  'gmt',
#  'wednesday',
#  'losing',
#  'previous',
#  'closebitcoin',
#  'worlds',
#  'biggest',
#  'bestknown',
#  'cryptocurrency',
#  'fro',
#  'chars',
#  'may',
#  'reuters',
#  'bitcoin',
#  'rose',
#  'wednesday',
#  'adding',
#  'previous',
#  'closebitcoin',
#  'worlds',
#  'biggest',
#  'bestknown',
#  'cryptocurrency',
#  'years',
#  'low',
#  'chars',
#  'april',
#  'reuters',
#  'bitcoin',
#  'dropped',
#  'tuesday',
#  'previous',
#  'closebitcoin',
#  'worlds',
#  'biggest',
#  'bestknown',
#  'cryptocurrency',
#  'years',
#  'low',
#  'chars',
#  'posted',
#  'bitcoins',
#  'dramatic',
#  'drop',
#  'new',
#  'way',
#  'pay',
#  'luxury',
#  'gucci',
#  'handbag',
#  'round',
#  'weeks',
#  'big',
#  'stories',
#  'cryptocurrencies',
#  'kristy',
#  'kilburn',
#  'reports',
#  'btc',
#  'fell',
#  'lowest',
#  'level',
#  'since',
#  'last',
#  'july',
#  'prices',
#  'dropped',
#  'start',
#  'week',
#  'selloff',
#  'cryptocurrency',
#  'started',
#  'last',
#  'week',
#  'following',
#  'feds',
#  'decision',
#  'hike',
#  'interest',
#  'rates',
#  'b',
#  'chars',
#  'may',
#  'reuters',
#  'bitcoin',
#  'dropped',
#  'gmt',
#  'monday',
#  'losing',
#  'previous',
#  'closebitcoin',
#  'worlds',
#  'biggest',
#  'bestknown',
#  'cryptocurrency',
#  'chars',
#  'dogecoiners',
#  'unite',
#  'movie',
#  'theater',
#  'chain',
#  'amc',
#  'welcomed',
#  'cryptocurrencies',
#  'payment',
#  'options',
#  'online',
#  'mobile',
#  'purchases',
#  'tweet',
#  'april',
#  'amc',
#  'ceo',
#  'adam',
#  'aron',
#  'announced',
#  'moviego',
#  'chars',
#  'mexican',
#  'restaurant',
#  'north',
#  'london',
#  'weeks',
#  'ago',
#  'handful',
#  'smalltime',
#  'remarkably',
#  'discerning',
#  'retail',
#  'cryptocurrency',
#  'investors',
#  'predicted',
#  'terra',
#  'luna',
#  'would',
#  'crash',
#  'several',
#  'w',
#  'chars',
#  'may',
#  'reuters',
#  'bitcoin',
#  'scant',
#  'experience',
#  'rising',
#  'interest',
#  'rates',
#  'posing',
#  'perils',
#  'investors',
#  'looking',
#  'capitalize',
#  'dramatic',
#  'dropthe',
#  'cryptocurrency',
#  'tanked',
#  'along',
#  'ris',
#  'chars',
#  'central',
#  'african',
#  'republic',
#  'adopted',
#  'bitcoin',
#  'legal',
#  'tender',
#  'making',
#  'second',
#  'nation',
#  'world',
#  'el',
#  'salvador',
#  'wednesday',
#  'president',
#  'faustin',
#  'archange',
#  'touaderas',
#  'office',
#  'chars',
#  'sam',
#  'bankmanfried',
#  'founder',
#  'digital',
#  'asset',
#  'exchange',
#  'ftx',
#  'said',
#  'proof',
#  'work',
#  'system',
#  'validating',
#  'blockchain',
#  'transactions',
#  'underpins',
#  'bitcoin',
#  'capable',
#  'scaling',
#  'cope',
#  'chars',
#  'el',
#  'salvador',
#  'became',
#  'first',
#  'country',
#  'make',
#  'bitcoin',
#  'legal',
#  'tender',
#  'september',
#  'lost',
#  'million',
#  'cryptocurrency',
#  'bitcoin',
#  'plummeted',
#  'alltime',
#  'high',
#  'thursdaypreside',
#  'chars',
#  'bangui',
#  'april',
#  'reuters',
#  'central',
#  'african',
#  'republics',
#  'adoption',
#  'bitcoin',
#  'many',
#  'worlds',
#  'largest',
#  'economies',
#  'stay',
#  'wary',
#  'puzzled',
#  'cryptocurrency',
#  'world',
#  'residents',
#  'gol',
#  'chars',
#  'bangui',
#  'april',
#  'reuters',
#  'central',
#  'african',
#  'republic',
#  'adopted',
#  'bitcoin',
#  'official',
#  'currency',
#  'presidency',
#  'said',
#  'wednesday',
#  'becoming',
#  'first',
#  'country',
#  'africa',
#  'second',
#  'wo',
#  'chars',
#  'posted',
#  'senior',
#  'government',
#  'official',
#  'says',
#  'south',
#  'africas',
#  'green',
#  'transition',
#  'need',
#  'funding',
#  'one',
#  'trillion',
#  'rand',
#  'zambias',
#  'president',
#  'says',
#  'country',
#  'close',
#  'finding',
#  'investor',
#  'mopani',
#  'chars',
#  'posted',
#  'value',
#  'worlds',
#  'biggest',
#  'cryptocurrencies',
#  'sliding',
#  'line',
#  'global',
#  'markets',
#  'particular',
#  'techheavy',
#  'nasdaq',
#  'tom',
#  'scally',
#  'posted',
#  'cryptocurrencies',
#  'nursed',
#  'large',
#  'losses',
#  'early',
#  'friday',
#  'bitcoin',
#  'set',
#  'record',
#  'losing',
#  'streak',
#  'collapse',
#  'terrausd',
#  'socalled',
#  'stablecoin',
#  'rippled',
#  'markets',
#  'may',
#  'reuters',
#  'block',
#  'inc',
#  'sqn',
#  'payments',
#  'company',
#  'led',
#  'jack',
#  'dorsey',
#  'thursday',
#  'reported',
#  'loss',
#  'first',
#  'quarter',
#  'demand',
#  'bitcoin',
#  'softened',
#  'due',
#  'decline',
#  'cryptocurrency',
#  'prices',
#  'chars',
#  'posted',
#  'value',
#  'worlds',
#  'biggest',
#  'cryptocurrencies',
#  'sliding',
#  'line',
#  'global',
#  'markets',
#  'particular',
#  'techheavy',
#  'nasdaq',
#  'hong',
#  'kong',
#  'may',
#  'reuters',
#  'cryptocurrencies',
#  'resumed',
#  'slide',
#  'monday',
#  'giving',
#  'gains',
#  'eked',
#  'weekend',
#  'regulators',
#  'continued',
#  'circleeuropean',
#  'officials',
#  'reiterated',
#  'chars',
#  'zurich',
#  'april',
#  'reuters',
#  'swiss',
#  'national',
#  'bank',
#  'buying',
#  'holding',
#  'bitcoin',
#  'reserve',
#  'currency',
#  'chairman',
#  'thomas',
#  'jordan',
#  'said',
#  'central',
#  'banks',
#  'annual',
#  'general',
#  'meeting',
#  'friday',
#  'chars',
#  'hong',
#  'kong',
#  'may',
#  'reuters',
#  'falling',
#  'commodity',
#  'prices',
#  'dragged',
#  'australian',
#  'canadian',
#  'currencies',
#  'lower',
#  'tuesday',
#  'although',
#  'dollar',
#  'steady',
#  'majors',
#  'bitcoin',
#  'continue',
#  'chars',
#  'posted',
#  'bitcoins',
#  'record',
#  'losing',
#  'streak',
#  'warhols',
#  'record',
#  'sale',
#  'round',
#  'big',
#  'numbers',
#  'business',
#  'finance',
#  'week',
#  'may',
#  'olivia',
#  'chan',
#  'reports',
#  'technological',
#  'advancement',
#  'surrounds',
#  'cryptocurrencies',
#  'evolves',
#  'rapidly',
#  'platforms',
#  'day',
#  'day',
#  'look',
#  'ways',
#  'present',
#  'within',
#  'emerging',
#  'universes',
#  'become',
#  'dail',
#  'chars',
#  'san',
#  'salvadornew',
#  'york',
#  'may',
#  'reuters',
#  'el',
#  'salvadors',
#  'big',
#  'bet',
#  'bitcoin',
#  'central',
#  'american',
#  'nation',
#  'buying',
#  'since',
#  'september',
#  'soured',
#  'recent',
#  'weeks',
#  'cryptocurrency',
#  'rout',
#  'shav',
#  'chars',
#  'excited',
#  'bring',
#  'transform',
#  'back',
#  'inperson',
#  'july',
#  'virtually',
#  'july',
#  'join',
#  'ai',
#  'data',
#  'leaders',
#  'insightful',
#  'talks',
#  'exciting',
#  'networking',
#  'opportunities',
#  'register',
#  'todaysome',
#  'te',
#  'chars',
#  'may',
#  'reuters',
#  'cryptocurrency',
#  'exchange',
#  'ftxs',
#  'founder',
#  'said',
#  'bitcoin',
#  'future',
#  'payments',
#  'network',
#  'criticized',
#  'digital',
#  'currency',
#  'inefficiency',
#  'high',
#  'environmental',
#  'cost',
#  'chars',
#  'cryptocurrency',
#  'prices',
#  'amid',
#  'slew',
#  'grim',
#  'economic',
#  'news',
#  'potential',
#  'factors',
#  'disparate',
#  'war',
#  'ukraine',
#  'rising',
#  'inflation',
#  'feds',
#  'corresponding',
#  'interest',
#  'rate',
#  'hikes',
#  'pric',
#  'chars',
#  'days',
#  'ago',
#  'bitcoin',
#  'sold',
#  'price',
#  'drop',
#  'third',
#  'drop',
#  'happened',
#  'week',
#  'bitcoin',
#  'ethereum',
#  'major',
#  'cryptocurrencies',
#  'fallen',
#  'sharp',
#  'chars',
#  'investors',
#  'arent',
#  'flocking',
#  'el',
#  'salvadors',
#  'bitcoin',
#  'bond',
#  'fact',
#  'cryptobacked',
#  'offering',
#  'hasnt',
#  'drawn',
#  'single',
#  'buyer',
#  'according',
#  'bloombergmillennial',
#  'president',
#  'nayib',
#  'bukele',
#  'seeking',
#  'chars',
#  'us',
#  'stock',
#  'index',
#  'futures',
#  'rallied',
#  'tuesday',
#  'suggesting',
#  'modest',
#  'recovery',
#  'open',
#  'previous',
#  'days',
#  'rout',
#  'drove',
#  'sampp',
#  'oneyear',
#  'low',
#  'investors',
#  'bought',
#  'back',
#  'technology',
#  'stoc',
#  'chars',
#  'hong',
#  'kong',
#  'may',
#  'reuters',
#  'bitcoin',
#  'fell',
#  'lowest',
#  'level',
#  'since',
#  'january',
#  'monday',
#  'slumping',
#  'equity',
#  'markets',
#  'continued',
#  'hurt',
#  'cryptocurrencies',
#  'currently',
#  'trading',
#  'line',
#  'socalled',
#  'chars',
#  'mondaymorning',
#  'bitcoin',
#  'drop',
#  'marks',
#  'steep',
#  'fall',
#  'since',
#  'alltime',
#  'high',
#  'november',
#  'bitcoin',
#  'isnt',
#  'digital',
#  'currency',
#  'taking',
#  'di',
#  'chars',
#  'microstrategy',
#  'fell',
#  'monday',
#  'lowest',
#  'level',
#  'since',
#  'stock',
#  'price',
#  'continues',
#  'closely',
#  'track',
#  'price',
#  'bitcoin',
#  'gets',
#  'closer',
#  'margin',
#  'call',
#  'levelbitcoin',
#  'dropped',
#  'chars',
#  'yesterday',
#  'forum',
#  'bitcoin',
#  'mexico',
#  'facing',
#  'future',
#  'held',
#  'senate',
#  'mexican',
#  'republic',
#  'order',
#  'analyze',
#  'trigger',
#  'growth',
#  'cryptocurrency',
#  'market',
#  'organized',
#  'senators',
#  'chars',
#  'hong',
#  'kong',
#  'may',
#  'reuters',
#  'terrausd',
#  'worlds',
#  'fourthlargest',
#  'stablecoin',
#  'lost',
#  'third',
#  'value',
#  'tuesday',
#  'spooking',
#  'cryptocurrency',
#  'investors',
#  'partly',
#  'contributing',
#  'bitcoins',
#  'tumble',
#  'belo',
#  'chars',
#  'secret',
#  'berkshire',
#  'hathaway',
#  'ownerceo',
#  'warren',
#  'buffett',
#  'arent',
#  'ardent',
#  'backers',
#  'bitcoin',
#  'years',
#  'ago',
#  'billionaire',
#  'investor',
#  'referred',
#  'cryptocurrency',
#  'rat',
#  'poison',
#  'chars',
#  'tesla',
#  'spacex',
#  'ceo',
#  'elon',
#  'musk',
#  'secured',
#  'billion',
#  'new',
#  'financing',
#  'commitments',
#  'fund',
#  'acquisition',
#  'twitter',
#  'including',
#  'several',
#  'procrypto',
#  'companies',
#  'cryptocurrency',
#  'exchange',
#  'binance',
#  'chars',
#  'editorial',
#  'independencewe',
#  'want',
#  'help',
#  'make',
#  'informed',
#  'decisions',
#  'links',
#  'page',
#  'clearly',
#  'marked',
#  'may',
#  'take',
#  'partner',
#  'website',
#  'may',
#  'result',
#  'us',
#  'earning',
#  'referral',
#  'commission',
#  'fo',
#  'chars',
#  'singapore',
#  'may',
#  'reuters',
#  'cryptocurrencies',
#  'nursed',
#  'large',
#  'losses',
#  'friday',
#  'bitcoin',
#  'pinned',
#  'set',
#  'record',
#  'losing',
#  'streak',
#  'collapse',
#  'terrausd',
#  'socalled',
#  'stablecoin',
#  'chars',
#  'londonnew',
#  'york',
#  'may',
#  'reuters',
#  'meltdown',
#  'terrausd',
#  'one',
#  'worlds',
#  'largest',
#  'stablecoins',
#  'rippled',
#  'cryptocurrency',
#  'markets',
#  'thursday',
#  'pushing',
#  'another',
#  'major',
#  'stablecoin',
#  'tether',
#  'chars',
#  'posted',
#  'cryptocurrency',
#  'investors',
#  'spooked',
#  'crashes',
#  'bitcoin',
#  'stablecoins',
#  'charley',
#  'cooper',
#  'managing',
#  'director',
#  'r',
#  'says',
#  'sector',
#  'still',
#  'small',
#  'make',
#  'significant',
#  'impact',
#  'tra',
#  'chars',
#  'ndjamena',
#  'may',
#  'reuters',
#  'central',
#  'africas',
#  'regional',
#  'banking',
#  'regulator',
#  'sent',
#  'reminder',
#  'friday',
#  'ban',
#  'use',
#  'cryptocurrencies',
#  'weeks',
#  'central',
#  'african',
#  'republic',
#  'membe',
#  'chars',
#  'may',
#  'reuters',
#  'guccis',
#  'highend',
#  'handbags',
#  'luxury',
#  'products',
#  'bought',
#  'using',
#  'cryptocurrencies',
#  'including',
#  'bitcoin',
#  'us',
#  'stores',
#  'italian',
#  'company',
#  'said',
#  'digital',
#  'currencies',
#  'chars',
#  'london',
#  'may',
#  ...]

# %%
# Generate the Bitcoin N-grams where N=2
btc_bigram = Counter(ngrams(btc_tokens_list, n=2))
print(dict(btc_bigram))
# Out:
# {('even', 'though'): 2, ('though', 'number'): 1, ('number', 'womenfocused'): 1, ('womenfocused', 'crypto'): 1, ('crypto', 'spaces'): 1, ('spaces', 'odeniran'): 1, ('odeniran', 'says'): 1, ('says', 'women'): 1, ('women', 'still'): 1, ('still', 'underrepresented'): 1, ('underrepresented', 'ive'): 1, ('ive', 'spaces'): 1, ('spaces', 'im'): 1, ('im', 'black'): 1, ('black', 'person'): 1, ('person', 'woman'): 1, ('woman', 'b'): 1, ('b', 'chars'): 3, ('chars', 'bitcoin'): 3, ('bitcoin', 'mining'): 3, ('mining', 'site'): 1, ('site', 'powered'): 1, ('powered', 'otherwise'): 1, ('otherwise', 'lost'): 1, ('lost', 'gas'): 1, ('gas', 'oil'): 1, ('oil', 'well'): 1, ('well', 'near'): 1, ('near', 'linden'): 1, ('linden', 'texas'): 1, ('texas', 'april'): 1, ('april', 'th'): 1, ('th', 'photo'): 1, ('photo', 'francois'): 1, ('francois', 'picardafp'): 1, ('picardafp', 'via'): 1, ('via', 'getty'): 1, ('getty', 'images'): 1, ('images', 'corporate'): 1, ('corporate', 'climate'): 1, ('climate', 'hype'): 1, ('hype', 'fl'): 1, ('fl', 'chars'): 1, ('chars', 'warren'): 2, ('warren', 'buffett'): 3, ('buffett', 'always'): 1, ('always', 'bitcoin'): 1, ('bitcoin', 'skeptic'): 1, ('skeptic', 'billionaire'): 1, ('billionaire', 'investor'): 2, ('investor', 'harsh'): 1, ('harsh', 'words'): 1, ('words', 'yet'): 1, ('yet', 'cryptocurrency'): 1, ('cryptocurrency', 'weekend'): 1, ('weekend', 'buffett'): 1, ('buffett', 'made'): 1, ('made', 'clear'): 1, ('clear', 'opposition'): 1, ('opposition', 'crypt'): 1, ('crypt', 'chars'): 2, ('chars', 'kid'): 1, ('kid', 'remember'): 1, ('remember', 'father'): 1, ('father', 'tried'): 1, ('tried', 'use'): 1, ('use', 'broom'): 1, ('broom', 'handle'): 1, ('handle', 'last'): 1, ('last', 'ditch'): 1, ('ditch', 'effort'): 1, ('effort', 'support'): 1, ('support', 'roof'): 1, ('roof', 'collapsing'): 1, ('collapsing', 'weight'): 1, ('weight', 'nearly'): 1, ('nearly', 'three'): 1, ('three', 'feet'): 1, ('feet', 'snow'): 1, ('snow', 'guess'): 1, ('guess', 'well'): 1, ('well', 'chars'): 1, ('chars', 'image'): 1, ('image', 'source'): 1, ('source', 'getty'): 1, ('getty', 'imagesthe'): 1, ('imagesthe', 'value'): 1, ('value', 'bitcoin'): 2, ('bitcoin', 'continued'): 1, ('continued', 'fall'): 1, ('fall', 'weekend'): 1, ('weekend', 'dropped'): 1, ('dropped', 'according'): 1, ('according', 'coinbase'): 1, ('coinbase', 'cryptocurrency'): 1, ('cryptocurrency', 'exchangethe'): 1, ('exchangethe', 'worlds'): 1, ('worlds', 'largest'): 4, ('largest', 'cryp'): 1, ('cryp', 'chars'): 1, ('chars', 'youve'): 1, ('youve', 'ever'): 1, ('ever', 'felt'): 1, ('felt', 'like'): 1, ('like', 'introducing'): 1, ('introducing', 'vegasstyle'): 1, ('vegasstyle', 'odds'): 1, ('odds', 'retirement'): 1, ('retirement', 'plan'): 1, ('plan', 'youre'): 1, ('youre', 'finally'): 1, ('finally', 'lucklast'): 1, ('lucklast', 'week'): 1, ('week', 'fidelity'): 1, ('fidelity', 'investments'): 1, ('investments', 'announced'): 1, ('announced', 'would'): 1, ('would', 'allow'): 1, ('allow', 'investors'): 1, ('investors', 'put'): 1, ('put', 'part'): 1, ('part', 'chars'): 1, ('chars', 'cryptocurrency'): 3, ('cryptocurrency', 'mixers'): 1, ('mixers', 'sometimes'): 1, ('sometimes', 'used'): 1, ('used', 'help'): 1, ('help', 'online'): 1, ('online', 'criminals'): 1, ('criminals', 'launder'): 1, ('launder', 'stolen'): 1, ('stolen', 'money'): 1, ('money', 'hiding'): 1, ('hiding', 'true'): 1, ('true', 'origins'): 1, ('origins', 'us'): 1, ('us', 'treasury'): 1, ('treasury', 'ready'): 1, ('ready', 'clamp'): 1, ('clamp', 'hostile'): 1, ('hostile', 'government'): 1, ('government', 'chars'): 1, ('chars', 'may'): 7, ('may', 'reuters'): 24, ('reuters', 'bitcoin'): 6, ('bitcoin', 'fell'): 2, ('fell', 'gmt'): 1, ('gmt', 'wednesday'): 1, ('wednesday', 'losing'): 1, ('losing', 'previous'): 2, ('previous', 'closebitcoin'): 4, ('closebitcoin', 'worlds'): 4, ('worlds', 'biggest'): 6, ('biggest', 'bestknown'): 4, ('bestknown', 'cryptocurrency'): 4, ('cryptocurrency', 'fro'): 1, ('fro', 'chars'): 1, ('bitcoin', 'ros ...

# %%
# Create variable for Ethereum tokens column 
eth_tokens = eth_ss_df['tokens']

# Combine token from list of lists into one large list 
eth_tokens_list = []
for sublist in eth_tokens:
    for item in sublist:
        eth_tokens_list.append(item)
        
# Display btc_tokens_list
eth_tokens_list
# Out:
# ['meta',
#  'revealed',
#  'nfts',
#  'work',
#  'instagram',
#  'usbased',
#  'test',
#  'show',
#  'youve',
#  'bought',
#  'created',
#  'free',
#  'connecting',
#  'instagram',
#  'account',
#  'compatible',
#  'digital',
#  'walle',
#  'chars',
#  'multibillion',
#  'dollar',
#  'cryptocurrency',
#  'company',
#  'apologised',
#  'users',
#  'sale',
#  'metaverse',
#  'land',
#  'sparked',
#  'frenzy',
#  'temporarily',
#  'brought',
#  'ethereum',
#  'cryptocurrencyyuga',
#  'labs',
#  'comp',
#  'chars',
#  'bored',
#  'ape',
#  'yacht',
#  'club',
#  'creators',
#  'yuga',
#  'labs',
#  'announced',
#  'otherside',
#  'nft',
#  'collection',
#  'would',
#  'launch',
#  'april',
#  'predicted',
#  'many',
#  'biggest',
#  'nft',
#  'launch',
#  'ever',
#  'otherside',
#  'upcoming',
#  'bore',
#  'chars',
#  'april',
#  'reuters',
#  'ether',
#  'promised',
#  'better',
#  'promised',
#  'go',
#  'next',
#  'level',
#  'edging',
#  'crypto',
#  'rivals',
#  'even',
#  'outshining',
#  'godfather',
#  'bitcoin',
#  'clocks',
#  'tickingthe',
#  'chars',
#  'ethereum',
#  'preparing',
#  'upgrade',
#  'thats',
#  'described',
#  'single',
#  'important',
#  'event',
#  'crypto',
#  'historythe',
#  'transition',
#  'would',
#  'overhaul',
#  'infrastructure',
#  'worlds',
#  'secondlargest',
#  'blockcha',
#  'chars',
#  'dogecoiners',
#  'unite',
#  'movie',
#  'theater',
#  'chain',
#  'amc',
#  'welcomed',
#  'cryptocurrencies',
#  'payment',
#  'options',
#  'online',
#  'mobile',
#  'purchases',
#  'tweet',
#  'april',
#  'amc',
#  'ceo',
#  'adam',
#  'aron',
#  'announced',
#  'moviego',
#  'chars',
#  'theres',
#  'new',
#  'metaverse',
#  'project',
#  'creators',
#  'bored',
#  'apes',
#  'yacht',
#  'club',
#  'nfts',
#  'last',
#  'night',
#  'held',
#  'virtual',
#  'land',
#  'sale',
#  'reports',
#  'bloomberg',
#  'raising',
#  'nearly',
#  'third',
#  'billion',
#  'dollarsat',
#  'ab',
#  'chars',
#  'editorial',
#  'independencewe',
#  'want',
#  'help',
#  'make',
#  'informed',
#  'decisions',
#  'links',
#  'page',
#  'clearly',
#  'marked',
#  'may',
#  'take',
#  'partner',
#  'website',
#  'may',
#  'result',
#  'us',
#  'earning',
#  'referral',
#  'commission',
#  'fo',
#  'chars',
#  'days',
#  'ago',
#  'bitcoin',
#  'sold',
#  'price',
#  'drop',
#  'third',
#  'drop',
#  'happened',
#  'week',
#  'bitcoin',
#  'ethereum',
#  'major',
#  'cryptocurrencies',
#  'fallen',
#  'sharp',
#  'chars',
#  'nvidia',
#  'launched',
#  'ampere',
#  'lite',
#  'hash',
#  'rate',
#  'lhr',
#  'graphics',
#  'card',
#  'feared',
#  'ethereum',
#  'antimining',
#  'limiter',
#  'world',
#  'knew',
#  'matter',
#  'time',
#  'someone',
#  'team',
#  'cracked',
#  'niceh',
#  'chars',
#  'may',
#  'reuters',
#  'bitcoin',
#  'rose',
#  'wednesday',
#  'adding',
#  'previous',
#  'closebitcoin',
#  'worlds',
#  'biggest',
#  'bestknown',
#  'cryptocurrency',
#  'years',
#  'low',
#  'chars',
#  'april',
#  'reuters',
#  'bitcoin',
#  'dropped',
#  'tuesday',
#  'previous',
#  'closebitcoin',
#  'worlds',
#  'biggest',
#  'bestknown',
#  'cryptocurrency',
#  'years',
#  'low',
#  'chars',
#  'may',
#  'reuters',
#  'bitcoin',
#  'fell',
#  'gmt',
#  'wednesday',
#  'losing',
#  'previous',
#  'closebitcoin',
#  'worlds',
#  'biggest',
#  'bestknown',
#  'cryptocurrency',
#  'fro',
#  'chars',
#  'may',
#  'reuters',
#  'bitcoin',
#  'dropped',
#  'gmt',
#  'monday',
#  'losing',
#  'previous',
#  'closebitcoin',
#  'worlds',
#  'biggest',
#  'bestknown',
#  'cryptocurrency',
#  'chars',
#  'ever',
#  'wanted',
#  'buy',
#  'nft',
#  'based',
#  'ethereum',
#  'would',
#  'pay',
#  'transaction',
#  'fee',
#  'register',
#  'blockchain',
#  'last',
#  'week',
#  'fee',
#  'skyrocketed',
#  'unprecedented',
#  'levelsso',
#  'might',
#  'ha',
#  'chars',
#  'posters',
#  'participatingnvidia',
#  'began',
#  'releasing',
#  'lhr',
#  'lite',
#  'hash',
#  'rate',
#  'graphics',
#  'cards',
#  'last',
#  'yearto',
#  'slow',
#  'cryptocurrency',
#  'mining',
#  'performance',
#  'make',
#  'less',
#  'appealing',
#  'nongamers',
#  'chars',
#  'btc',
#  'fell',
#  'lowest',
#  'level',
#  'since',
#  'last',
#  'july',
#  'prices',
#  'dropped',
#  'start',
#  'week',
#  'selloff',
#  'cryptocurrency',
#  'started',
#  'last',
#  'week',
#  'following',
#  'feds',
#  'decision',
#  'hike',
#  'interest',
#  'rates',
#  'b',
#  'chars',
#  'cryptocurrency',
#  'boom',
#  'past',
#  'years',
#  'helped',
#  'propel',
#  'newer',
#  'market',
#  'record',
#  'heights',
#  'digital',
#  'collectibles',
#  'known',
#  'nftsthe',
#  'craze',
#  'pushed',
#  'total',
#  'nft',
#  'sales',
#  'volume',
#  'billion',
#  'ov',
#  'chars',
#  'apecoin',
#  'native',
#  'cryptocurrency',
#  'ape',
#  'ecosystem',
#  'slid',
#  'monday',
#  'viciously',
#  'volatile',
#  'trading',
#  'sessiontokens',
#  'trading',
#  'per',
#  'token',
#  'presstime',
#  'crypto',
#  'often',
#  'linked',
#  'wit',
#  'chars',
#  'excited',
#  'bring',
#  'transform',
#  'back',
#  'inperson',
#  'july',
#  'virtually',
#  'july',
#  'join',
#  'ai',
#  'data',
#  'leaders',
#  'insightful',
#  'talks',
#  'exciting',
#  'networking',
#  'opportunities',
#  'register',
#  'todaya',
#  'coali',
#  'chars',
#  'image',
#  'source',
#  'getty',
#  'imagesthe',
#  'value',
#  'bitcoin',
#  'continued',
#  'fall',
#  'weekend',
#  'dropped',
#  'according',
#  'coinbase',
#  'cryptocurrency',
#  'exchangethe',
#  'worlds',
#  'largest',
#  'cryp',
#  'chars',
#  'advocates',
#  'believed',
#  'web',
#  'freedom',
#  'democracy',
#  'ownership',
#  'idealistic',
#  'version',
#  'web',
#  'built',
#  'users',
#  'theoretically',
#  'theyre',
#  'wrong',
#  'web',
#  'still',
#  'development',
#  'chars',
#  'may',
#  'reuters',
#  'guccis',
#  'highend',
#  'handbags',
#  'luxury',
#  'products',
#  'bought',
#  'using',
#  'cryptocurrencies',
#  'including',
#  'bitcoin',
#  'us',
#  'stores',
#  'italian',
#  'company',
#  'said',
#  'digital',
#  'currencies',
#  'chars',
#  'april',
#  'reuters',
#  'twitter',
#  'inc',
#  'twtrn',
#  'digital',
#  'payments',
#  'processor',
#  'stripe',
#  'inc',
#  'pilot',
#  'cryptocurrency',
#  'payouts',
#  'select',
#  'users',
#  'social',
#  'media',
#  'sites',
#  'content',
#  'monetization',
#  'products',
#  'co',
#  'chars',
#  'saturday',
#  'yuga',
#  'labsthe',
#  'company',
#  'behind',
#  'bored',
#  'apes',
#  'yacht',
#  'club',
#  'nft',
#  'collection',
#  'launched',
#  'sale',
#  'otherdeeds',
#  'nfts',
#  'digital',
#  'land',
#  'related',
#  'upcoming',
#  'metaverse',
#  'gaming',
#  'project',
#  'c',
#  'chars',
#  'pegged',
#  'dollar',
#  'terras',
#  'ust',
#  'coin',
#  'trading',
#  'centsillustration',
#  'alex',
#  'castroits',
#  'crushing',
#  'days',
#  'terra',
#  'project',
#  'week',
#  'unforgiving',
#  'cryptoc',
#  'chars',
#  'us',
#  'department',
#  'justice',
#  'accused',
#  'two',
#  'european',
#  'citizens',
#  'money',
#  'laundering',
#  'role',
#  'helping',
#  'north',
#  'korean',
#  'government',
#  'organize',
#  'cryptocurrency',
#  'conference',
#  'one',
#  'men',
#  'chars',
#  'may',
#  'tough',
#  'month',
#  'cryptocurrencies',
#  'especially',
#  'luna',
#  'bitcoin',
#  'ether',
#  'respectively',
#  'luna',
#  'token',
#  'cratered',
#  'month',
#  'ago',
#  'fraction',
#  'chars',
#  'terrausd',
#  'algorithmic',
#  'stablecoin',
#  'whose',
#  'collapse',
#  'prompted',
#  'multibilliondollar',
#  'selloff',
#  'across',
#  'crypto',
#  'markets',
#  'turned',
#  'blockchain',
#  'delisted',
#  'major',
#  'exchanges',
#  'effect',
#  'shutt',
#  'chars',
#  'disclaimer',
#  'invested',
#  'savings',
#  'stable',
#  'cryptocurrencies',
#  'bitcoin',
#  'ethereum',
#  'etclets',
#  'talk',
#  'slot',
#  'games',
#  'first',
#  'designed',
#  'way',
#  'w',
#  'chars',
#  'bottom',
#  'line',
#  'etoro',
#  'best',
#  'choice',
#  'cryptofocused',
#  'communityoriented',
#  'traders',
#  'offers',
#  'assets',
#  'including',
#  'automated',
#  'investing',
#  'options',
#  'like',
#  'copyportfolios',
#  'copytrader',
#  'system',
#  'chars',
#  'hong',
#  'kong',
#  'may',
#  'reuters',
#  'bitcoin',
#  'fell',
#  'lowest',
#  'level',
#  'since',
#  'january',
#  'monday',
#  'slumping',
#  'equity',
#  'markets',
#  'continued',
#  'hurt',
#  'cryptocurrencies',
#  'currently',
#  'trading',
#  'line',
#  'socalled',
#  'chars',
#  'representations',
#  'cryptocurrencies',
#  'bitcoin',
#  'ethereum',
#  'dogecoin',
#  'ripple',
#  'litecoin',
#  'placed',
#  'pc',
#  'motherboard',
#  'illustration',
#  'taken',
#  'june',
#  'reutersdado',
#  'ruvicillustrationfile',
#  'photofi',
#  'chars',
#  'contagion',
#  'spreading',
#  'stock',
#  'markets',
#  'investors',
#  'see',
#  'one',
#  'thing',
#  'worry',
#  'massive',
#  'selloff',
#  'spread',
#  'like',
#  'wildfire',
#  'world',
#  'cryptocurrenciesphoto',
#  'reutersdado',
#  'ruvicfil',
#  'chars',
#  'read',
#  'jack',
#  'dorsey',
#  'cofounder',
#  'twitter',
#  'claims',
#  'regret',
#  'role',
#  'creating',
#  'centralized',
#  'internet',
#  'given',
#  'know',
#  'divisiveness',
#  'violence',
#  'misinformation',
#  'social',
#  'chars',
#  'conservative',
#  'party',
#  'leadership',
#  'candidate',
#  'pierre',
#  'poilievre',
#  'personal',
#  'financial',
#  'interest',
#  'cryptocurrencies',
#  'promoted',
#  'campaign',
#  'hedge',
#  'inflationthe',
#  'ottawaarea',
#  'chars',
#  'last',
#  'week',
#  'senate',
#  'republic',
#  'mexico',
#  'organized',
#  'forum',
#  'raise',
#  'awareness',
#  'use',
#  'cryptocurrencies',
#  'analyze',
#  'trigger',
#  'growth',
#  'senators',
#  'must',
#  'seen',
#  'something',
#  'chars',
#  'cryptocurrency',
#  'industry',
#  'isnt',
#  'buying',
#  'selling',
#  'coins',
#  'tokens',
#  'myriad',
#  'things',
#  'crypto',
#  'thousands',
#  'crypto',
#  'enthusiasts',
#  'want',
#  'take',
#  'passion',
#  'ste',
#  'chars',
#  'dirk',
#  'hohndel',
#  'gets',
#  'frequentlymentioned',
#  'slashdot',
#  'early',
#  'contributor',
#  'linux',
#  'last',
#  'five',
#  'years',
#  'chief',
#  'open',
#  'source',
#  'officer',
#  'vice',
#  'president',
#  'vmware',
#  'hes',
#  'also',
#  'chars',
#  'mondaymorning',
#  'bitcoin',
#  'drop',
#  'marks',
#  'steep',
#  'fall',
#  'since',
#  'alltime',
#  'high',
#  'november',
#  'bitcoin',
#  'isnt',
#  'digital',
#  'currency',
#  'taking',
#  'di',
#  'chars',
#  'past',
#  'years',
#  'tech',
#  'world',
#  'experienced',
#  'rapid',
#  'evolution',
#  'spearheaded',
#  'large',
#  'part',
#  'blockchain',
#  'evolution',
#  'precipice',
#  'revolution',
#  'nfts',
#  'metaverse',
#  'chars',
#  'know',
#  'known',
#  'use',
#  'blockchain',
#  'technology',
#  'cryptocurrencyof',
#  'course',
#  'isnt',
#  'though',
#  'weve',
#  'seen',
#  'nfts',
#  'nonfungible',
#  'tokens',
#  'part',
#  'ethereum',
#  'chars',
#  'investment',
#  'firm',
#  'bought',
#  'acres',
#  'real',
#  'estate',
#  'us',
#  'million',
#  'normally',
#  'would',
#  'make',
#  'headlines',
#  'case',
#  'land',
#  'virtual',
#  'existed',
#  'metaverse',
#  'pla',
#  'chars',
#  'digital',
#  'investors',
#  'withdrawn',
#  'savings',
#  'stablecoin',
#  'tether',
#  'worth',
#  'bn',
#  'since',
#  'cryptocurrency',
#  'crisis',
#  'began',
#  'last',
#  'week',
#  'suggesting',
#  'company',
#  'paid',
#  'sum',
#  'almost',
#  'twice',
#  'total',
#  'cash',
#  'h',
#  'chars',
#  'crypto',
#  'crash',
#  'reduce',
#  'sectors',
#  'climate',
#  'impact',
#  'time',
#  'soon',
#  'economist',
#  'warned',
#  'even',
#  'though',
#  'environmental',
#  'footprint',
#  'digital',
#  'currencies',
#  'theory',
#  'set',
#  'market',
#  'valu',
#  'chars',
#  'looked',
#  'inside',
#  'blockchain',
#  'art',
#  'purchased',
#  'fucking',
#  'found',
#  'url',
#  'returns',
#  'im',
#  'sure',
#  'resell',
#  'paid',
#  'certainly',
#  'chars',
#  'tether',
#  'worlds',
#  'biggest',
#  'stablecoin',
#  'tumbled',
#  'low',
#  'thursday',
#  'panic',
#  'spread',
#  'across',
#  'crypto',
#  'markets',
#  'dramatic',
#  'plunge',
#  'terrausd',
#  'luna',
#  'tokensthe',
#  'stablecoin',
#  'fell',
#  'chars',
#  'earlier',
#  'year',
#  'meta',
#  'ceo',
#  'mark',
#  'zuckerberg',
#  'revealed',
#  'company',
#  'toying',
#  'idea',
#  'bringing',
#  'nfts',
#  'socialmedia',
#  'platform',
#  'instagram',
#  'though',
#  'declined',
#  'comment',
#  'exactly',
#  'whe',
#  'chars',
#  'cryptocurrency',
#  'world',
#  'rough',
#  'may',
#  'farsince',
#  'start',
#  'month',
#  'cryptocurrency',
#  'lost',
#  'billion',
#  'value',
#  'bitcoin',
#  'dropped',
#  'prices',
#  'havent',
#  'seen',
#  'since',
#  'briefl',
#  'chars',
#  'web',
#  'reallyweb',
#  'abbreviation',
#  'third',
#  'generation',
#  'world',
#  'wide',
#  'web',
#  'term',
#  'coined',
#  'tim',
#  'bernerslee',
#  'describes',
#  'internet',
#  'interactive',
#  'chars',
#  'smart',
#  'entrepreneurs',
#  'always',
#  'look',
#  'towards',
#  'infrastructures',
#  'marketplaces',
#  'opposed',
#  'businesses',
#  'web',
#  'difference',
#  'creating',
#  'google',
#  'creating',
#  'online',
#  'website',
#  'visited',
#  'thro',
#  'chars',
#  'despite',
#  'fury',
#  'seems',
#  'exist',
#  'around',
#  'nfts',
#  'nonfungible',
#  'tokens',
#  'cryptographic',
#  'assets',
#  'represent',
#  'something',
#  'unique',
#  'market',
#  'slowed',
#  'opensea',
#  'one',
#  'chars',
#  'restaurant',
#  'addition',
#  ...]

# %%
# Generate the Ethereum N-grams where N=2
eth_bigram = Counter(ngrams(eth_tokens_list, n=2))
print(dict(eth_bigram))
# Out:
# {('meta', 'revealed'): 1, ('revealed', 'nfts'): 1, ('nfts', 'work'): 1, ('work', 'instagram'): 1, ('instagram', 'usbased'): 1, ('usbased', 'test'): 1, ('test', 'show'): 1, ('show', 'youve'): 1, ('youve', 'bought'): 1, ('bought', 'created'): 1, ('created', 'free'): 1, ('free', 'connecting'): 1, ('connecting', 'instagram'): 1, ('instagram', 'account'): 1, ('account', 'compatible'): 1, ('compatible', 'digital'): 1, ('digital', 'walle'): 1, ('walle', 'chars'): 1, ('chars', 'multibillion'): 1, ('multibillion', 'dollar'): 1, ('dollar', 'cryptocurrency'): 1, ('cryptocurrency', 'company'): 1, ('company', 'apologised'): 1, ('apologised', 'users'): 1, ('users', 'sale'): 1, ('sale', 'metaverse'): 1, ('metaverse', 'land'): 1, ('land', 'sparked'): 1, ('sparked', 'frenzy'): 1, ('frenzy', 'temporarily'): 1, ('temporarily', 'brought'): 1, ('brought', 'ethereum'): 1, ('ethereum', 'cryptocurrencyyuga'): 1, ('cryptocurrencyyuga', 'labs'): 1, ('labs', 'comp'): 1, ('comp', 'chars'): 1, ('chars', 'bored'): 1, ('bored', 'ape'): 2, ('ape', 'yacht'): 2, ('yacht', 'club'): 4, ('club', 'creators'): 2, ('creators', 'yuga'): 2, ('yuga', 'labs'): 2, ('labs', 'announced'): 1, ('announced', 'otherside'): 1, ('otherside', 'nft'): 1, ('nft', 'collection'): 2, ('collection', 'would'): 1, ('would', 'launch'): 1, ('launch', 'april'): 1, ('april', 'predicted'): 1, ('predicted', 'many'): 1, ('many', 'biggest'): 1, ('biggest', 'nft'): 1, ('nft', 'launch'): 1, ('launch', 'ever'): 1, ('ever', 'otherside'): 1, ('otherside', 'upcoming'): 1, ('upcoming', 'bore'): 1, ('bore', 'chars'): 1, ('chars', 'april'): 4, ('april', 'reuters'): 4, ('reuters', 'ether'): 1, ('ether', 'promised'): 1, ('promised', 'better'): 1, ('better', 'promised'): 1, ('promised', 'go'): 1, ('go', 'next'): 1, ('next', 'level'): 1, ('level', 'edging'): 1, ('edging', 'crypto'): 1, ('crypto', 'rivals'): 1, ('rivals', 'even'): 1, ('even', 'outshining'): 1, ('outshining', 'godfather'): 1, ('godfather', 'bitcoin'): 1, ('bitcoin', 'clocks'): 1, ('clocks', 'tickingthe'): 1, ('tickingthe', 'chars'): 1, ('chars', 'ethereum'): 1, ('ethereum', 'preparing'): 1, ('preparing', 'upgrade'): 1, ('upgrade', 'thats'): 1, ('thats', 'described'): 1, ('described', 'single'): 1, ('single', 'important'): 1, ('important', 'event'): 1, ('event', 'crypto'): 1, ('crypto', 'historythe'): 1, ('historythe', 'transition'): 1, ('transition', 'would'): 1, ('would', 'overhaul'): 1, ('overhaul', 'infrastructure'): 1, ('infrastructure', 'worlds'): 1, ('worlds', 'secondlargest'): 1, ('secondlargest', 'blockcha'): 1, ('blockcha', 'chars'): 1, ('chars', 'dogecoiners'): 1, ('dogecoiners', 'unite'): 1, ('unite', 'movie'): 1, ('movie', 'theater'): 1, ('theater', 'chain'): 1, ('chain', 'amc'): 1, ('amc', 'welcomed'): 1, ('welcomed', 'cryptocurrencies'): 1, ('cryptocurrencies', 'payment'): 1, ('payment', 'options'): 1, ('options', 'online'): 1, ('online', 'mobile'): 1, ('mobile', 'purchases'): 1, ('purchases', 'tweet'): 1, ('tweet', 'april'): 1, ('april', 'amc'): 1, ('amc', 'ceo'): 1, ('ceo', 'adam'): 1, ('adam', 'aron'): 1, ('aron', 'announced'): 1, ('announced', 'moviego'): 1, ('moviego', 'chars'): 1, ('chars', 'theres'): 1, ('theres', 'new'): 1, ('new', 'metaverse'): 1, ('metaverse', 'project'): 1, ('project', 'creators'): 1, ('creators', 'bored'): 1, ('bored', 'apes'): 2, ('apes', 'yacht'): 2, ('club', 'nfts'): 1, ('nfts', 'last'): 1, ('last', 'night'): 1, ('night', 'held'): 1, ('held', 'virtual'): 1, ('virtual', 'land'): 2, ('land', 'sale'): 2, ('sale', 'reports'): 1, ('reports', 'bloomberg'): 1, ('bloomberg', 'raising'): 1, ('raising', 'nearly'): 1, ('nearly', 'third'): 1, ('third', 'billion'): 1, ('billion', 'dollarsat'): 1, ('dollarsat', 'ab'): 1, ('ab', 'chars'): 1, ('chars', 'editorial'): 1, ('editorial', 'independencewe'): 1, ('independencewe', 'want'): 1, ('want', 'help'): 1, ('help', 'make'): 1, ('make', 'informed'): 1, ('informed', 'decisions'): 1, ('decisions', 'links'): 1, ('links', 'page'): 1, ('page', 'clearly'): 1, ('clearly',  ...

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
btc_top_10= token_count(btc_tokens_list, N=10)
btc_top_10= pd.DataFrame (btc_top_10, columns = ['word', 'count'])
btc_top_10.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_ede76_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >word</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ede76_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ede76_row0_col0" class="data row0 col0" >chars</td>
#       <td id="T_ede76_row0_col1" class="data row0 col1" >91</td>
#     </tr>
#     <tr>
#       <th id="T_ede76_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ede76_row1_col0" class="data row1 col0" >bitcoin</td>
#       <td id="T_ede76_row1_col1" class="data row1 col1" >54</td>
#     </tr>
#     <tr>
#       <th id="T_ede76_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ede76_row2_col0" class="data row2 col0" >reuters</td>
#       <td id="T_ede76_row2_col1" class="data row2 col1" >34</td>
#     </tr>
#     <tr>
#       <th id="T_ede76_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ede76_row3_col0" class="data row3 col0" >may</td>
#       <td id="T_ede76_row3_col1" class="data row3 col1" >33</td>
#     </tr>
#     <tr>
#       <th id="T_ede76_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ede76_row4_col0" class="data row4 col0" >cryptocurrency</td>
#       <td id="T_ede76_row4_col1" class="data row4 col1" >32</td>
#     </tr>
#     <tr>
#       <th id="T_ede76_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ede76_row5_col0" class="data row5 col0" >crypto</td>
#       <td id="T_ede76_row5_col1" class="data row5 col1" >21</td>
#     </tr>
#     <tr>
#       <th id="T_ede76_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ede76_row6_col0" class="data row6 col0" >cryptocurrencies</td>
#       <td id="T_ede76_row6_col1" class="data row6 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_ede76_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ede76_row7_col0" class="data row7 col0" >worlds</td>
#       <td id="T_ede76_row7_col1" class="data row7 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_ede76_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ede76_row8_col0" class="data row8 col0" >april</td>
#       <td id="T_ede76_row8_col1" class="data row8 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_ede76_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ede76_row9_col0" class="data row9 col0" >new</td>
#       <td id="T_ede76_row9_col1" class="data row9 col1" >11</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Use token_count to get the top 10 words for Ethereum
eth_top_10= token_count(eth_tokens_list, N=10)
eth_top_10= pd.DataFrame (eth_top_10, columns = ['word', 'count'])
eth_top_10.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_9aa14_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >word</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9aa14_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9aa14_row0_col0" class="data row0 col0" >chars</td>
#       <td id="T_9aa14_row0_col1" class="data row0 col1" >100</td>
#     </tr>
#     <tr>
#       <th id="T_9aa14_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9aa14_row1_col0" class="data row1 col0" >cryptocurrency</td>
#       <td id="T_9aa14_row1_col1" class="data row1 col1" >27</td>
#     </tr>
#     <tr>
#       <th id="T_9aa14_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9aa14_row2_col0" class="data row2 col0" >crypto</td>
#       <td id="T_9aa14_row2_col1" class="data row2 col1" >26</td>
#     </tr>
#     <tr>
#       <th id="T_9aa14_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9aa14_row3_col0" class="data row3 col0" >bitcoin</td>
#       <td id="T_9aa14_row3_col1" class="data row3 col1" >22</td>
#     </tr>
#     <tr>
#       <th id="T_9aa14_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9aa14_row4_col0" class="data row4 col0" >cryptocurrencies</td>
#       <td id="T_9aa14_row4_col1" class="data row4 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_9aa14_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9aa14_row5_col0" class="data row5 col0" >last</td>
#       <td id="T_9aa14_row5_col1" class="data row5 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_9aa14_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9aa14_row6_col0" class="data row6 col0" >may</td>
#       <td id="T_9aa14_row6_col1" class="data row6 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_9aa14_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9aa14_row7_col0" class="data row7 col0" >ethereum</td>
#       <td id="T_9aa14_row7_col1" class="data row7 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_9aa14_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9aa14_row8_col0" class="data row8 col0" >nfts</td>
#       <td id="T_9aa14_row8_col1" class="data row8 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_9aa14_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9aa14_row9_col0" class="data row9 col0" >digital</td>
#       <td id="T_9aa14_row9_col1" class="data row9 col1" >10</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
big_string_btc = ' '.join(btc_tokens_list)
input_text_btc = big_string_btc
wc_btc = WordCloud().generate(input_text_btc)
plt.imshow(wc_btc)

# %%
# Generate the Ethereum word cloud
big_string_eth = ' '.join(eth_tokens_list)
input_text_eth = big_string_eth
wc_eth = WordCloud().generate(input_text_eth)
plt.imshow(wc_eth)

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.3.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.3.0/en_core_web_sm-3.3.0-py3-none-any.whl (12.8 MB)
# Requirement already satisfied: spacy<3.4.0,>=3.3.0.dev0 in c:\users\owner\anaconda3\envs\mlenv\lib\site-packages (from en-core-web-sm==3.3.0) (3.3.0)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\owner\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.6.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\owner\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.0.6)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\owner\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.4.1)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\owner\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.7.7)
# Requirement already satisfied: jinja2 in c:\users\owner\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.11.3)
# Requirement already satisfied: thinc<8.1.0,>=8.0.14 in c:\users\owner\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (8.0.15)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\owner\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.26.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\owner\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.3.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in c:\users\owner\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.0.9)
# Requirement already satisfied: setuptools in c:\users\owner\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (58.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\owner\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.0.7)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\owner\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.9.1)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\owner\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.20.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\owner\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.0.6)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\owner\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.0.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\owner\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (4.62.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\owner\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (21.0)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in c:\users\owner\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.10.0.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\owner\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.4.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\owner\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.0.7)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\owner\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.8.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\owner\anaconda3\envs\mlenv\lib\site-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.6.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\owner\anaconda3\envs\mlenv\lib\site-packages (from packaging>=20.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.0.4)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\owner\anaconda3\envs\mlenv\lib\site-packages (from pathy>=0.3.5->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (5.2.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\owner\anaconda3\envs\mlenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\owner\anaconda3\envs\mlenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\owner\anaconda3\envs\mlenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\owner\anaconda3\envs\mlenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2021.10.8)
# Requirement already satisfied: colorama in c:\users\owner\anaconda3\envs\mlenv\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.4.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\owner\anaconda3\envs\mlenv\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (8.0.3)
# Requirement already satisfied: importlib-metadata in c:\users\owner\anaconda3\envs\mlenv\lib\site-packages (from click<9.0.0,>=7.1.1->typer<0.5.0,>=0.3.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (4.8.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\owner\anaconda3\envs\mlenv\lib\site-packages (from jinja2->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.1.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
btc_text = btc_ss_df['text'].str.cat()
btc_text
# Out:
# 'Now, even though there are a number of women-focused crypto spaces, Odeniran says women are still underrepresented. Ive been in spaces where Im the only Black person, or the only woman, or the only B… [+3828 chars]A Bitcoin mining site powered by otherwise lost gas from an oil well near Linden, Texas, on April 4th, 2022. | Photo by FRANCOIS PICARD/AFP via Getty Images\r\n\n \n\n Of all the corporate climate hype fl… [+6544 chars]Warren Buffett has always been a bitcoin skeptic. But the billionaire investor had his most harsh words yet for the cryptocurrency over the weekend. Buffett made it clear that his opposition to crypt… [+2297 chars]As a kid, I remember when my father tried to use a broom handle in a last ditch effort to support a roof that was collapsing from the weight of nearly three feet of snow. You can guess how well that … [+3390 chars]Image source, Getty Images\r\nThe value of Bitcoin continued to fall over the weekend as it dropped below $34,000 (£27,630), according to the Coinbase cryptocurrency exchange.\r\nThe world\'s largest cryp… [+2164 chars]If youve ever felt like introducing some Vegas-style odds into your retirement plan, youre finally in luck.\r\nLast week, Fidelity Investments announced that it would allow investors to put part of the… [+3239 chars]Cryptocurrency mixers are sometimes used to help online criminals launder their stolen money by hiding its true origins, and the US Treasury is now ready to clamp down on them when hostile government… [+1432 chars]May 11 (Reuters) - Bitcoin fell 7.23% to $28,758.29 at 22:05 GMT on Wednesday, losing $2,241.68 from its previous close.\r\nBitcoin, the world\'s biggest and best-known cryptocurrency, is down 40.4% fro… [+361 chars]May 4 (Reuters) - Bitcoin rose 5.7% to $39,862.84, on Wednesday, adding $2,102.94 to its previous close.\r\nBitcoin, the world\'s biggest and best-known cryptocurrency, is up 20.9% from the year\'s low o… [+337 chars]April 26 (Reuters) - Bitcoin dropped 5.1% to $38,391.36 on Tuesday, down $2,229.82 from its previous close.\r\nBitcoin, the world\'s biggest and best-known cryptocurrency, is up 16% from the year\'s low … [+339 chars]Posted \r\nFrom Bitcoin\'s dramatic drop to a new way to pay for your luxury Gucci handbag, we round up the week\'s big stories in cryptocurrencies. Kristy Kilburn reports.BTC fell to its lowest level since last July, as prices dropped below $33,000 to start the week. The selloff in cryptocurrency started last week, following the Fed’s decision to hike interest rates b… [+2651 chars]May 9 (Reuters) - Bitcoin dropped 7.81% to $31,333.41 at 20:03 GMT on Monday, losing $2,655.98 from its previous close.\r\nBitcoin, the world\'s biggest and best-known cryptocurrency, is down 35% from t… [+351 chars]Dogecoiners unite! Movie theater chain AMC has welcomed some more cryptocurrencies as payment options for online and mobile purchases. In a tweet on April 15, AMC CEO Adam Aron announced that moviego… [+1603 chars]At a Mexican restaurant in North London a few weeks ago, a handful of small-time but remarkably discerning retail cryptocurrency investors predicted that terra and luna would crash. Several of them w… [+2779 chars]May 10 (Reuters) - Bitcoin has scant experience with rising interest rates, posing perils for investors looking to capitalize on its dramatic drop.\r\nThe cryptocurrency has tanked along with other ris… [+4315 chars]The Central African Republic has adopted bitcoin as legal tender, making it the second nation in the world -- after El Salvador -- to do so. On Wednesday, President Faustin Archange Touadera\'s office… [+1078 chars]Sam Bankman-Fried, founder of the digital asset exchange FTX, said the proof of work system of validating blockchain transactions, which underpins bitcoin, was not capable of scaling up to cope with … [+1063 chars]El Salvador which became the first country to make bitcoin legal tender in September has lost $36 million in cryptocurrency as bitcoin plummeted over 50% from its a ...

# %%
# Run the NER processor on all of the text
nlp(btc_text)

# Add a title to the document
btc_doc=nlp(btc_text)

# %%
# Render the visualization
displacy.render(btc_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Now, even though there are a number of women-focused crypto spaces,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Odeniran
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  says women are still underrepresented. Ive been in spaces where Im the only Black person, or the only woman, or the only B… [+3828 chars]A Bitcoin mining site powered by otherwise lost gas from an oil well near
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Linden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Texas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April 4th, 2022
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . |
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Photo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FRANCOIS PICARD/AFP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  via
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Getty Images
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br></br> </br></br> Of all the corporate climate hype fl… [+6544 chars]Warren
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Buffett
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  has always been a bitcoin skeptic. But the billionaire investor had his most harsh words yet for the cryptocurrency over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the weekend
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . Buffett made it clear that his opposition to crypt… [+2297 chars]As a kid, I remember when my father tried to use a broom handle in a last ditch effort to support a roof that was collapsing from the weight of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly three feet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  of snow. You can guess how well that … [+3390 chars]Image source,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Getty Images
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# The value of Bitcoin continued to fall over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the weekend
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  as it dropped below $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     34,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  (£
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     27,630
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# ), according to the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Coinbase
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Last week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fidelity Investments
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  announced that it would allow investors to put part of the… [+3239 chars]Cryptocurrency mixers are sometimes used to help online criminals launder their stolen money by hiding its true origins, and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the US Treasury
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is now ready to clamp down on them when hostile government… [+1432 chars]May
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     11
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - Bitcoin fell
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     7.23%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  to $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     28,758.29
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  at 22:05
# <ma

# %%
# List all Entities
for ent in btc_doc.ents:
    print(ent.text, ent.label_)
# Out:
# Odeniran GPE
# Linden GPE
# Texas GPE
# April 4th, 2022 DATE
# Photo PERSON
# FRANCOIS PICARD/AFP ORG
# Getty Images ORG
# Buffett PERSON
# the weekend DATE
# nearly three feet QUANTITY
# Getty Images
#  ORG
# the weekend DATE
# 34,000 MONEY
# 27,630 MONEY
# Coinbase PERSON
# Last week DATE
# Fidelity Investments ORG
# the US Treasury ORG
# 11 CARDINAL
# Reuters ORG
# 7.23% PERCENT
# 28,758.29 MONEY
# GMT WORK_OF_ART
# Wednesday DATE
# 2,241.68 MONEY
# 40.4% PERCENT
# +361 chars]May 4 ORG
# Reuters ORG
# 5.7% PERCENT
# 39,862.84 MONEY
# Wednesday DATE
# 2,102.94 MONEY
# 20.9% PERCENT
# year DATE
# Reuters ORG
# 5.1% PERCENT
# 38,391.36 MONEY
# Tuesday DATE
# 2,229.82 MONEY
# 16% PERCENT
# year DATE
# Bitcoin ORG
# Gucci handbag PERSON
# week DATE
# Kristy Kilburn PERSON
# last July DATE
# 33,000 MONEY
# the week DATE
# last week DATE
# Fed ORG
# 9 CARDINAL
# Reuters ORG
# 7.81% PERCENT
# 31,333.41 MONEY
# GMT WORK_OF_ART
# Monday DATE
# 2,655.98 MONEY
# 35% PERCENT
# AMC ORG
# April 15 DATE
# AMC ORG
# Adam Aron PERSON
# Mexican NORP
# North London LOC
# a few weeks ago DATE
# +2779 chars]May ORG
# 10 CARDINAL
# Reuters ORG
# chars]The Central African Republic NORP
# second ORDINAL
# El Salvador GPE
# Wednesday DATE
# Faustin Archange PERSON
# Touadera GPE
# Bankman-Fried PERSON
# the digital asset exchange ORG
# FTX ORG
# first ORDINAL
# September DATE
# $36 million MONEY
# over 50% PERCENT
# Thursday DATE
# April 28 DATE
# Reuters ORG
# April 27 DATE
# Reuters ORG
# Wednesday DATE
# first ORDINAL
# Africa LOC
# second ORDINAL
# South Africa's GPE
# one trillion rand MONEY
# Zambia GPE
# Mopani NORP
# Nasdaq ORG
# Tom Scally PERSON
# 05/13 Cryptocurrencies PRODUCT
# early Friday DATE
# TerraUSD ORG
# May 5 DATE
# Reuters ORG
# - Block Inc ORG
# Jack Dorsey PERSON
# Thursday DATE
# the first quarter DATE
# Nasdaq ORG
# HONG KONG GPE
# May 16 DATE
# Reuters ORG
# Monday DATE
# the weekend DATE
# European NORP
# April 29 DATE
# Reuters ORG
# The Swiss National Bank ORG
# Thomas Jordan PERSON
# annual DATE
# Friday DATE
# May 10 DATE
# Reuters ORG
# Australian NORP
# Canadian NORP
# Tuesday DATE
# Warhol PERSON
# the week to May 13 DATE
# Olivia Chan PERSON
# SALVADOR ORG
# NEW YORK GPE
# May 19 DATE
# Reuters ORG
# El Salvador's GPE
# Central American NORP
# September DATE
# recent weeks DATE
# Transform 2022 LAW
# July 19 and virtually DATE
# July 20 - 28 DATE
# today DATE
# 16 CARDINAL
# Reuters ORG
# FTX ORG
# Bitcoin ORG
# Ukraine GPE
# Fed ORG
# +2914 chars]40 days ago DATE
# 47,454 MONEY
# 34,007 MONEY
# 28%.About a third CARDINAL
# this week DATE
# El Salvador's GPE
# Bloomberg GPE
# Nayib Bukele PERSON
# 1 MONEY
# Tuesday DATE
# the previous day's DATE
# one-year DATE
# +3816 chars]HONG KONG ORG
# May 9 DATE
# Reuters ORG
# January on Monday DATE
# Monday DATE
# 32,940 MONEY
# more than 50% PERCENT
# 68,990 MONEY
# November DATE
# 16% PERCENT
# Monday DATE
# 2020 DATE
# 18% PERCENT
# Mexico GPE
# May 10 DATE
# Reuters ORG
# fourth ORDINAL
# third ORDINAL
# Tuesday DATE
# Berkshire Hathaway PERSON
# Warren Buffett PERSON
# Bitcoin ORG
# just a few years ago DATE
# Spacex PERSON
# $7.139 billion MONEY
# Twitter ORG
# IndependenceWe NORP
# May 13 DATE
# Reuters ORG
# Friday DATE
# 30,000 MONEY
# TerraUSD ORG
# NEW YORK GPE
# May 12 DATE
# Reuters ORG
# one CARDINAL
# Thursday DATE
# Tether PERSON
# Charley Cooper PERSON
# R3 GPE
# May 13 DATE
# Reuters ORG
# Central Africa's GPE
# Friday DATE
# weeks DATE
# the Central African Republic LOC
# 5 CARDINAL
# Reuters ORG
# Gucci PERSON
# U.S. GPE
# Italian NORP
# chars]LONDON ORG
# May 2 DATE
# Silicon Valley LOC
# Central African Republic LOC
# CAR ORG
# Wednesday DATE
# chars]LONDON ORG
# May 4 DATE
# Reuters ORG
# $100 billion MONEY
# chars]NEW YORK GPE
# AP ORG
# a wild week DATE
# third ORDINAL
# early Friday DATE
# TerraUSD ORG
# Tom Scally PERSON
# April 26 DATE
# Reuters ORG
# No.2 CARDINAL
# Luna PERSON
# TerraUSD ORG
# Joe Mullally PERSON
# US GPE
# 37.84% PERCENT
# between September 2021 to January DATE
# the Cambridge Centre for Alternative ORG
# CAR ORG
# decades DATE
# Russian NORP
# the Wagner Group ORG
# 16% PERCENT
# $59 million MONEY
# Miami GPE
# Bitcoin NORP
# Sam Bankman-Fried PERSON
# FTX ORG
# the Financial Times ORG
# Party ORG
# Pierre Poilievre PERSON
# Ottawa ORG
# 16 CARDINAL
# one CARDINAL
# Bitcoin NORP
# 27,000 MONEY
# Thursday DATE
# morning TIME
# 2020 DATE
# one CARDINAL
# REUTERS ORG
# Dado Ruvic PERSON
# chars]NEW YORK GPE
# April 29 DATE
# Reuters ORG
# U.S. GPE
# the latest week DATE
# Reuters ORG
# U.S. Commodity Futures Trading Commission ORG
# Fidelity ORG
# Fidelity ORG
# May 13 DATE
# Reuters ORG
# Nomura ORG
# 8604.T CARDINAL
# Friday DATE
# 2021 DATE
# ATM ORG
# Hong Kong GPE
# 2017 DATE
# Kin Cheung/AP PERSON
# NEW YORK GPE
# +4321 chars]Wow PERSON
# January 2007 DATE
# Steve Jobs PERSON
# New York City GPE
# January 2021 DATE
# Miami GPE
# Francis Suarez PERSON
# The City of GPE
# Miami GPE
# # CARDINAL
# Fla. GPE
# May 5 DATE
# Reuters ORG
# U.S. GPE
# the 2000s DATE
# Fla. GPE
# May 12 DATE
# Reuters ORG
# +6190 chars]May 12 ORG
# Reuters ORG
# TerraUSD ORG
# Thursday DATE
# 2021 DATE
# 16 CARDINAL
# a wild week DATE
# third ORDINAL
# last week DATE
# Namthip Muanthongthae
# Investors ORG
# last week DATE
# recent days DATE
# chars]WASHINGTON GPE
# MUMBAI GPE
# May 17 DATE
# Reuters ORG
# Nofe Isah PERSON
# 25-year old DATE
# Nigeria GPE
# January DATE
# Last week DATE
# 5,000 MONEY
# +5652 chars]NEW YORK ORG
# May 11 DATE
# Reuters ORG
# Coinbase Global WORK_OF_ART
# Bitcoin NORP
# chars]LONDON ORG
# April 29 DATE
# 400% PERCENT
# 1,400% PERCENT
# the past two DATE
# chars]LONDON/HONG KONG ORG
# May 12 DATE
# Reuters ORG
# the next year DATE
# chars](Kitco News ORG
# Terra ORG
# more than 97 percent PERCENT
# the past few days DATE
# UST ORG
# 2 cents MONEY
# early Thursday DATE
# 30% PERCENT
# 2020 DATE
# April 25 DATE
# Reuters ORG
# Canadian NORP
# Monday DATE
# Conservative NORP
# BLOCKSCALEIntels ORG
# the Intel Blockscale ASIC ORG
# Q3 2022 DATE
# Bitcoin Magazine ORG
# April 2022 DATE
# Friday DATE
# Dow Jones ORG
# nearly 1,000 CARDINAL
# Fed ORG
# Jerome Powell PERSON
# GPV ORG
# 31% PERCENT
# year DATE
# YoY ORG
# $43.5 billion MONEY
# GPV ORG
# the same period  DATE
# multibillion-dollar MONEY
# Coinbases ORG
# Brian Armstrong PERSON
# chars]NEW YORK GPE
# Fidelity ORG
# Tuesda ORG
# Charlie Munger PERSON
# Apple and Activision Blizzard ORG
# last quarter DATE
# Berkshire Hathaway's PERSON
# this year DATE
# Metaverse ORG
# this year DATE
# Metaverse ORG
# Dhara Ranasinghe ORG
# Friday 13 DATE
# April 27 DATE
# Reuters ORG
# Cuban NORP
# Tuesday DATE
# last year DATE

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
eth_text = eth_ss_df['text'].str.cat()
eth_text
# Out:
# 'Meta has revealed more of how NFTs will work on Instagram. In the US-based test, you can show what you\'ve bought or created for free by connecting your Instagram account to a compatible digital walle… [+1223 chars]A multi-billion dollar cryptocurrency company has apologised to users after its sale of metaverse land sparked a frenzy that temporarily brought down the Ethereum cryptocurrency.\r\nYuga Labs, the comp… [+3475 chars]When Bored Ape Yacht Club creators Yuga Labs announced its Otherside NFT collection would launch on April 30, it was predicted by many to be the biggest NFT launch ever. Otherside is an upcoming Bore… [+6669 chars]April 26 (Reuters) - Ether has promised to do better. It has promised to go to the next level, edging out crypto rivals and even outshining the godfather, bitcoin. But the clock\'s ticking.\r\nThe No.2 … [+4092 chars]Ethereum is preparing for an upgrade thats been described as the single most important event in crypto history.\r\nThe transition would overhaul the infrastructure of the worlds second-largest blockcha… [+2824 chars]Dogecoiners unite! Movie theater chain AMC has welcomed some more cryptocurrencies as payment options for online and mobile purchases. In a tweet on April 15, AMC CEO Adam Aron announced that moviego… [+1603 chars]There\'s a new metaverse project from the creators of the "Bored Apes Yacht Club" NFTs. Last night they held a "virtual land" sale, reports Bloomberg, raising nearly a third of a billion dollars.At ab… [+2023 chars]Editorial IndependenceWe want to help you make more informed decisions. Some links on this page clearly marked may take you to a partner website and may result in us earning a referral commission. Fo… [+6022 chars]40 days ago Bitcoin sold for $47,454. It\'s price now is $34,007 — a drop of 28%.About a third of that drop happened this week, as "Bitcoin, ethereum and other major cryptocurrencies have fallen sharp… [+975 chars]When Nvidia launched its Ampere Lite Hash Rate (LHR) graphics card with the feared Ethereum anti-mining limiter, the world knew it was only a matter of time before someone or a team cracked it. NiceH… [+1230 chars]May 4 (Reuters) - Bitcoin rose 5.7% to $39,862.84, on Wednesday, adding $2,102.94 to its previous close.\r\nBitcoin, the world\'s biggest and best-known cryptocurrency, is up 20.9% from the year\'s low o… [+337 chars]April 26 (Reuters) - Bitcoin dropped 5.1% to $38,391.36 on Tuesday, down $2,229.82 from its previous close.\r\nBitcoin, the world\'s biggest and best-known cryptocurrency, is up 16% from the year\'s low … [+339 chars]May 11 (Reuters) - Bitcoin fell 7.23% to $28,758.29 at 22:05 GMT on Wednesday, losing $2,241.68 from its previous close.\r\nBitcoin, the world\'s biggest and best-known cryptocurrency, is down 40.4% fro… [+361 chars]May 9 (Reuters) - Bitcoin dropped 7.81% to $31,333.41 at 20:03 GMT on Monday, losing $2,655.98 from its previous close.\r\nBitcoin, the world\'s biggest and best-known cryptocurrency, is down 35% from t… [+351 chars]If you ever wanted to buy an NFT based on Ethereum, you would have to pay a transaction fee to register it on the blockchain. Last week, that fee skyrocketed to unprecedented levels.\r\nSo you might ha… [+7216 chars]9 with 8 posters participating\r\nNvidia began releasing LHR (or Lite Hash Rate) graphics cards last year\xa0to slow down their cryptocurrency mining performance and make them less appealing to non-gamers… [+2182 chars]BTC fell to its lowest level since last July, as prices dropped below $33,000 to start the week. The selloff in cryptocurrency started last week, following the Fed’s decision to hike interest rates b… [+2651 chars]The cryptocurrency boom over the past few years has helped propel a newer market to record heights: digital collectibles known as NFTs.\xa0\r\nThe craze has pushed total NFT sales volume to $29 billion ov… [+2866 chars]ApeCoin, the native cryptocurrency of the APE Ecosystem, slid 16% Monday in a viciously volatile trading session.\r\ ...

# %%
# Run the NER processor on all of the text
nlp(eth_text)

# Add a title to the document
eth_doc=nlp(eth_text)

# %%
# Render the visualization
displacy.render(eth_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Meta
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has revealed more of how NFTs will work on
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Instagram
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . In the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# -based test, you can show what you've bought or created for free by connecting your
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Instagram
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  account to a compatible digital walle… [+1223 chars]A multi-billion dollar cryptocurrency company has apologised to users after its sale of metaverse land sparked a frenzy that temporarily brought down the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Yuga Labs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , the comp… [+3475 chars]When Bored Ape
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Yacht Club
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  creators
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Yuga Labs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  announced its
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Otherside NFT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LAW</span>
# </mark>
#  collection would launch on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April 30
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , it was predicted by many to be the biggest
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NFT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  launch ever. Otherside is an upcoming Bore… [+6669
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chars]April 26
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>The
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     No.2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>The transition would overhaul the infrastructure of the worlds
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     second
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# -largest blockcha… [+2824 chars]Dogecoiners unite! Movie theater chain
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AMC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has welcomed some more cryptocurrencies as payment options for online and mobile purchases. In a tweet on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April 15
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AMC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  CEO
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Adam Aron
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  announced that moviego… [+1603 chars]There's a new metaverse project from the creators of the &quot;Bored Apes Yacht Club&quot; NFTs.
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Last night
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  they held a &quot;virtual land&quot; sale, reports
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bloomberg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , raising
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly a third
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a billion dollars
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius:

# %%
# List all Entities
for ent in eth_doc.ents:
    print(ent.text, ent.label_)
# Out:
# Meta ORG
# Instagram ORG
# US GPE
# Instagram ORG
# Ethereum ORG
# Yuga Labs PERSON
# Yacht Club ORG
# Yuga Labs PERSON
# Otherside NFT LAW
# April 30 DATE
# NFT ORG
# chars]April 26 DATE
# Reuters ORG
# No.2 CARDINAL
# second ORDINAL
# AMC ORG
# April 15 DATE
# AMC ORG
# Adam Aron PERSON
# Last night TIME
# Bloomberg GPE
# nearly a third CARDINAL
# a billion dollars MONEY
# IndependenceWe NORP
# chars]40 days ago DATE
# 47,454 MONEY
# 34,007 MONEY
# 28%.About a third CARDINAL
# this week DATE
# Nvidia PERSON
# Ampere Lite Hash Rate WORK_OF_ART
# LHR ORG
# Ethereum ORG
# 4 CARDINAL
# Reuters ORG
# 5.7% PERCENT
# 39,862.84 MONEY
# Wednesday DATE
# 2,102.94 MONEY
# 20.9% PERCENT
# year DATE
# Reuters ORG
# 5.1% PERCENT
# 38,391.36 MONEY
# Tuesday DATE
# 2,229.82 MONEY
# 16% PERCENT
# year DATE
# +339 chars]May 11 ORG
# Reuters ORG
# 7.23% PERCENT
# 28,758.29 MONEY
# GMT WORK_OF_ART
# Wednesday DATE
# 2,241.68 MONEY
# 40.4% PERCENT
# +361 chars]May 9 ORG
# Reuters ORG
# 7.81% PERCENT
# 31,333.41 MONEY
# GMT WORK_OF_ART
# Monday DATE
# 2,655.98 MONEY
# 35% PERCENT
# NFT ORG
# Ethereum ORG
# Last week DATE
# 8 CARDINAL
# Nvidia ORG
# LHR ORG
# last year  DATE
# last July DATE
# 33,000 MONEY
# the week DATE
# last week DATE
# Fed ORG
# the past few years DATE
# NFT ORG
# $29 billion MONEY
# 16% PERCENT
# Monday DATE
# 14.60 MONEY
# Transform 2022 LAW
# July 19 and virtually DATE
# July 20 - 28 DATE
# today DATE
# Getty Images
#  ORG
# the weekend DATE
# 34,000 MONEY
# 27,630 MONEY
# Coinbase PERSON
# 5 CARDINAL
# Reuters ORG
# Gucci PERSON
# U.S. GPE
# Italian NORP
# 22 CARDINAL
# Reuters ORG
# - Twitter Inc ORG
# Stripe Inc ORG
# Saturday DATE
# Yuga Labs―the company ORG
# the Bored Apes Yacht Club NFT collection― ORG
# Otherdeeds ORG
# Terras UST ORG
# 40 cents MONEY
# Alex Castro ORG
# a crushing few days DATE
# Terra PERSON
# a week DATE
# chars]The U.S. Department of Justice ORG
# two CARDINAL
# European NORP
# North Korean NORP
# 2019 DATE
# One CARDINAL
# 30 DATE
# a tough month DATE
# 25% PERCENT
# 30% PERCENT
# 81 MONEY
# a month ago DATE
# multibillion-dollar MONEY
# 1% PERCENT
# Bitcoin and Ethereum ORG
# first ORDINAL
# eToro ORG
# CopyPortfolios PRODUCT
# CopyTrader ORG
# May 9 DATE
# Reuters ORG
# January on Monday DATE
# Bitcoin, Ethereum ORG
# DogeCoin ORG
# June 29, 2021 DATE
# REUTERS ORG
# Dado Ruvic/Illustration/File Photo/Fi PERSON
# one CARDINAL
# REUTERS ORG
# Dado Ruvic PERSON
# Jack Dorsey PERSON
# Twitter ORG
# Party ORG
# Pierre Poilievre PERSON
# Ottawa ORG
# the Senate of the Republic ORG
# Mexico GPE
# thousands CARDINAL
# Hohndel ORG
# Slashdot ORG
# the last five years DATE
# VMware ORG
# Monday DATE
# 32,940 MONEY
# more than 50% PERCENT
# 68,990 MONEY
# November DATE
# the past few years DATE
# Metaverse ORG
# +1613 chars]By NORP
# 2022 DATE
# Ethereum ORG
# 2021 DATE
# 2,000 acres QUANTITY
# about US$4 million MONEY
# last week DATE
# 404 CARDINAL
# as low as $0.94 MONEY
# Thursday DATE
# 0.9 MONEY
# this year DATE
# Meta ORG
# Mark Zuckerberg PERSON
# platform Instagram PERSON
# May DATE
# the start of the month DATE
# $600 billion MONEY
# 2020 DATE
# 3.0 CARDINAL
# 3.0 CARDINAL
# third ORDINAL
# Tim Berners-Lee PERSON
# 2022 DATE
# OpenSea ORG
# one CARDINAL
# NFT ORG
# Hungry ORG
# 16 CARDINAL
# one CARDINAL
# Bitcoin NORP
# 27,000 MONEY
# Thursday DATE
# morning TIME
# 2020 DATE
# Coinbase PERSON
# eToro ORG
# chars]April 25 DATE
# Reuters ORG
# multibillion-dollar MONEY
# Coinbases ORG
# Brian Armstrong PERSON
# GamesBeat Summit 2022 ORG
# first ORDINAL
# today DATE
# dis ORG
# chars]arXivLabs ORG
# arXivLabs ORG
# morning TIME
# Fed ORG
# DeFi GPE
# Fidelity ORG
# Fidelity ORG
# last week DATE
# Namthip Muanthongthae
# Investors ORG
# last week DATE
# Thursday DATE
# US GPE
# last month DATE
# Crypto.com Pay ORG
# Crypto.com ORG
# 0.5% PERCENT
# Stripe ORG
# Stripe PERSON
# Friday DATE
# Twitter ORG
# +944 ORG
# NFT ORG
# Ethereum ORG
# Sarah Tew/CNET PERSON
# Coinbase PERSON
# NFT ORG
# Wednesday DATE
# Bored Ape Yacht Club PERSON
# Yuga Labs PERSON
# thousands of dollars MONEY
# Ethereum ORG
# Dive
#  ORG
# daily DATE
# -21.76 ORG
# The Crypto Show WORK_OF_ART
# Bitcoin NORP
# almost 20% PERCENT
# the past ten days DATE
# weeks DATE
# Bloomberg Intelligence PERSON
# this week DATE
# Friday DATE
# SEC ORG
# Nvidia ORG
# $5.5 million MONEY
# GPU ORG
# 3 CARDINAL
# 3 CARDINAL
# 3 CARDINAL
# Reuters ORG
# 2022 DATE
# the last year DATE
# March 22 DATE
# Stephenson ORG
# 1992 DATE
# Snow Crash PERSON
# first ORDINAL
# Thursday DATE
# Stephenson PERSON
# first ORDINAL
# NFT ORG
# Neophyte MMXXII #94 WORK_OF_ART
# Ster PERSON
# Transform 2022 LAW
# July 19 and virtually DATE
# July 20 - 28 DATE
# today DATE
# thousands CARDINAL
# Ethereum(ETH -3.30% PERSON
# second ORDINAL
# years DATE
# the last few years DATE
# one CARDINAL
# Ethereum ORG
# -2.75% PERCENT
# Ethereum ORG
# a rough week DATE
# Monday DATE
# morning TIME
# a new month DATE
# 0.12% PERCENT
# 5,500% PERCENT
# the past five years DATE
# +3866 PERSON
# June 2009 DATE
# one CARDINAL
# 0.0001 USD PERCENT
# November 2021 DATE
# Italian NORP
# Gucci PERSON
# US GPE
# Gucci PERSON
# 10 CARDINAL
# Bitcoin, Ethereum ORG
# the past five years DATE
# 10.54% PERCENT
# 2,560% PERCENT
# chars]Ava Labs PERSON
# -23.35% PERCENT
# The Crypto Show WORK_OF_ART
# April 20 DATE
# Fool.com ORG
# Solana  PRODUCT
# SOL -4.10 ORG
# ADA ORG
# 0.02% PERCENT
# +3203 GPE
# NFT ORG
# Decrypt PERSON
# Solana ORG
# yesterday DATE
# 4.03% PERCENT
# 4.58% PERCENT
# 500 MONEY
# Ethereum ORG
# -3.94% PERCENT
# 41% PERCENT
# $1.3 trillion MONEY
# year to date DATE
# +2952 chars]Bloomberg's ORG
# Levine: Can WORK_OF_ART
# Coinbase PRODUCT
# Coinbase Pro PERSON
# 16% PERCENT
# next year DATE
# Today DATE

# %% [markdown]
# ---
